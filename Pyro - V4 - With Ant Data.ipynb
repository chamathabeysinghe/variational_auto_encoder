# %%
import argparse
import math
import os
import time
from functools import partial

import numpy as np
import torch
import visdom

import pyro
import pyro.contrib.examples.multi_mnist as multi_mnist
import pyro.optim as optim
import pyro.poutine as poutine
from components.AIR import AIR, latents_to_tensor
from pyro.contrib.examples.util import get_data_directory
from pyro.infer import SVI, JitTraceGraph_ELBO, TraceGraph_ELBO
from utils.viz import draw_many, tensor_to_objs
from utils.visualizer import plot_mnist_sample
from utils.visualizer import plot_mnist_sample

# %% [markdown]
# ## Support functions

# %%
def count_accuracy(X, true_counts, air, batch_size):
    assert X.size(0) == true_counts.size(0), 'Size mismatch.'
    assert X.size(0) % batch_size == 0, 'Input size must be multiple of batch_size.'
    counts = torch.LongTensor(3, 4).zero_()
    error_latents = []
    error_indicators = []

    def count_vec_to_mat(vec, max_index):
        out = torch.LongTensor(vec.size(0), max_index + 1).zero_()
        out.scatter_(1, vec.type(torch.LongTensor).view(vec.size(0), 1), 1)
        return out

    for i in range(X.size(0) // batch_size):
        X_batch = X[i * batch_size:(i + 1) * batch_size]
        true_counts_batch = true_counts[i * batch_size:(i + 1) * batch_size]
        z_where, z_pres = air.guide(X_batch, batch_size)
        inferred_counts = sum(z.cpu() for z in z_pres).squeeze().data
        true_counts_m = count_vec_to_mat(true_counts_batch, 2)
        inferred_counts_m = count_vec_to_mat(inferred_counts, 3)
        counts += torch.mm(true_counts_m.t(), inferred_counts_m)
        error_ind = 1 - (true_counts_batch == inferred_counts)
        error_ix = error_ind.nonzero().squeeze()
        error_latents.append(latents_to_tensor((z_where, z_pres)).index_select(0, error_ix))
        error_indicators.append(error_ind)

    acc = counts.diag().sum().float() / X.size(0)
    error_indices = torch.cat(error_indicators).nonzero().squeeze()
    if X.is_cuda:
        error_indices = error_indices.cuda()
    return acc, counts, torch.cat(error_latents), error_indices


# Defines something like a truncated geometric. Like the geometric,
# this has the property that there's a constant difference in log prob
# between p(steps=n) and p(steps=n+1).
def make_prior(k):
    assert 0 < k <= 1
    u = 1 / (1 + k + k**2 + k**3)
    p0 = 1 - u
    p1 = 1 - (k * u) / p0
    p2 = 1 - (k**2 * u) / (p0 * p1)
    trial_probs = [p0, p1, p2]
    # dist = [1 - p0, p0 * (1 - p1), p0 * p1 * (1 - p2), p0 * p1 * p2]
    # print(dist)
    return lambda t: trial_probs[t]


# Implements "prior annealing" as described in this blog post:
# http://akosiorek.github.io/ml/2017/09/03/implementing-air.html

# That implementation does something very close to the following:
# --z-pres-prior (1 - 1e-15)
# --z-pres-prior-raw
# --anneal-prior exp
# --anneal-prior-to 1e-7
# --anneal-prior-begin 1000
# --anneal-prior-duration 1e6

# e.g. After 200K steps z_pres_p will have decayed to ~0.04

# These compute the value of a decaying value at time t.
# initial: initial value
# final: final value, reached after begin + duration steps
# begin: number of steps before decay begins
# duration: number of steps over which decay occurs
# t: current time step


def lin_decay(initial, final, begin, duration, t):
    assert duration > 0
    x = (final - initial) * (t - begin) / duration + initial
    return max(min(x, initial), final)


def exp_decay(initial, final, begin, duration, t):
    assert final > 0
    assert duration > 0
    # half_life = math.log(2) / math.log(initial / final) * duration
    decay_rate = math.log(initial / final) / duration
    x = initial * math.exp(-decay_rate * (t - begin))
    return max(min(x, initial), final)

# %% [markdown]
# ## Args

# %%
parser = argparse.ArgumentParser(description="Pyro AIR example", argument_default=argparse.SUPPRESS)
parser.add_argument('-n', '--num-steps', type=int, default=int(1e8),
                    help='number of optimization steps to take')
parser.add_argument('-b', '--batch-size', type=int, default=64,
                    help='batch size')
parser.add_argument('-lr', '--learning-rate', type=float, default=1e-4,
                    help='learning rate')
parser.add_argument('-blr', '--baseline-learning-rate', type=float, default=1e-3,
                    help='baseline learning rate')
parser.add_argument('--progress-every', type=int, default=1,
                    help='number of steps between writing progress to stdout')
parser.add_argument('--eval-every', type=int, default=0,
                    help='number of steps between evaluations')
parser.add_argument('--baseline-scalar', type=float,
                    help='scale the output of the baseline nets by this value')
parser.add_argument('--no-baselines', action='store_true', default=False,
                    help='do not use data dependent baselines')
parser.add_argument('--encoder-net', type=int, nargs='+', default=[200],
                    help='encoder net hidden layer sizes')
parser.add_argument('--decoder-net', type=int, nargs='+', default=[200],
                    help='decoder net hidden layer sizes')
parser.add_argument('--predict-net', type=int, nargs='+',
                    help='predict net hidden layer sizes')
parser.add_argument('--embed-net', type=int, nargs='+',
                    help='embed net architecture')
parser.add_argument('--bl-predict-net', type=int, nargs='+',
                    help='baseline predict net hidden layer sizes')
parser.add_argument('--non-linearity', type=str,
                    help='non linearity to use throughout')
parser.add_argument('--viz', action='store_true', default=True,
                    help='generate vizualizations during optimization')
parser.add_argument('--viz-every', type=int, default=100,
                    help='number of steps between vizualizations')
parser.add_argument('--visdom-env', default='main',
                    help='visdom enviroment name')
parser.add_argument('--load', type=str,
                    help='load previously saved parameters')
parser.add_argument('--save', type=str,
                    help='save parameters to specified file')
parser.add_argument('--save-every', type=int, default=1e4,
                    help='number of steps between parameter saves')
parser.add_argument('--cuda', action='store_true', default=False,
                    help='use cuda')
parser.add_argument('--jit', action='store_true', default=False,
                    help='use PyTorch jit')
parser.add_argument('-t', '--model-steps', type=int, default=3,
                    help='number of time steps')
parser.add_argument('--rnn-hidden-size', type=int, default=256,
                    help='rnn hidden size')
parser.add_argument('--encoder-latent-size', type=int, default=50,
                    help='attention window encoder/decoder latent space size')
parser.add_argument('--decoder-output-bias', type=float,
                    help='bias added to decoder output (prior to applying non-linearity)')
parser.add_argument('--decoder-output-use-sigmoid', action='store_true',
                    help='apply sigmoid function to output of decoder network')
parser.add_argument('--window-size', type=int, default=28,
                    help='attention window size')
parser.add_argument('--z-pres-prior', type=float, default=0.5,
                    help='prior success probability for z_pres')
parser.add_argument('--z-pres-prior-raw', action='store_true', default=False,
                    help='use --z-pres-prior directly as success prob instead of a geometric like prior')
parser.add_argument('--anneal-prior', choices='none lin exp'.split(), default='none',
                    help='anneal z_pres prior during optimization')
parser.add_argument('--anneal-prior-to', type=float, default=1e-7,
                    help='target z_pres prior prob')
parser.add_argument('--anneal-prior-begin', type=int, default=0,
                    help='number of steps to wait before beginning to anneal the prior')
parser.add_argument('--anneal-prior-duration', type=int, default=100000,
                    help='number of steps over which to anneal the prior')
parser.add_argument('--pos-prior-mean', type=float,
                    help='mean of the window position prior')
parser.add_argument('--pos-prior-sd', type=float,
                    help='std. dev. of the window position prior')
parser.add_argument('--scale-prior-mean', type=float,
                    help='mean of the window scale prior')
parser.add_argument('--scale-prior-sd', type=float,
                    help='std. dev. of the window scale prior')
parser.add_argument('--no-masking', action='store_true', default=False,
                    help='do not mask out the costs of unused choices')
parser.add_argument('--seed', type=int, help='random seed', default=None)
parser.add_argument('-v', '--verbose', action='store_true', default=False,
                    help='write hyper parameters and network architecture to stdout')
# Out:
# _StoreTrueAction(option_strings=['-v', '--verbose'], dest='verbose', nargs=0, const=True, default=False, type=None, choices=None, help='write hyper parameters and network architecture to stdout', metavar=None)

# %%
# vars(parser.parse_args(""))
args = argparse.Namespace(**vars(parser.parse_args("")))

# %%
if 'save' in args:
    if os.path.exists(args.save):
        raise RuntimeError('Output file "{}" already exists.'.format(args.save))

if args.seed is not None:
    pyro.set_rng_seed(args.seed)

# Build a function to compute z_pres prior probabilities.
if args.z_pres_prior_raw:
    def base_z_pres_prior_p(t):
        return args.z_pres_prior
else:
    base_z_pres_prior_p = make_prior(args.z_pres_prior)

# Wrap with logic to apply any annealing.
def z_pres_prior_p(opt_step, time_step):
    p = base_z_pres_prior_p(time_step)
    if args.anneal_prior == 'none':
        return p
    else:
        decay = dict(lin=lin_decay, exp=exp_decay)[args.anneal_prior]
        return decay(p, args.anneal_prior_to, args.anneal_prior_begin,
                     args.anneal_prior_duration, opt_step)

# %% [markdown]
# ## Data loader

# %%
def load_data():
#     inpath = './air/.data'
#     X_np, Y = multi_mnist.load(inpath)
    X_np = np.load('/Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/data/synthetic/smaill_size-150_rad-5.npy')
    X_np = X_np.astype(np.float32)
    X_np /= 255.0
    X = torch.from_numpy(X_np)
    # Using FloatTensor to allow comparison with values sampled from
    # Bernoulli.
    counts = torch.FloatTensor([1 for objs in X_np])
    return X, counts

# %%
#     X_np = np.load('/Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/data/synthetic/size-50_rad-5.npy')

X, true_counts = load_data()
X_size = X.size(0)
if args.cuda:
    X = X.cuda()

# %%
X.shape
# plot_mnist_sample(X[2])
# Out:
# torch.Size([10000, 150, 150])

# %% [markdown]
# ## Model

# %%
model_arg_keys = ['window_size',
                  'rnn_hidden_size',
                  'decoder_output_bias',
                  'decoder_output_use_sigmoid',
                  'baseline_scalar',
                  'encoder_net',
                  'decoder_net',
                  'predict_net',
                  'embed_net',
                  'bl_predict_net',
                  'non_linearity',
                  'pos_prior_mean',
                  'pos_prior_sd',
                  'scale_prior_mean',
                  'scale_prior_sd']
model_args = {key: getattr(args, key) for key in model_arg_keys if key in args}

# %%
air = AIR(
        num_steps=args.model_steps,
        x_size=150,
        use_masking=not args.no_masking,
        use_baselines=not args.no_baselines,
        z_what_size=args.encoder_latent_size,
        use_cuda=args.cuda,
        **model_args
    )

# %%
if 'load' in args:
    print('Loading parameters...')
    air.load_state_dict(torch.load(args.load))

# %% [markdown]
# ## Visualize

# %%
if args.viz:
    vis = visdom.Visdom(env=args.visdom_env)
    z, x = air.prior(5, z_pres_prior_p=partial(z_pres_prior_p, 0))
    vis.images(draw_many(x, tensor_to_objs(latents_to_tensor(z))))
# Out:
# Setting up a new session...
# /Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/nn/functional.py:2764: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/nn/functional.py:2705: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "

# %% [markdown]
# ## Optimizer

# %%
def isBaselineParam(module_name, param_name):
    return 'bl_' in module_name or 'bl_' in param_name

def per_param_optim_args(module_name, param_name):
    lr = args.baseline_learning_rate if isBaselineParam(module_name, param_name) else args.learning_rate
    return {'lr': lr}

adam = optim.Adam(per_param_optim_args)
elbo = JitTraceGraph_ELBO() if args.jit else TraceGraph_ELBO()
svi = SVI(air.model, air.guide, adam, loss=elbo)

# %%
t0 = time.time()
examples_to_viz = X[5:10]

for i in range(1, args.num_steps + 1):

    loss = svi.step(X, batch_size=args.batch_size, z_pres_prior_p=partial(z_pres_prior_p, i))

    if args.progress_every > 0 and i % args.progress_every == 0:
        print('i={}, epochs={:.2f}, elapsed={:.2f}, elbo={:.2f}'.format(
            i,
            (i * args.batch_size) / X_size,
            (time.time() - t0) / 3600,
            loss / X_size))

    if args.viz and i % args.viz_every == 0:
        print('Drawing')
        trace = poutine.trace(air.guide).get_trace(examples_to_viz, None)
        z, recons = poutine.replay(air.prior, trace=trace)(examples_to_viz.size(0))
        z_wheres = tensor_to_objs(latents_to_tensor(z))

        # Show data with inferred objection positions.
        vis.images(draw_many(examples_to_viz, z_wheres))
        # Show reconstructions of data.
        vis.images(draw_many(recons, z_wheres))

    if args.eval_every > 0 and i % args.eval_every == 0:
        # Measure accuracy on subset of training data.
        acc, counts, error_z, error_ix = count_accuracy(X, true_counts, air, 1000)
        print('i={}, accuracy={}, counts={}'.format(i, acc, counts.numpy().tolist()))
        if args.viz and error_ix.size(0) > 0:
            vis.images(draw_many(X[error_ix[0:5]], tensor_to_objs(error_z[0:5])),
                       opts=dict(caption='errors ({})'.format(i)))

    if 'save' in args and i % args.save_every == 0:
        print('Saving parameters...')
        torch.save(air.state_dict(), args.save)
# Out:
# i=1, epochs=0.01, elapsed=0.00, elbo=-5980.85
# i=2, epochs=0.01, elapsed=0.00, elbo=-5974.87
# i=3, epochs=0.02, elapsed=0.00, elbo=-5910.69
# i=4, epochs=0.03, elapsed=0.00, elbo=-6041.07
# i=5, epochs=0.03, elapsed=0.00, elbo=-5935.86
# i=6, epochs=0.04, elapsed=0.00, elbo=-6002.75
# i=7, epochs=0.04, elapsed=0.00, elbo=-5948.34
# i=8, epochs=0.05, elapsed=0.00, elbo=-5942.32
# i=9, epochs=0.06, elapsed=0.00, elbo=-5992.71
# i=10, epochs=0.06, elapsed=0.00, elbo=-5939.23
# i=11, epochs=0.07, elapsed=0.00, elbo=-6000.89
# i=12, epochs=0.08, elapsed=0.00, elbo=-6030.49
# i=13, epochs=0.08, elapsed=0.00, elbo=-5895.71
# i=14, epochs=0.09, elapsed=0.00, elbo=-5973.95
# i=15, epochs=0.10, elapsed=0.00, elbo=-5972.18
# i=16, epochs=0.10, elapsed=0.00, elbo=-6014.98
# i=17, epochs=0.11, elapsed=0.00, elbo=-5929.12
# i=18, epochs=0.12, elapsed=0.01, elbo=-6042.53
# i=19, epochs=0.12, elapsed=0.01, elbo=-6003.73
# i=20, epochs=0.13, elapsed=0.01, elbo=-6025.98
# i=21, epochs=0.13, elapsed=0.01, elbo=-5999.86
# i=22, epochs=0.14, elapsed=0.01, elbo=-6073.99
# i=23, epochs=0.15, elapsed=0.01, elbo=-5975.09
# i=24, epochs=0.15, elapsed=0.01, elbo=-6017.50
# i=25, epochs=0.16, elapsed=0.01, elbo=-6026.19
# i=26, epochs=0.17, elapsed=0.01, elbo=-6004.04
# i=27, epochs=0.17, elapsed=0.01, elbo=-5943.28
# i=28, epochs=0.18, elapsed=0.01, elbo=-5970.11
# i=29, epochs=0.19, elapsed=0.01, elbo=-6040.94
# i=30, epochs=0.19, elapsed=0.01, elbo=-5985.16
# i=31, epochs=0.20, elapsed=0.01, elbo=-5997.54
# i=32, epochs=0.20, elapsed=0.01, elbo=-6026.26
# i=33, epochs=0.21, elapsed=0.01, elbo=-6027.90
# i=34, epochs=0.22, elapsed=0.01, elbo=-6069.17
# i=35, epochs=0.22, elapsed=0.01, elbo=-6090.63
# i=36, epochs=0.23, elapsed=0.01, elbo=-5992.24
# i=37, epochs=0.24, elapsed=0.01, elbo=-6034.02
# i=38, epochs=0.24, elapsed=0.01, elbo=-6047.07
# i=39, epochs=0.25, elapsed=0.01, elbo=-5953.70
# i=40, epochs=0.26, elapsed=0.01, elbo=-6078.24
# i=41, epochs=0.26, elapsed=0.01, elbo=-6041.76
# i=42, epochs=0.27, elapsed=0.01, elbo=-6013.68
# i=43, epochs=0.28, elapsed=0.01, elbo=-5976.99
# i=44, epochs=0.28, elapsed=0.01, elbo=-6068.93
# i=45, epochs=0.29, elapsed=0.01, elbo=-5937.19
# i=46, epochs=0.29, elapsed=0.01, elbo=-6098.14
# i=47, epochs=0.30, elapsed=0.01, elbo=-5968.14
# i=48, epochs=0.31, elapsed=0.01, elbo=-6024.00
# i=49, epochs=0.31, elapsed=0.01, elbo=-6031.18
# i=50, epochs=0.32, elapsed=0.02, elbo=-6001.62
# i=51, epochs=0.33, elapsed=0.02, elbo=-6058.86
# i=52, epochs=0.33, elapsed=0.02, elbo=-6021.18
# i=53, epochs=0.34, elapsed=0.02, elbo=-6047.99
# i=54, epochs=0.35, elapsed=0.02, elbo=-6025.17
# i=55, epochs=0.35, elapsed=0.02, elbo=-6052.59
# i=56, epochs=0.36, elapsed=0.02, elbo=-6021.10
# i=57, epochs=0.36, elapsed=0.02, elbo=-6030.90
# i=58, epochs=0.37, elapsed=0.02, elbo=-5973.98
# i=59, epochs=0.38, elapsed=0.02, elbo=-6073.90
# i=60, epochs=0.38, elapsed=0.02, elbo=-6050.19
# i=61, epochs=0.39, elapsed=0.02, elbo=-6003.82
# i=62, epochs=0.40, elapsed=0.02, elbo=-6023.43
# i=63, epochs=0.40, elapsed=0.02, elbo=-6042.35
# i=64, epochs=0.41, elapsed=0.02, elbo=-6081.45
# i=65, epochs=0.42, elapsed=0.02, elbo=-6063.86
# i=66, epochs=0.42, elapsed=0.02, elbo=-6029.77
# i=67, epochs=0.43, elapsed=0.02, elbo=-5994.97
# i=68, epochs=0.44, elapsed=0.02, elbo=-6016.91
# i=69, epochs=0.44, elapsed=0.02, elbo=-6002.18
# i=70, epochs=0.45, elapsed=0.02, elbo=-6029.45
# i=71, epochs=0.45, elapsed=0.02, elbo=-6068.99
# i=72, epochs=0.46, elapsed=0.02, elbo=-6044.15
# i=73, epochs=0.47, elapsed=0.02, elbo=-6069.30
# i=74, epochs=0.47, elapsed=0.02, elbo=-6065.98
# i=75, epochs=0.48, elapsed=0.02, elbo=-6106.71
# i=76, epochs=0.49, elapsed=0.02, elbo=-6077.12
# i=77, epochs=0.49, elapsed=0.02, elbo=-6046.45
# i=78, epochs=0.50, elapsed=0.02, elbo=-6036.86
# i=79, epochs=0.51, elapsed=0.02, elbo=-6060.08
# i=80, epochs=0.51, elapsed=0.02, elbo=-6043.28
# i=81, epochs=0.52, elapsed=0.02, elbo=-6060.52
# i=82, epochs=0.52, elapsed=0.02, elbo=-6007.18
# i=83, epochs=0.53, elapsed=0.02, elbo=-6074.81
# i=84, epochs=0.54, elapsed=0.02, elbo=-6033.91
# i=85, epochs=0.54, elapsed=0.03, elbo=-6037.64
# i=86, epochs=0.55, elapsed=0.03, elbo=-5967.37
# i=87, epochs=0.56, elapsed=0.03, elbo=-6045.51
# i=88, epochs=0.56, elapsed=0.03, elbo=-6063.33
# i=89, epochs=0.57, elapsed=0.03, elbo=-6040.51
# i=90, epochs=0.58, elapsed=0.03, elbo=-6056.04
# i=91, epochs=0.58, elapsed=0.03, elbo=-6016.88
# i=92, epochs=0.59, elapsed=0.03, elbo=-6061.59
# i=93, epochs=0.60, elapsed=0.03, elbo=-6069.75
# i=94, epochs=0.60, elapsed=0.03, elbo=-6066.82
# i=95, epochs=0.61, elapsed=0.03, elbo=-6116.16
# i=96, epochs=0.61, elapsed=0.03, elbo=-6017.56
# i=97, epochs=0.62, elapsed=0.03, elbo=-6085.62
# i=98, epochs=0.63, elapsed=0.03, elbo=-6060.75
# i=99, epochs=0.63, elapsed=0.03, elbo=-5991.87
# i=100, epochs=0.64, elapsed=0.03, elbo=-6050.22
# Drawing
# i=101, epochs=0.65, elapsed=0.03, elbo=-6060.87
# i=102, epochs=0.65, elapsed=0.03, elbo=-6046.91
# i=103, epochs=0.66, elapsed=0.03, elbo=-6048.93
# i=104, epochs=0.67, elapsed=0.03, elbo=-6046.62
# i=105, epochs=0.67, elapsed=0.03, elbo=-6075.16
# i=106, epochs=0.68, elapsed=0.03, elbo=-6063.78
# i=107, epochs=0.68, elapsed=0.03, elbo=-6065.29
# i=108, epochs=0.69, elapsed=0.03, elbo=-6060.09
# i=109, epochs=0.70, elapsed=0.03, elbo=-6071.45
# i=110, epochs=0.70, elapsed=0.03, elbo=-5990.65
# i=111, epochs=0.71, elapsed=0.03, elbo=-6035.50
# i=112, epochs=0.72, elapsed=0.03, elbo=-6036.54
# i=113, epochs=0.72, elapsed=0.03, elbo=-6068.27
# i=114, epochs=0.73, elapsed=0.03, elbo=-6067.21
# i=115, epochs=0.74, elapsed=0.03, elbo=-6074.83
# i=116, epochs=0.74, elapsed=0.03, elbo=-6049.85
# i=117, epochs=0.75, elapsed=0.03, elbo=-6080.21
# i=118, epochs=0.76, elapsed=0.03, elbo=-6131.05
# i=119, epochs=0.76, elapsed=0.04, elbo=-6042.74
# i=120, epochs=0.77, elapsed=0.04, elbo=-6068.81
# i=121, epochs=0.77, elapsed=0.04, elbo=-6094.70
# i=122, epochs=0.78, elapsed=0.04, elbo=-6023.38
# i=123, epochs=0.79, elapsed=0.04, elbo=-6130.22
# i=124, epochs=0.79, elapsed=0.04, elbo=-6035.47
# i=125, epochs=0.80, elapsed=0.04, elbo=-5985.85
# i=126, epochs=0.81, elapsed=0.04, elbo=-6032.01
# i=127, epochs=0.81, elapsed=0.04, elbo=-6081.37
# i=128, epochs=0.82, elapsed=0.04, elbo=-6007.77
# i=129, epochs=0.83, elapsed=0.04, elbo=-6036.51
# i=130, epochs=0.83, elapsed=0.04, elbo=-6050.91
# i=131, epochs=0.84, elapsed=0.04, elbo=-6090.11
# i=132, epochs=0.84, elapsed=0.04, elbo=-6032.11
# i=133, epochs=0.85, elapsed=0.04, elbo=-6066.03
# i=134, epochs=0.86, elapsed=0.04, elbo=-6069.35
# i=135, epochs=0.86, elapsed=0.04, elbo=-6031.96
# i=136, epochs=0.87, elapsed=0.04, elbo=-6077.24
# i=137, epochs=0.88, elapsed=0.04, elbo=-6108.70
# i=138, epochs=0.88, elapsed=0.04, elbo=-6021.71
# i=139, epochs=0.89, elapsed=0.04, elbo=-6056.10
# i=140, epochs=0.90, elapsed=0.04, elbo=-6060.16
# i=141, epochs=0.90, elapsed=0.04, elbo=-6111.13
# i=142, epochs=0.91, elapsed=0.04, elbo=-6041.57
# i=143, epochs=0.92, elapsed=0.04, elbo=-6050.72
# i=144, epochs=0.92, elapsed=0.04, elbo=-6003.44
# i=145, epochs=0.93, elapsed=0.04, elbo=-6075.65
# i=146, epochs=0.93, elapsed=0.04, elbo=-6085.42
# i=147, epochs=0.94, elapsed=0.04, elbo=-6099.14
# i=148, epochs=0.95, elapsed=0.04, elbo=-6048.62
# i=149, epochs=0.95, elapsed=0.04, elbo=-6035.38
# i=150, epochs=0.96, elapsed=0.04, elbo=-6065.18
# i=151, epochs=0.97, elapsed=0.04, elbo=-6044.54
# i=152, epochs=0.97, elapsed=0.04, elbo=-6034.68
# i=153, epochs=0.98, elapsed=0.05, elbo=-6096.00
# i=154, epochs=0.99, elapsed=0.05, elbo=-6081.35
# i=155, epochs=0.99, elapsed=0.05, elbo=-6011.99
# i=156, epochs=1.00, elapsed=0.05, elbo=-6073.33
# i=157, epochs=1.00, elapsed=0.05, elbo=-6053.82
# i=158, epochs=1.01, elapsed=0.05, elbo=-6072.95
# i=159, epochs=1.02, elapsed=0.05, elbo=-6037.51
# i=160, epochs=1.02, elapsed=0.05, elbo=-6137.81
# i=161, epochs=1.03, elapsed=0.05, elbo=-6083.07
# i=162, epochs=1.04, elapsed=0.05, elbo=-6085.10
# i=163, epochs=1.04, elapsed=0.05, elbo=-5992.64
# i=164, epochs=1.05, elapsed=0.05, elbo=-6082.54
# i=165, epochs=1.06, elapsed=0.05, elbo=-6101.64
# i=166, epochs=1.06, elapsed=0.05, elbo=-6030.44
# i=167, epochs=1.07, elapsed=0.05, elbo=-6058.65
# i=168, epochs=1.08, elapsed=0.05, elbo=-6080.54
# i=169, epochs=1.08, elapsed=0.05, elbo=-6048.05
# i=170, epochs=1.09, elapsed=0.05, elbo=-6054.15
# i=171, epochs=1.09, elapsed=0.05, elbo=-6015.17
# i=172, epochs=1.10, elapsed=0.05, elbo=-6065.34
# i=173, epochs=1.11, elapsed=0.05, elbo=-6064.81
# i=174, epochs=1.11, elapsed=0.05, elbo=-6075.88
# i=175, epochs=1.12, elapsed=0.05, elbo=-6096.17
# i=176, epochs=1.13, elapsed=0.05, elbo=-6090.50
# i=177, epochs=1.13, elapsed=0.05, elbo=-6086.23
# i=178, epochs=1.14, elapsed=0.05, elbo=-6055.39
# i=179, epochs=1.15, elapsed=0.05, elbo=-6107.24
# i=180, epochs=1.15, elapsed=0.05, elbo=-6052.59
# i=181, epochs=1.16, elapsed=0.05, elbo=-6045.95
# i=182, epochs=1.16, elapsed=0.05, elbo=-6068.63
# i=183, epochs=1.17, elapsed=0.05, elbo=-6103.47
# i=184, epochs=1.18, elapsed=0.05, elbo=-6006.92
# i=185, epochs=1.18, elapsed=0.05, elbo=-6084.17
# i=186, epochs=1.19, elapsed=0.05, elbo=-6067.16
# i=187, epochs=1.20, elapsed=0.06, elbo=-6040.41
# i=188, epochs=1.20, elapsed=0.06, elbo=-6049.00
# i=189, epochs=1.21, elapsed=0.06, elbo=-6116.11
# i=190, epochs=1.22, elapsed=0.06, elbo=-6095.85
# i=191, epochs=1.22, elapsed=0.06, elbo=-6087.33
# i=192, epochs=1.23, elapsed=0.06, elbo=-6054.59
# i=193, epochs=1.24, elapsed=0.06, elbo=-6062.66
# i=194, epochs=1.24, elapsed=0.06, elbo=-6068.98
# i=195, epochs=1.25, elapsed=0.06, elbo=-6027.98
# i=196, epochs=1.25, elapsed=0.06, elbo=-5996.53
# i=197, epochs=1.26, elapsed=0.06, elbo=-6072.97
# i=198, epochs=1.27, elapsed=0.06, elbo=-6073.20
# i=199, epochs=1.27, elapsed=0.06, elbo=-6041.45
# i=200, epochs=1.28, elapsed=0.06, elbo=-6117.04
# Drawing
# i=201, epochs=1.29, elapsed=0.06, elbo=-6073.09
# i=202, epochs=1.29, elapsed=0.06, elbo=-6055.29
# i=203, epochs=1.30, elapsed=0.06, elbo=-6082.56
# i=204, epochs=1.31, elapsed=0.06, elbo=-6080.37
# i=205, epochs=1.31, elapsed=0.06, elbo=-6013.19
# i=206, epochs=1.32, elapsed=0.06, elbo=-6044.13
# i=207, epochs=1.32, elapsed=0.06, elbo=-6093.44
# i=208, epochs=1.33, elapsed=0.06, elbo=-6078.48
# i=209, epochs=1.34, elapsed=0.06, elbo=-6055.77
# i=210, epochs=1.34, elapsed=0.06, elbo=-6038.71
# i=211, epochs=1.35, elapsed=0.06, elbo=-6083.82
# i=212, epochs=1.36, elapsed=0.06, elbo=-6045.59
# i=213, epochs=1.36, elapsed=0.06, elbo=-6110.00
# i=214, epochs=1.37, elapsed=0.06, elbo=-6126.80
# i=215, epochs=1.38, elapsed=0.06, elbo=-6109.11
# i=216, epochs=1.38, elapsed=0.06, elbo=-6029.98
# i=217, epochs=1.39, elapsed=0.06, elbo=-6068.04
# i=218, epochs=1.40, elapsed=0.06, elbo=-6074.64
# i=219, epochs=1.40, elapsed=0.06, elbo=-6066.62
# i=220, epochs=1.41, elapsed=0.06, elbo=-6072.00
# i=221, epochs=1.41, elapsed=0.07, elbo=-6016.10
# i=222, epochs=1.42, elapsed=0.07, elbo=-6127.40
# i=223, epochs=1.43, elapsed=0.07, elbo=-6123.14
# i=224, epochs=1.43, elapsed=0.07, elbo=-6078.11
# i=225, epochs=1.44, elapsed=0.07, elbo=-6139.64
# i=226, epochs=1.45, elapsed=0.07, elbo=-6113.90
# i=227, epochs=1.45, elapsed=0.07, elbo=-6045.44
# i=228, epochs=1.46, elapsed=0.07, elbo=-6057.17
# i=229, epochs=1.47, elapsed=0.07, elbo=-6093.17
# i=230, epochs=1.47, elapsed=0.07, elbo=-6085.53
# i=231, epochs=1.48, elapsed=0.07, elbo=-6084.59
# i=232, epochs=1.48, elapsed=0.07, elbo=-6111.79
# i=233, epochs=1.49, elapsed=0.07, elbo=-6082.10
# i=234, epochs=1.50, elapsed=0.07, elbo=-6061.08
# i=235, epochs=1.50, elapsed=0.07, elbo=-6055.83
# i=236, epochs=1.51, elapsed=0.07, elbo=-6066.48
# i=237, epochs=1.52, elapsed=0.07, elbo=-6063.27
# i=238, epochs=1.52, elapsed=0.07, elbo=-6056.85
# i=239, epochs=1.53, elapsed=0.07, elbo=-6097.57
# i=240, epochs=1.54, elapsed=0.07, elbo=-6083.30
# i=241, epochs=1.54, elapsed=0.07, elbo=-6052.90
# i=242, epochs=1.55, elapsed=0.07, elbo=-6081.94
# i=243, epochs=1.56, elapsed=0.07, elbo=-6040.48
# i=244, epochs=1.56, elapsed=0.07, elbo=-6107.65
# i=245, epochs=1.57, elapsed=0.07, elbo=-6133.57
# i=246, epochs=1.57, elapsed=0.07, elbo=-6030.49
# i=247, epochs=1.58, elapsed=0.07, elbo=-6049.34
# i=248, epochs=1.59, elapsed=0.07, elbo=-6085.26
# i=249, epochs=1.59, elapsed=0.07, elbo=-6080.72
# i=250, epochs=1.60, elapsed=0.07, elbo=-6094.22
# i=251, epochs=1.61, elapsed=0.07, elbo=-6110.45
# i=252, epochs=1.61, elapsed=0.07, elbo=-6083.29
# i=253, epochs=1.62, elapsed=0.07, elbo=-6093.10
# i=254, epochs=1.63, elapsed=0.07, elbo=-6064.66
# i=255, epochs=1.63, elapsed=0.08, elbo=-6021.48
# i=256, epochs=1.64, elapsed=0.08, elbo=-6070.57
# i=257, epochs=1.64, elapsed=0.08, elbo=-6061.24
# i=258, epochs=1.65, elapsed=0.08, elbo=-6078.55
# i=259, epochs=1.66, elapsed=0.08, elbo=-6088.11
# i=260, epochs=1.66, elapsed=0.08, elbo=-6103.41
# i=261, epochs=1.67, elapsed=0.08, elbo=-6131.83
# i=262, epochs=1.68, elapsed=0.08, elbo=-6063.41
# i=263, epochs=1.68, elapsed=0.08, elbo=-6130.61
# i=264, epochs=1.69, elapsed=0.08, elbo=-6064.47
# i=265, epochs=1.70, elapsed=0.08, elbo=-6111.22
# i=266, epochs=1.70, elapsed=0.08, elbo=-5995.33
# i=267, epochs=1.71, elapsed=0.08, elbo=-6036.23
# i=268, epochs=1.72, elapsed=0.08, elbo=-6088.12
# i=269, epochs=1.72, elapsed=0.08, elbo=-6093.18
# i=270, epochs=1.73, elapsed=0.08, elbo=-6045.32
# i=271, epochs=1.73, elapsed=0.08, elbo=-6086.14
# i=272, epochs=1.74, elapsed=0.08, elbo=-6033.05
# i=273, epochs=1.75, elapsed=0.08, elbo=-6070.41
# i=274, epochs=1.75, elapsed=0.08, elbo=-6062.43
# i=275, epochs=1.76, elapsed=0.08, elbo=-6083.81
# i=276, epochs=1.77, elapsed=0.08, elbo=-6111.19
# i=277, epochs=1.77, elapsed=0.08, elbo=-6165.73
# i=278, epochs=1.78, elapsed=0.08, elbo=-6047.90
# i=279, epochs=1.79, elapsed=0.08, elbo=-6072.68
# i=280, epochs=1.79, elapsed=0.08, elbo=-6108.24
# i=281, epochs=1.80, elapsed=0.08, elbo=-6041.63
# i=282, epochs=1.80, elapsed=0.08, elbo=-6045.46
# i=283, epochs=1.81, elapsed=0.08, elbo=-6109.50
# i=284, epochs=1.82, elapsed=0.08, elbo=-6081.40
# i=285, epochs=1.82, elapsed=0.08, elbo=-6128.00
# i=286, epochs=1.83, elapsed=0.08, elbo=-6096.00
# i=287, epochs=1.84, elapsed=0.08, elbo=-6092.88
# i=288, epochs=1.84, elapsed=0.08, elbo=-6091.31
# i=289, epochs=1.85, elapsed=0.09, elbo=-6120.16
# i=290, epochs=1.86, elapsed=0.09, elbo=-6056.85
# i=291, epochs=1.86, elapsed=0.09, elbo=-6052.94
# i=292, epochs=1.87, elapsed=0.09, elbo=-6089.68
# i=293, epochs=1.88, elapsed=0.09, elbo=-6108.77
# i=294, epochs=1.88, elapsed=0.09, elbo=-6104.48
# i=295, epochs=1.89, elapsed=0.09, elbo=-6102.33
# i=296, epochs=1.89, elapsed=0.09, elbo=-6074.58
# i=297, epochs=1.90, elapsed=0.09, elbo=-6017.50
# i=298, epochs=1.91, elapsed=0.09, elbo=-6083.26
# i=299, epochs=1.91, elapsed=0.09, elbo=-6041.73
# i=300, epochs=1.92, elapsed=0.09, elbo=-6045.96
# Drawing
# i=301, epochs=1.93, elapsed=0.09, elbo=-6043.85
# i=302, epochs=1.93, elapsed=0.09, elbo=-6025.37
# i=303, epochs=1.94, elapsed=0.09, elbo=-6070.50
# i=304, epochs=1.95, elapsed=0.09, elbo=-6076.05
# i=305, epochs=1.95, elapsed=0.09, elbo=-6055.83
# i=306, epochs=1.96, elapsed=0.09, elbo=-6015.13
# i=307, epochs=1.96, elapsed=0.09, elbo=-6030.77
# i=308, epochs=1.97, elapsed=0.09, elbo=-6103.78
# i=309, epochs=1.98, elapsed=0.09, elbo=-6117.03
# i=310, epochs=1.98, elapsed=0.09, elbo=-6064.82
# i=311, epochs=1.99, elapsed=0.09, elbo=-6064.83
# i=312, epochs=2.00, elapsed=0.09, elbo=-6072.71
# i=313, epochs=2.00, elapsed=0.09, elbo=-6157.78
# i=314, epochs=2.01, elapsed=0.09, elbo=-6059.74
# i=315, epochs=2.02, elapsed=0.09, elbo=-6079.96
# i=316, epochs=2.02, elapsed=0.09, elbo=-6045.78
# i=317, epochs=2.03, elapsed=0.09, elbo=-6078.69
# i=318, epochs=2.04, elapsed=0.09, elbo=-6068.87
# i=319, epochs=2.04, elapsed=0.09, elbo=-6043.10
# i=320, epochs=2.05, elapsed=0.09, elbo=-6100.00
# i=321, epochs=2.05, elapsed=0.09, elbo=-6065.92
# i=322, epochs=2.06, elapsed=0.10, elbo=-6044.48
# i=323, epochs=2.07, elapsed=0.10, elbo=-6109.67
# i=324, epochs=2.07, elapsed=0.10, elbo=-6071.78
# i=325, epochs=2.08, elapsed=0.10, elbo=-6097.93
# i=326, epochs=2.09, elapsed=0.10, elbo=-6101.38
# i=327, epochs=2.09, elapsed=0.10, elbo=-6063.50
# i=328, epochs=2.10, elapsed=0.10, elbo=-6105.62
# i=329, epochs=2.11, elapsed=0.10, elbo=-6084.22
# i=330, epochs=2.11, elapsed=0.10, elbo=-6061.78
# i=331, epochs=2.12, elapsed=0.10, elbo=-6091.50
# i=332, epochs=2.12, elapsed=0.10, elbo=-6107.34
# i=333, epochs=2.13, elapsed=0.10, elbo=-6120.60
# i=334, epochs=2.14, elapsed=0.10, elbo=-6037.39
# i=335, epochs=2.14, elapsed=0.10, elbo=-6074.28
# i=336, epochs=2.15, elapsed=0.10, elbo=-6121.62
# i=337, epochs=2.16, elapsed=0.10, elbo=-6089.12
# i=338, epochs=2.16, elapsed=0.10, elbo=-6083.87
# i=339, epochs=2.17, elapsed=0.10, elbo=-6093.78
# i=340, epochs=2.18, elapsed=0.10, elbo=-6064.00
# i=341, epochs=2.18, elapsed=0.10, elbo=-6081.09
# i=342, epochs=2.19, elapsed=0.10, elbo=-6053.59
# i=343, epochs=2.20, elapsed=0.10, elbo=-6075.42
# i=344, epochs=2.20, elapsed=0.10, elbo=-6042.91
# i=345, epochs=2.21, elapsed=0.10, elbo=-6048.24
# i=346, epochs=2.21, elapsed=0.10, elbo=-6083.41
# i=347, epochs=2.22, elapsed=0.10, elbo=-6104.36
# i=348, epochs=2.23, elapsed=0.10, elbo=-6064.01
# i=349, epochs=2.23, elapsed=0.10, elbo=-6112.11
# i=350, epochs=2.24, elapsed=0.10, elbo=-6058.60
# i=351, epochs=2.25, elapsed=0.10, elbo=-6072.73
# i=352, epochs=2.25, elapsed=0.10, elbo=-6040.37
# i=353, epochs=2.26, elapsed=0.10, elbo=-6077.85
# i=354, epochs=2.27, elapsed=0.10, elbo=-6092.15
# i=355, epochs=2.27, elapsed=0.10, elbo=-6060.84
# i=356, epochs=2.28, elapsed=0.11, elbo=-6072.59
# i=357, epochs=2.28, elapsed=0.11, elbo=-6040.69
# i=358, epochs=2.29, elapsed=0.11, elbo=-6072.01
# i=359, epochs=2.30, elapsed=0.11, elbo=-6118.56
# i=360, epochs=2.30, elapsed=0.11, elbo=-5997.87
# i=361, epochs=2.31, elapsed=0.11, elbo=-6109.18
# i=362, epochs=2.32, elapsed=0.11, elbo=-6154.90
# i=363, epochs=2.32, elapsed=0.11, elbo=-6098.61
# i=364, epochs=2.33, elapsed=0.11, elbo=-6036.82
# i=365, epochs=2.34, elapsed=0.11, elbo=-6115.78
# i=366, epochs=2.34, elapsed=0.11, elbo=-6118.30
# i=367, epochs=2.35, elapsed=0.11, elbo=-6125.08
# i=368, epochs=2.36, elapsed=0.11, elbo=-6151.11
# i=369, epochs=2.36, elapsed=0.11, elbo=-6088.82
# i=370, epochs=2.37, elapsed=0.11, elbo=-6125.28
# i=371, epochs=2.37, elapsed=0.11, elbo=-6093.58
# i=372, epochs=2.38, elapsed=0.11, elbo=-6106.43
# i=373, epochs=2.39, elapsed=0.11, elbo=-6081.34
# i=374, epochs=2.39, elapsed=0.11, elbo=-6115.28
# i=375, epochs=2.40, elapsed=0.11, elbo=-6079.94
# i=376, epochs=2.41, elapsed=0.11, elbo=-6071.77
# i=377, epochs=2.41, elapsed=0.11, elbo=-6090.81
# i=378, epochs=2.42, elapsed=0.11, elbo=-6104.31
# i=379, epochs=2.43, elapsed=0.11, elbo=-6055.82
# i=380, epochs=2.43, elapsed=0.11, elbo=-6052.08
# i=381, epochs=2.44, elapsed=0.11, elbo=-6120.81
# i=382, epochs=2.44, elapsed=0.11, elbo=-6039.55
# i=383, epochs=2.45, elapsed=0.11, elbo=-6057.24
# i=384, epochs=2.46, elapsed=0.11, elbo=-6077.37
# i=385, epochs=2.46, elapsed=0.11, elbo=-6050.67
# i=386, epochs=2.47, elapsed=0.11, elbo=-6051.52
# i=387, epochs=2.48, elapsed=0.11, elbo=-6059.46
# i=388, epochs=2.48, elapsed=0.11, elbo=-6034.98
# i=389, epochs=2.49, elapsed=0.11, elbo=-6065.44
# i=390, epochs=2.50, elapsed=0.12, elbo=-6069.12
# i=391, epochs=2.50, elapsed=0.12, elbo=-6074.09
# i=392, epochs=2.51, elapsed=0.12, elbo=-6068.77
# i=393, epochs=2.52, elapsed=0.12, elbo=-6110.84
# i=394, epochs=2.52, elapsed=0.12, elbo=-6093.28
# i=395, epochs=2.53, elapsed=0.12, elbo=-6114.91
# i=396, epochs=2.53, elapsed=0.12, elbo=-6049.96
# i=397, epochs=2.54, elapsed=0.12, elbo=-6095.50
# i=398, epochs=2.55, elapsed=0.12, elbo=-6083.32
# i=399, epochs=2.55, elapsed=0.12, elbo=-6086.42
# i=400, epochs=2.56, elapsed=0.12, elbo=-6065.95
# Drawing
# i=401, epochs=2.57, elapsed=0.12, elbo=-6087.87
# i=402, epochs=2.57, elapsed=0.12, elbo=-6099.74
# i=403, epochs=2.58, elapsed=0.12, elbo=-6102.93
# i=404, epochs=2.59, elapsed=0.12, elbo=-6028.81
# i=405, epochs=2.59, elapsed=0.12, elbo=-6051.82
# i=406, epochs=2.60, elapsed=0.12, elbo=-6084.63
# i=407, epochs=2.60, elapsed=0.12, elbo=-6150.83
# i=408, epochs=2.61, elapsed=0.12, elbo=-6130.32
# i=409, epochs=2.62, elapsed=0.12, elbo=-6137.79
# i=410, epochs=2.62, elapsed=0.12, elbo=-6073.82
# i=411, epochs=2.63, elapsed=0.12, elbo=-6086.37
# i=412, epochs=2.64, elapsed=0.12, elbo=-6116.46
# i=413, epochs=2.64, elapsed=0.12, elbo=-6079.33
# i=414, epochs=2.65, elapsed=0.12, elbo=-6109.85
# i=415, epochs=2.66, elapsed=0.12, elbo=-6053.23
# i=416, epochs=2.66, elapsed=0.12, elbo=-6032.92
# i=417, epochs=2.67, elapsed=0.12, elbo=-6145.49
# i=418, epochs=2.68, elapsed=0.12, elbo=-6068.83
# i=419, epochs=2.68, elapsed=0.12, elbo=-6088.21
# i=420, epochs=2.69, elapsed=0.12, elbo=-6095.76
# i=421, epochs=2.69, elapsed=0.12, elbo=-6140.40
# i=422, epochs=2.70, elapsed=0.12, elbo=-6064.21
# i=423, epochs=2.71, elapsed=0.13, elbo=-6103.48
# i=424, epochs=2.71, elapsed=0.13, elbo=-6065.65
# i=425, epochs=2.72, elapsed=0.13, elbo=-6092.86
# i=426, epochs=2.73, elapsed=0.13, elbo=-6062.90
# i=427, epochs=2.73, elapsed=0.13, elbo=-6143.59
# i=428, epochs=2.74, elapsed=0.13, elbo=-6133.68
# i=429, epochs=2.75, elapsed=0.13, elbo=-6101.60
# i=430, epochs=2.75, elapsed=0.13, elbo=-6106.57
# i=431, epochs=2.76, elapsed=0.13, elbo=-6062.68
# i=432, epochs=2.76, elapsed=0.13, elbo=-6039.87
# i=433, epochs=2.77, elapsed=0.13, elbo=-6112.36
# i=434, epochs=2.78, elapsed=0.13, elbo=-6087.57
# i=435, epochs=2.78, elapsed=0.13, elbo=-6094.27
# i=436, epochs=2.79, elapsed=0.13, elbo=-6171.33
# i=437, epochs=2.80, elapsed=0.13, elbo=-6081.87
# i=438, epochs=2.80, elapsed=0.13, elbo=-6053.71
# i=439, epochs=2.81, elapsed=0.13, elbo=-6071.92
# i=440, epochs=2.82, elapsed=0.13, elbo=-6094.77
# i=441, epochs=2.82, elapsed=0.13, elbo=-6061.33
# i=442, epochs=2.83, elapsed=0.13, elbo=-6110.94
# i=443, epochs=2.84, elapsed=0.13, elbo=-6095.39
# i=444, epochs=2.84, elapsed=0.13, elbo=-6066.68
# i=445, epochs=2.85, elapsed=0.13, elbo=-6106.59
# i=446, epochs=2.85, elapsed=0.13, elbo=-6089.26
# i=447, epochs=2.86, elapsed=0.13, elbo=-6063.18
# i=448, epochs=2.87, elapsed=0.13, elbo=-6028.81
# i=449, epochs=2.87, elapsed=0.13, elbo=-6079.22
# i=450, epochs=2.88, elapsed=0.13, elbo=-6101.68
# i=451, epochs=2.89, elapsed=0.13, elbo=-6105.49
# i=452, epochs=2.89, elapsed=0.13, elbo=-6084.69
# i=453, epochs=2.90, elapsed=0.13, elbo=-6133.94
# i=454, epochs=2.91, elapsed=0.13, elbo=-6051.84
# i=455, epochs=2.91, elapsed=0.13, elbo=-6092.57
# i=456, epochs=2.92, elapsed=0.13, elbo=-6092.68
# i=457, epochs=2.92, elapsed=0.14, elbo=-6095.54
# i=458, epochs=2.93, elapsed=0.14, elbo=-6111.34
# i=459, epochs=2.94, elapsed=0.14, elbo=-6117.28
# i=460, epochs=2.94, elapsed=0.14, elbo=-6041.93
# i=461, epochs=2.95, elapsed=0.14, elbo=-6040.47
# i=462, epochs=2.96, elapsed=0.14, elbo=-6098.65
# i=463, epochs=2.96, elapsed=0.14, elbo=-6043.25
# i=464, epochs=2.97, elapsed=0.14, elbo=-6069.52
# i=465, epochs=2.98, elapsed=0.14, elbo=-6048.40
# i=466, epochs=2.98, elapsed=0.14, elbo=-6059.38
# i=467, epochs=2.99, elapsed=0.14, elbo=-6124.83
# i=468, epochs=3.00, elapsed=0.14, elbo=-6073.71
# i=469, epochs=3.00, elapsed=0.14, elbo=-6081.30
# i=470, epochs=3.01, elapsed=0.14, elbo=-6103.36
# i=471, epochs=3.01, elapsed=0.14, elbo=-6064.47
# i=472, epochs=3.02, elapsed=0.14, elbo=-6130.07
# i=473, epochs=3.03, elapsed=0.14, elbo=-6117.13
# i=474, epochs=3.03, elapsed=0.14, elbo=-6122.59
# i=475, epochs=3.04, elapsed=0.14, elbo=-6091.62
# i=476, epochs=3.05, elapsed=0.14, elbo=-6076.28
# i=477, epochs=3.05, elapsed=0.14, elbo=-6114.80
# i=478, epochs=3.06, elapsed=0.14, elbo=-6085.79
# i=479, epochs=3.07, elapsed=0.14, elbo=-6086.99
# i=480, epochs=3.07, elapsed=0.14, elbo=-6007.86
# i=481, epochs=3.08, elapsed=0.14, elbo=-6081.02
# i=482, epochs=3.08, elapsed=0.14, elbo=-6074.24
# i=483, epochs=3.09, elapsed=0.14, elbo=-6064.46
# i=484, epochs=3.10, elapsed=0.14, elbo=-6126.80
# i=485, epochs=3.10, elapsed=0.14, elbo=-6116.96
# i=486, epochs=3.11, elapsed=0.14, elbo=-6062.33
# i=487, epochs=3.12, elapsed=0.14, elbo=-6060.69
# i=488, epochs=3.12, elapsed=0.14, elbo=-6089.05
# i=489, epochs=3.13, elapsed=0.15, elbo=-6091.72
# i=490, epochs=3.14, elapsed=0.15, elbo=-6051.73
# i=491, epochs=3.14, elapsed=0.15, elbo=-6058.46
# i=492, epochs=3.15, elapsed=0.15, elbo=-6073.26
# i=493, epochs=3.16, elapsed=0.15, elbo=-6103.56
# i=494, epochs=3.16, elapsed=0.15, elbo=-6061.02
# i=495, epochs=3.17, elapsed=0.15, elbo=-6042.47
# i=496, epochs=3.17, elapsed=0.15, elbo=-6056.61
# i=497, epochs=3.18, elapsed=0.15, elbo=-6114.53
# i=498, epochs=3.19, elapsed=0.15, elbo=-6080.61
# i=499, epochs=3.19, elapsed=0.15, elbo=-6073.67
# i=500, epochs=3.20, elapsed=0.15, elbo=-6121.42
# Drawing
# i=501, epochs=3.21, elapsed=0.15, elbo=-6080.66
# i=502, epochs=3.21, elapsed=0.15, elbo=-6071.10
# i=503, epochs=3.22, elapsed=0.15, elbo=-6071.30
# i=504, epochs=3.23, elapsed=0.15, elbo=-6117.56
# i=505, epochs=3.23, elapsed=0.15, elbo=-6081.85
# i=506, epochs=3.24, elapsed=0.15, elbo=-6073.13
# i=507, epochs=3.24, elapsed=0.15, elbo=-6117.07
# i=508, epochs=3.25, elapsed=0.15, elbo=-6092.39
# i=509, epochs=3.26, elapsed=0.15, elbo=-6105.45
# i=510, epochs=3.26, elapsed=0.15, elbo=-6037.50
# i=511, epochs=3.27, elapsed=0.15, elbo=-6061.42
# i=512, epochs=3.28, elapsed=0.15, elbo=-6099.30
# i=513, epochs=3.28, elapsed=0.15, elbo=-6059.14
# i=514, epochs=3.29, elapsed=0.15, elbo=-6083.06
# i=515, epochs=3.30, elapsed=0.15, elbo=-6105.53
# i=516, epochs=3.30, elapsed=0.15, elbo=-6117.89
# i=517, epochs=3.31, elapsed=0.15, elbo=-6104.64
# i=518, epochs=3.32, elapsed=0.15, elbo=-6068.47
# i=519, epochs=3.32, elapsed=0.15, elbo=-6109.25
# i=520, epochs=3.33, elapsed=0.15, elbo=-6111.25
# i=521, epochs=3.33, elapsed=0.16, elbo=-6038.84
# i=522, epochs=3.34, elapsed=0.16, elbo=-6065.47
# i=523, epochs=3.35, elapsed=0.16, elbo=-6049.77
# i=524, epochs=3.35, elapsed=0.16, elbo=-6119.18
# i=525, epochs=3.36, elapsed=0.16, elbo=-6110.65
# i=526, epochs=3.37, elapsed=0.16, elbo=-6149.15
# i=527, epochs=3.37, elapsed=0.16, elbo=-6063.76
# i=528, epochs=3.38, elapsed=0.16, elbo=-6020.06
# i=529, epochs=3.39, elapsed=0.16, elbo=-6079.76
# i=530, epochs=3.39, elapsed=0.16, elbo=-6098.23
# i=531, epochs=3.40, elapsed=0.16, elbo=-6137.51
# i=532, epochs=3.40, elapsed=0.16, elbo=-6151.36
# i=533, epochs=3.41, elapsed=0.16, elbo=-6122.17
# i=534, epochs=3.42, elapsed=0.16, elbo=-6054.50
# i=535, epochs=3.42, elapsed=0.16, elbo=-6048.66
# i=536, epochs=3.43, elapsed=0.16, elbo=-6141.70
# i=537, epochs=3.44, elapsed=0.16, elbo=-6094.57
# i=538, epochs=3.44, elapsed=0.16, elbo=-6039.54
# i=539, epochs=3.45, elapsed=0.16, elbo=-6124.66
# i=540, epochs=3.46, elapsed=0.16, elbo=-6103.54
# i=541, epochs=3.46, elapsed=0.16, elbo=-6081.99
# i=542, epochs=3.47, elapsed=0.16, elbo=-6110.05
# i=543, epochs=3.48, elapsed=0.16, elbo=-6113.64
# i=544, epochs=3.48, elapsed=0.16, elbo=-6086.72
# i=545, epochs=3.49, elapsed=0.16, elbo=-6123.61
# i=546, epochs=3.49, elapsed=0.16, elbo=-6023.09
# i=547, epochs=3.50, elapsed=0.16, elbo=-6086.64
# i=548, epochs=3.51, elapsed=0.16, elbo=-6083.63
# i=549, epochs=3.51, elapsed=0.17, elbo=-6067.79
# i=550, epochs=3.52, elapsed=0.17, elbo=-6165.83
# i=551, epochs=3.53, elapsed=0.17, elbo=-6096.71
# i=552, epochs=3.53, elapsed=0.17, elbo=-6119.13
# i=553, epochs=3.54, elapsed=0.17, elbo=-6155.47
# i=554, epochs=3.55, elapsed=0.17, elbo=-6123.69
# i=555, epochs=3.55, elapsed=0.17, elbo=-6019.76
# i=556, epochs=3.56, elapsed=0.17, elbo=-6105.69
# i=557, epochs=3.56, elapsed=0.17, elbo=-6052.93
# i=558, epochs=3.57, elapsed=0.17, elbo=-6134.42
# i=559, epochs=3.58, elapsed=0.17, elbo=-6152.13
# i=560, epochs=3.58, elapsed=0.17, elbo=-6074.61
# i=561, epochs=3.59, elapsed=0.17, elbo=-6087.57
# i=562, epochs=3.60, elapsed=0.17, elbo=-6108.66
# i=563, epochs=3.60, elapsed=0.17, elbo=-6146.20
# i=564, epochs=3.61, elapsed=0.17, elbo=-6078.74
# i=565, epochs=3.62, elapsed=0.17, elbo=-6131.29
# i=566, epochs=3.62, elapsed=0.17, elbo=-6070.98
# i=567, epochs=3.63, elapsed=0.17, elbo=-6146.04
# i=568, epochs=3.64, elapsed=0.17, elbo=-6085.68
# i=569, epochs=3.64, elapsed=0.17, elbo=-6077.04
# i=570, epochs=3.65, elapsed=0.17, elbo=-6119.31
# i=571, epochs=3.65, elapsed=0.17, elbo=-6075.19
# i=572, epochs=3.66, elapsed=0.17, elbo=-6099.47
# i=573, epochs=3.67, elapsed=0.17, elbo=-6093.30
# i=574, epochs=3.67, elapsed=0.17, elbo=-6047.52
# i=575, epochs=3.68, elapsed=0.17, elbo=-6047.84
# i=576, epochs=3.69, elapsed=0.18, elbo=-6120.13
# i=577, epochs=3.69, elapsed=0.18, elbo=-6081.97
# i=578, epochs=3.70, elapsed=0.18, elbo=-6117.21
# i=579, epochs=3.71, elapsed=0.18, elbo=-6047.77
# i=580, epochs=3.71, elapsed=0.18, elbo=-6122.71
# i=581, epochs=3.72, elapsed=0.18, elbo=-6120.97
# i=582, epochs=3.72, elapsed=0.18, elbo=-6068.93
# i=583, epochs=3.73, elapsed=0.18, elbo=-6125.85
# i=584, epochs=3.74, elapsed=0.18, elbo=-6008.82
# i=585, epochs=3.74, elapsed=0.18, elbo=-6065.28
# i=586, epochs=3.75, elapsed=0.18, elbo=-6078.33
# i=587, epochs=3.76, elapsed=0.18, elbo=-6082.45
# i=588, epochs=3.76, elapsed=0.18, elbo=-6089.45
# i=589, epochs=3.77, elapsed=0.18, elbo=-6102.16
# i=590, epochs=3.78, elapsed=0.18, elbo=-6106.10
# i=591, epochs=3.78, elapsed=0.18, elbo=-6113.84
# i=592, epochs=3.79, elapsed=0.18, elbo=-6079.24
# i=593, epochs=3.80, elapsed=0.18, elbo=-6101.68
# i=594, epochs=3.80, elapsed=0.18, elbo=-6096.18
# i=595, epochs=3.81, elapsed=0.18, elbo=-6099.02
# i=596, epochs=3.81, elapsed=0.18, elbo=-6113.80
# i=597, epochs=3.82, elapsed=0.18, elbo=-6071.70
# i=598, epochs=3.83, elapsed=0.18, elbo=-6150.75
# i=599, epochs=3.83, elapsed=0.18, elbo=-6084.02
# i=600, epochs=3.84, elapsed=0.18, elbo=-6084.39
# Drawing
# i=601, epochs=3.85, elapsed=0.18, elbo=-6087.46
# i=602, epochs=3.85, elapsed=0.18, elbo=-6113.73
# i=603, epochs=3.86, elapsed=0.18, elbo=-6143.40
# i=604, epochs=3.87, elapsed=0.19, elbo=-6125.24
# i=605, epochs=3.87, elapsed=0.19, elbo=-6123.27
# i=606, epochs=3.88, elapsed=0.19, elbo=-6102.04
# i=607, epochs=3.88, elapsed=0.19, elbo=-6070.58
# i=608, epochs=3.89, elapsed=0.19, elbo=-6092.73
# i=609, epochs=3.90, elapsed=0.19, elbo=-6086.96
# i=610, epochs=3.90, elapsed=0.19, elbo=-6061.26
# i=611, epochs=3.91, elapsed=0.19, elbo=-6127.19
# i=612, epochs=3.92, elapsed=0.19, elbo=-6132.25
# i=613, epochs=3.92, elapsed=0.19, elbo=-6109.81
# i=614, epochs=3.93, elapsed=0.19, elbo=-6112.60
# i=615, epochs=3.94, elapsed=0.19, elbo=-6082.74
# i=616, epochs=3.94, elapsed=0.19, elbo=-6059.19
# i=617, epochs=3.95, elapsed=0.19, elbo=-6141.38
# i=618, epochs=3.96, elapsed=0.19, elbo=-6123.88
# i=619, epochs=3.96, elapsed=0.19, elbo=-6086.36
# i=620, epochs=3.97, elapsed=0.19, elbo=-6112.86
# i=621, epochs=3.97, elapsed=0.19, elbo=-6129.66
# i=622, epochs=3.98, elapsed=0.19, elbo=-6066.24
# i=623, epochs=3.99, elapsed=0.19, elbo=-6104.54
# i=624, epochs=3.99, elapsed=0.19, elbo=-6083.24
# i=625, epochs=4.00, elapsed=0.19, elbo=-6079.19
# i=626, epochs=4.01, elapsed=0.19, elbo=-6101.23
# i=627, epochs=4.01, elapsed=0.19, elbo=-6120.65
# i=628, epochs=4.02, elapsed=0.19, elbo=-6147.29
# i=629, epochs=4.03, elapsed=0.19, elbo=-6089.35
# i=630, epochs=4.03, elapsed=0.19, elbo=-6132.67
# i=631, epochs=4.04, elapsed=0.20, elbo=-6154.61
# i=632, epochs=4.04, elapsed=0.20, elbo=-6046.50
# i=633, epochs=4.05, elapsed=0.20, elbo=-6086.95
# i=634, epochs=4.06, elapsed=0.20, elbo=-6056.81
# i=635, epochs=4.06, elapsed=0.20, elbo=-6112.14
# i=636, epochs=4.07, elapsed=0.20, elbo=-6148.49
# i=637, epochs=4.08, elapsed=0.20, elbo=-6096.84
# i=638, epochs=4.08, elapsed=0.20, elbo=-6069.86
# i=639, epochs=4.09, elapsed=0.20, elbo=-6067.14
# i=640, epochs=4.10, elapsed=0.20, elbo=-6083.16
# i=641, epochs=4.10, elapsed=0.20, elbo=-6076.90
# i=642, epochs=4.11, elapsed=0.20, elbo=-6158.05
# i=643, epochs=4.12, elapsed=0.20, elbo=-6095.77
# i=644, epochs=4.12, elapsed=0.20, elbo=-6111.65
# i=645, epochs=4.13, elapsed=0.20, elbo=-6147.94
# i=646, epochs=4.13, elapsed=0.20, elbo=-6113.74
# i=647, epochs=4.14, elapsed=0.20, elbo=-6049.04
# i=648, epochs=4.15, elapsed=0.20, elbo=-6062.85
# i=649, epochs=4.15, elapsed=0.20, elbo=-6051.33
# i=650, epochs=4.16, elapsed=0.20, elbo=-6063.15
# i=651, epochs=4.17, elapsed=0.20, elbo=-6083.85
# i=652, epochs=4.17, elapsed=0.20, elbo=-6148.20
# i=653, epochs=4.18, elapsed=0.20, elbo=-6106.33
# i=654, epochs=4.19, elapsed=0.20, elbo=-6081.95
# i=655, epochs=4.19, elapsed=0.20, elbo=-6053.75
# i=656, epochs=4.20, elapsed=0.20, elbo=-6069.46
# i=657, epochs=4.20, elapsed=0.20, elbo=-6053.11
# i=658, epochs=4.21, elapsed=0.20, elbo=-6109.55
# i=659, epochs=4.22, elapsed=0.20, elbo=-6053.25
# i=660, epochs=4.22, elapsed=0.21, elbo=-6111.93
# i=661, epochs=4.23, elapsed=0.21, elbo=-6084.74
# i=662, epochs=4.24, elapsed=0.21, elbo=-6056.87
# i=663, epochs=4.24, elapsed=0.21, elbo=-6084.12
# i=664, epochs=4.25, elapsed=0.21, elbo=-6108.98
# i=665, epochs=4.26, elapsed=0.21, elbo=-6123.36
# i=666, epochs=4.26, elapsed=0.21, elbo=-6039.50
# i=667, epochs=4.27, elapsed=0.21, elbo=-6117.16
# i=668, epochs=4.28, elapsed=0.21, elbo=-6035.56
# i=669, epochs=4.28, elapsed=0.21, elbo=-6122.59
# i=670, epochs=4.29, elapsed=0.21, elbo=-6055.08
# i=671, epochs=4.29, elapsed=0.21, elbo=-6093.90
# i=672, epochs=4.30, elapsed=0.21, elbo=-6121.07
# i=673, epochs=4.31, elapsed=0.21, elbo=-6093.19
# i=674, epochs=4.31, elapsed=0.21, elbo=-6014.28
# i=675, epochs=4.32, elapsed=0.21, elbo=-6086.06
# i=676, epochs=4.33, elapsed=0.21, elbo=-6141.72
# i=677, epochs=4.33, elapsed=0.21, elbo=-6112.80
# i=678, epochs=4.34, elapsed=0.21, elbo=-6062.52
# i=679, epochs=4.35, elapsed=0.21, elbo=-6053.21
# i=680, epochs=4.35, elapsed=0.21, elbo=-6127.97
# i=681, epochs=4.36, elapsed=0.21, elbo=-6024.68
# i=682, epochs=4.36, elapsed=0.21, elbo=-6040.11
# i=683, epochs=4.37, elapsed=0.21, elbo=-6059.48
# i=684, epochs=4.38, elapsed=0.21, elbo=-6123.41
# i=685, epochs=4.38, elapsed=0.21, elbo=-6119.17
# i=686, epochs=4.39, elapsed=0.21, elbo=-6001.21
# i=687, epochs=4.40, elapsed=0.22, elbo=-6101.14
# i=688, epochs=4.40, elapsed=0.22, elbo=-6179.91
# i=689, epochs=4.41, elapsed=0.22, elbo=-6088.23
# i=690, epochs=4.42, elapsed=0.22, elbo=-6100.35
# i=691, epochs=4.42, elapsed=0.22, elbo=-6106.76
# i=692, epochs=4.43, elapsed=0.22, elbo=-6115.37
# i=693, epochs=4.44, elapsed=0.22, elbo=-6084.13
# i=694, epochs=4.44, elapsed=0.22, elbo=-6101.28
# i=695, epochs=4.45, elapsed=0.22, elbo=-6060.24
# i=696, epochs=4.45, elapsed=0.22, elbo=-6074.81
# i=697, epochs=4.46, elapsed=0.22, elbo=-6111.43
# i=698, epochs=4.47, elapsed=0.22, elbo=-6145.64
# i=699, epochs=4.47, elapsed=0.22, elbo=-6138.53
# i=700, epochs=4.48, elapsed=0.22, elbo=-6077.08
# Drawing
# i=701, epochs=4.49, elapsed=0.22, elbo=-6051.84
# i=702, epochs=4.49, elapsed=0.22, elbo=-6091.96
# i=703, epochs=4.50, elapsed=0.22, elbo=-6149.04
# i=704, epochs=4.51, elapsed=0.22, elbo=-6148.23
# i=705, epochs=4.51, elapsed=0.22, elbo=-6081.72
# i=706, epochs=4.52, elapsed=0.22, elbo=-6070.88
# i=707, epochs=4.52, elapsed=0.22, elbo=-6067.96
# i=708, epochs=4.53, elapsed=0.22, elbo=-6097.48
# i=709, epochs=4.54, elapsed=0.22, elbo=-6092.92
# i=710, epochs=4.54, elapsed=0.22, elbo=-6093.06
# i=711, epochs=4.55, elapsed=0.22, elbo=-6106.71
# i=712, epochs=4.56, elapsed=0.22, elbo=-6081.41
# i=713, epochs=4.56, elapsed=0.22, elbo=-6089.49
# i=714, epochs=4.57, elapsed=0.23, elbo=-6146.78
# i=715, epochs=4.58, elapsed=0.23, elbo=-6041.11
# i=716, epochs=4.58, elapsed=0.23, elbo=-6053.92
# i=717, epochs=4.59, elapsed=0.23, elbo=-6108.95
# i=718, epochs=4.60, elapsed=0.23, elbo=-6124.16
# i=719, epochs=4.60, elapsed=0.23, elbo=-6065.62
# i=720, epochs=4.61, elapsed=0.23, elbo=-6053.57
# i=721, epochs=4.61, elapsed=0.23, elbo=-6088.37
# i=722, epochs=4.62, elapsed=0.23, elbo=-6082.54
# i=723, epochs=4.63, elapsed=0.23, elbo=-6097.13
# i=724, epochs=4.63, elapsed=0.23, elbo=-6110.04
# i=725, epochs=4.64, elapsed=0.23, elbo=-6072.36
# i=726, epochs=4.65, elapsed=0.23, elbo=-6073.47
# i=727, epochs=4.65, elapsed=0.23, elbo=-6075.49
# i=728, epochs=4.66, elapsed=0.23, elbo=-6050.69
# i=729, epochs=4.67, elapsed=0.23, elbo=-6043.03
# i=730, epochs=4.67, elapsed=0.23, elbo=-6077.84
# i=731, epochs=4.68, elapsed=0.23, elbo=-6077.71
# i=732, epochs=4.68, elapsed=0.23, elbo=-6084.68
# i=733, epochs=4.69, elapsed=0.23, elbo=-6084.82
# i=734, epochs=4.70, elapsed=0.23, elbo=-6071.11
# i=735, epochs=4.70, elapsed=0.23, elbo=-6095.51
# i=736, epochs=4.71, elapsed=0.23, elbo=-6016.00
# i=737, epochs=4.72, elapsed=0.23, elbo=-6099.23
# i=738, epochs=4.72, elapsed=0.23, elbo=-6077.42
# i=739, epochs=4.73, elapsed=0.23, elbo=-6099.24
# i=740, epochs=4.74, elapsed=0.23, elbo=-6084.16
# i=741, epochs=4.74, elapsed=0.23, elbo=-6120.34
# i=742, epochs=4.75, elapsed=0.24, elbo=-6079.76
# i=743, epochs=4.76, elapsed=0.24, elbo=-6065.39
# i=744, epochs=4.76, elapsed=0.24, elbo=-6101.95
# i=745, epochs=4.77, elapsed=0.24, elbo=-6089.09
# i=746, epochs=4.77, elapsed=0.24, elbo=-6130.28
# i=747, epochs=4.78, elapsed=0.24, elbo=-6078.06
# i=748, epochs=4.79, elapsed=0.24, elbo=-6066.24
# i=749, epochs=4.79, elapsed=0.24, elbo=-6070.87
# i=750, epochs=4.80, elapsed=0.24, elbo=-6071.75
# i=751, epochs=4.81, elapsed=0.24, elbo=-6058.72
# i=752, epochs=4.81, elapsed=0.24, elbo=-6108.72
# i=753, epochs=4.82, elapsed=0.24, elbo=-6097.80
# i=754, epochs=4.83, elapsed=0.24, elbo=-6122.82
# i=755, epochs=4.83, elapsed=0.24, elbo=-6118.57
# i=756, epochs=4.84, elapsed=0.24, elbo=-6090.12
# i=757, epochs=4.84, elapsed=0.24, elbo=-6127.27
# i=758, epochs=4.85, elapsed=0.24, elbo=-6115.39
# i=759, epochs=4.86, elapsed=0.24, elbo=-6132.18
# i=760, epochs=4.86, elapsed=0.24, elbo=-6110.41
# i=761, epochs=4.87, elapsed=0.24, elbo=-6113.34
# i=762, epochs=4.88, elapsed=0.24, elbo=-6059.70
# i=763, epochs=4.88, elapsed=0.24, elbo=-6022.06
# i=764, epochs=4.89, elapsed=0.24, elbo=-6097.30
# i=765, epochs=4.90, elapsed=0.24, elbo=-6075.97
# i=766, epochs=4.90, elapsed=0.24, elbo=-6063.16
# i=767, epochs=4.91, elapsed=0.24, elbo=-6109.79
# i=768, epochs=4.92, elapsed=0.25, elbo=-6064.70
# i=769, epochs=4.92, elapsed=0.25, elbo=-6085.36
# i=770, epochs=4.93, elapsed=0.25, elbo=-6076.99
# i=771, epochs=4.93, elapsed=0.25, elbo=-6096.38
# i=772, epochs=4.94, elapsed=0.25, elbo=-6187.51
# i=773, epochs=4.95, elapsed=0.25, elbo=-6068.50
# i=774, epochs=4.95, elapsed=0.25, elbo=-6134.36
# i=775, epochs=4.96, elapsed=0.25, elbo=-6127.66
# i=776, epochs=4.97, elapsed=0.25, elbo=-6034.59
# i=777, epochs=4.97, elapsed=0.25, elbo=-6081.09
# i=778, epochs=4.98, elapsed=0.25, elbo=-6056.45
# i=779, epochs=4.99, elapsed=0.25, elbo=-6073.31
# i=780, epochs=4.99, elapsed=0.25, elbo=-6101.30
# i=781, epochs=5.00, elapsed=0.25, elbo=-6109.05
# i=782, epochs=5.00, elapsed=0.25, elbo=-6066.34
# i=783, epochs=5.01, elapsed=0.25, elbo=-6085.31
# i=784, epochs=5.02, elapsed=0.25, elbo=-6126.35
# i=785, epochs=5.02, elapsed=0.25, elbo=-6101.31
# i=786, epochs=5.03, elapsed=0.25, elbo=-6091.49
# i=787, epochs=5.04, elapsed=0.25, elbo=-6029.03
# i=788, epochs=5.04, elapsed=0.25, elbo=-6069.84
# i=789, epochs=5.05, elapsed=0.25, elbo=-6069.01
# i=790, epochs=5.06, elapsed=0.25, elbo=-6106.46
# i=791, epochs=5.06, elapsed=0.25, elbo=-6102.05
# i=792, epochs=5.07, elapsed=0.25, elbo=-6093.88
# i=793, epochs=5.08, elapsed=0.26, elbo=-6125.19
# i=794, epochs=5.08, elapsed=0.26, elbo=-6122.51
# i=795, epochs=5.09, elapsed=0.26, elbo=-6104.10
# i=796, epochs=5.09, elapsed=0.26, elbo=-6131.08
# i=797, epochs=5.10, elapsed=0.26, elbo=-6031.57
# i=798, epochs=5.11, elapsed=0.26, elbo=-6057.15
# i=799, epochs=5.11, elapsed=0.26, elbo=-6094.47
# i=800, epochs=5.12, elapsed=0.26, elbo=-6090.77
# Drawing
# i=801, epochs=5.13, elapsed=0.26, elbo=-6031.16
# i=802, epochs=5.13, elapsed=0.26, elbo=-6059.52
# i=803, epochs=5.14, elapsed=0.26, elbo=-6129.19
# i=804, epochs=5.15, elapsed=0.26, elbo=-6076.32
# i=805, epochs=5.15, elapsed=0.26, elbo=-6075.73
# i=806, epochs=5.16, elapsed=0.26, elbo=-6073.18
# i=807, epochs=5.16, elapsed=0.26, elbo=-6102.04
# i=808, epochs=5.17, elapsed=0.26, elbo=-6045.05
# i=809, epochs=5.18, elapsed=0.26, elbo=-6079.52
# i=810, epochs=5.18, elapsed=0.26, elbo=-6057.19
# i=811, epochs=5.19, elapsed=0.26, elbo=-6077.28
# i=812, epochs=5.20, elapsed=0.26, elbo=-6132.60
# i=813, epochs=5.20, elapsed=0.26, elbo=-6130.01
# i=814, epochs=5.21, elapsed=0.26, elbo=-6062.25
# i=815, epochs=5.22, elapsed=0.26, elbo=-6026.51
# i=816, epochs=5.22, elapsed=0.26, elbo=-6101.95
# i=817, epochs=5.23, elapsed=0.26, elbo=-6084.73
# i=818, epochs=5.24, elapsed=0.26, elbo=-6074.04
# i=819, epochs=5.24, elapsed=0.26, elbo=-6111.97
# i=820, epochs=5.25, elapsed=0.27, elbo=-6077.05
# i=821, epochs=5.25, elapsed=0.27, elbo=-6085.14
# i=822, epochs=5.26, elapsed=0.27, elbo=-6104.44
# i=823, epochs=5.27, elapsed=0.27, elbo=-6059.64
# i=824, epochs=5.27, elapsed=0.27, elbo=-6103.86
# i=825, epochs=5.28, elapsed=0.27, elbo=-6115.29
# i=826, epochs=5.29, elapsed=0.27, elbo=-6116.86
# i=827, epochs=5.29, elapsed=0.27, elbo=-6114.27
# i=828, epochs=5.30, elapsed=0.27, elbo=-6104.37
# i=829, epochs=5.31, elapsed=0.27, elbo=-6019.20
# i=830, epochs=5.31, elapsed=0.27, elbo=-6048.99
# i=831, epochs=5.32, elapsed=0.27, elbo=-6112.71
# i=832, epochs=5.32, elapsed=0.27, elbo=-6080.96
# i=833, epochs=5.33, elapsed=0.27, elbo=-6100.80
# i=834, epochs=5.34, elapsed=0.27, elbo=-6128.19
# i=835, epochs=5.34, elapsed=0.27, elbo=-6133.69
# i=836, epochs=5.35, elapsed=0.27, elbo=-6075.98
# i=837, epochs=5.36, elapsed=0.27, elbo=-6090.36
# i=838, epochs=5.36, elapsed=0.27, elbo=-6063.50
# i=839, epochs=5.37, elapsed=0.27, elbo=-6056.73
# i=840, epochs=5.38, elapsed=0.27, elbo=-6109.63
# i=841, epochs=5.38, elapsed=0.27, elbo=-6074.21
# i=842, epochs=5.39, elapsed=0.27, elbo=-6085.84
# i=843, epochs=5.40, elapsed=0.27, elbo=-6087.64
# i=844, epochs=5.40, elapsed=0.27, elbo=-6098.70
# i=845, epochs=5.41, elapsed=0.28, elbo=-6125.55
# i=846, epochs=5.41, elapsed=0.28, elbo=-6140.28
# i=847, epochs=5.42, elapsed=0.28, elbo=-6113.83
# i=848, epochs=5.43, elapsed=0.28, elbo=-6073.41
# i=849, epochs=5.43, elapsed=0.28, elbo=-6071.47
# i=850, epochs=5.44, elapsed=0.28, elbo=-6072.65
# i=851, epochs=5.45, elapsed=0.28, elbo=-6090.37
# i=852, epochs=5.45, elapsed=0.28, elbo=-6083.03
# i=853, epochs=5.46, elapsed=0.28, elbo=-6125.87
# i=854, epochs=5.47, elapsed=0.28, elbo=-6073.60
# i=855, epochs=5.47, elapsed=0.28, elbo=-6064.30
# i=856, epochs=5.48, elapsed=0.28, elbo=-6083.82
# i=857, epochs=5.48, elapsed=0.28, elbo=-6080.76
# i=858, epochs=5.49, elapsed=0.28, elbo=-6063.24
# i=859, epochs=5.50, elapsed=0.28, elbo=-6109.42
# i=860, epochs=5.50, elapsed=0.28, elbo=-6112.24
# i=861, epochs=5.51, elapsed=0.28, elbo=-6115.38
# i=862, epochs=5.52, elapsed=0.28, elbo=-6046.29
# i=863, epochs=5.52, elapsed=0.28, elbo=-6080.27
# i=864, epochs=5.53, elapsed=0.28, elbo=-6093.05
# i=865, epochs=5.54, elapsed=0.28, elbo=-6087.72
# i=866, epochs=5.54, elapsed=0.28, elbo=-6066.19
# i=867, epochs=5.55, elapsed=0.28, elbo=-6099.63
# i=868, epochs=5.56, elapsed=0.28, elbo=-6128.37
# i=869, epochs=5.56, elapsed=0.28, elbo=-6105.33
# i=870, epochs=5.57, elapsed=0.28, elbo=-6054.86
# i=871, epochs=5.57, elapsed=0.28, elbo=-6088.04
# i=872, epochs=5.58, elapsed=0.28, elbo=-6094.66
# i=873, epochs=5.59, elapsed=0.28, elbo=-6074.69
# i=874, epochs=5.59, elapsed=0.29, elbo=-6097.92
# i=875, epochs=5.60, elapsed=0.29, elbo=-6080.96
# i=876, epochs=5.61, elapsed=0.29, elbo=-6133.79
# i=877, epochs=5.61, elapsed=0.29, elbo=-6079.52
# i=878, epochs=5.62, elapsed=0.29, elbo=-6072.60
# i=879, epochs=5.63, elapsed=0.29, elbo=-6131.16
# i=880, epochs=5.63, elapsed=0.29, elbo=-6099.48
# i=881, epochs=5.64, elapsed=0.29, elbo=-6091.23
# i=882, epochs=5.64, elapsed=0.29, elbo=-6129.58
# i=883, epochs=5.65, elapsed=0.29, elbo=-6130.31
# i=884, epochs=5.66, elapsed=0.29, elbo=-6066.50
# i=885, epochs=5.66, elapsed=0.29, elbo=-6073.09
# i=886, epochs=5.67, elapsed=0.29, elbo=-6095.39
# i=887, epochs=5.68, elapsed=0.29, elbo=-6080.78
# i=888, epochs=5.68, elapsed=0.29, elbo=-6095.61
# i=889, epochs=5.69, elapsed=0.29, elbo=-6089.77
# i=890, epochs=5.70, elapsed=0.29, elbo=-6026.63
# i=891, epochs=5.70, elapsed=0.29, elbo=-6107.72
# i=892, epochs=5.71, elapsed=0.29, elbo=-6132.41
# i=893, epochs=5.72, elapsed=0.29, elbo=-6093.71
# i=894, epochs=5.72, elapsed=0.29, elbo=-6123.73
# i=895, epochs=5.73, elapsed=0.29, elbo=-6096.09
# i=896, epochs=5.73, elapsed=0.29, elbo=-6070.13
# i=897, epochs=5.74, elapsed=0.29, elbo=-6069.10
# i=898, epochs=5.75, elapsed=0.29, elbo=-6114.54
# i=899, epochs=5.75, elapsed=0.29, elbo=-6149.15
# i=900, epochs=5.76, elapsed=0.29, elbo=-6066.09
# Drawing
# i=901, epochs=5.77, elapsed=0.30, elbo=-6132.37
# i=902, epochs=5.77, elapsed=0.30, elbo=-6095.46
# i=903, epochs=5.78, elapsed=0.30, elbo=-6079.31
# i=904, epochs=5.79, elapsed=0.30, elbo=-6084.21
# i=905, epochs=5.79, elapsed=0.30, elbo=-6102.98
# i=906, epochs=5.80, elapsed=0.30, elbo=-6083.51
# i=907, epochs=5.80, elapsed=0.30, elbo=-6111.99
# i=908, epochs=5.81, elapsed=0.30, elbo=-6151.77
# i=909, epochs=5.82, elapsed=0.30, elbo=-6114.82
# i=910, epochs=5.82, elapsed=0.30, elbo=-6097.98
# i=911, epochs=5.83, elapsed=0.30, elbo=-6113.11
# i=912, epochs=5.84, elapsed=0.30, elbo=-6135.26
# i=913, epochs=5.84, elapsed=0.30, elbo=-6125.81
# i=914, epochs=5.85, elapsed=0.30, elbo=-6093.45
# i=915, epochs=5.86, elapsed=0.30, elbo=-6075.87
# i=916, epochs=5.86, elapsed=0.30, elbo=-6132.34
# i=917, epochs=5.87, elapsed=0.30, elbo=-6077.98
# i=918, epochs=5.88, elapsed=0.30, elbo=-6073.16
# i=919, epochs=5.88, elapsed=0.30, elbo=-6074.18
# i=920, epochs=5.89, elapsed=0.30, elbo=-6075.18
# i=921, epochs=5.89, elapsed=0.30, elbo=-6076.32
# i=922, epochs=5.90, elapsed=0.30, elbo=-6032.59
# i=923, epochs=5.91, elapsed=0.30, elbo=-6100.15
# i=924, epochs=5.91, elapsed=0.30, elbo=-6097.51
# i=925, epochs=5.92, elapsed=0.30, elbo=-6133.92
# i=926, epochs=5.93, elapsed=0.30, elbo=-6115.83
# i=927, epochs=5.93, elapsed=0.30, elbo=-6102.94
# i=928, epochs=5.94, elapsed=0.30, elbo=-6056.06
# i=929, epochs=5.95, elapsed=0.31, elbo=-6038.87
# i=930, epochs=5.95, elapsed=0.31, elbo=-6128.21
# i=931, epochs=5.96, elapsed=0.31, elbo=-6048.51
# i=932, epochs=5.96, elapsed=0.31, elbo=-6140.72
# i=933, epochs=5.97, elapsed=0.31, elbo=-6098.09
# i=934, epochs=5.98, elapsed=0.31, elbo=-6121.41
# i=935, epochs=5.98, elapsed=0.31, elbo=-6121.61
# i=936, epochs=5.99, elapsed=0.31, elbo=-6099.67
# i=937, epochs=6.00, elapsed=0.31, elbo=-6034.42
# i=938, epochs=6.00, elapsed=0.31, elbo=-6120.10
# i=939, epochs=6.01, elapsed=0.31, elbo=-6036.54
# i=940, epochs=6.02, elapsed=0.31, elbo=-6124.31
# i=941, epochs=6.02, elapsed=0.31, elbo=-6040.48
# i=942, epochs=6.03, elapsed=0.31, elbo=-6056.00
# i=943, epochs=6.04, elapsed=0.31, elbo=-6092.12
# i=944, epochs=6.04, elapsed=0.31, elbo=-6078.88
# i=945, epochs=6.05, elapsed=0.31, elbo=-6064.17
# i=946, epochs=6.05, elapsed=0.31, elbo=-6129.54
# i=947, epochs=6.06, elapsed=0.31, elbo=-6114.66
# i=948, epochs=6.07, elapsed=0.31, elbo=-6102.52
# i=949, epochs=6.07, elapsed=0.31, elbo=-6097.58
# i=950, epochs=6.08, elapsed=0.31, elbo=-6115.59
# i=951, epochs=6.09, elapsed=0.31, elbo=-6096.00
# i=952, epochs=6.09, elapsed=0.31, elbo=-6054.29
# i=953, epochs=6.10, elapsed=0.31, elbo=-6080.57
# i=954, epochs=6.11, elapsed=0.31, elbo=-6072.54
# i=955, epochs=6.11, elapsed=0.31, elbo=-6047.16
# i=956, epochs=6.12, elapsed=0.32, elbo=-6110.90
# i=957, epochs=6.12, elapsed=0.32, elbo=-6075.82
# i=958, epochs=6.13, elapsed=0.32, elbo=-6147.90
# i=959, epochs=6.14, elapsed=0.32, elbo=-6127.80
# i=960, epochs=6.14, elapsed=0.32, elbo=-6115.39
# i=961, epochs=6.15, elapsed=0.32, elbo=-6118.49
# i=962, epochs=6.16, elapsed=0.32, elbo=-6096.02
# i=963, epochs=6.16, elapsed=0.32, elbo=-6107.81
# i=964, epochs=6.17, elapsed=0.32, elbo=-6155.34
# i=965, epochs=6.18, elapsed=0.32, elbo=-6073.35
# i=966, epochs=6.18, elapsed=0.32, elbo=-6092.88
# i=967, epochs=6.19, elapsed=0.32, elbo=-6112.35
# i=968, epochs=6.20, elapsed=0.32, elbo=-6061.50
# i=969, epochs=6.20, elapsed=0.32, elbo=-6098.31
# i=970, epochs=6.21, elapsed=0.32, elbo=-6033.67
# i=971, epochs=6.21, elapsed=0.32, elbo=-6119.90
# i=972, epochs=6.22, elapsed=0.32, elbo=-6100.21
# i=973, epochs=6.23, elapsed=0.32, elbo=-6101.76
# i=974, epochs=6.23, elapsed=0.32, elbo=-6122.55
# i=975, epochs=6.24, elapsed=0.32, elbo=-6122.25
# i=976, epochs=6.25, elapsed=0.32, elbo=-6149.64
# i=977, epochs=6.25, elapsed=0.32, elbo=-6074.09
# i=978, epochs=6.26, elapsed=0.32, elbo=-6062.26
# i=979, epochs=6.27, elapsed=0.32, elbo=-6075.65
# i=980, epochs=6.27, elapsed=0.32, elbo=-6113.04
# i=981, epochs=6.28, elapsed=0.33, elbo=-6101.93
# i=982, epochs=6.28, elapsed=0.33, elbo=-6109.85
# i=983, epochs=6.29, elapsed=0.33, elbo=-6078.33
# i=984, epochs=6.30, elapsed=0.33, elbo=-6108.62
# i=985, epochs=6.30, elapsed=0.33, elbo=-6063.03
# i=986, epochs=6.31, elapsed=0.33, elbo=-6078.59
# i=987, epochs=6.32, elapsed=0.33, elbo=-6063.85
# i=988, epochs=6.32, elapsed=0.33, elbo=-6084.09
# i=989, epochs=6.33, elapsed=0.33, elbo=-6136.72
# i=990, epochs=6.34, elapsed=0.33, elbo=-6047.39
# i=991, epochs=6.34, elapsed=0.33, elbo=-6116.39
# i=992, epochs=6.35, elapsed=0.33, elbo=-6166.51
# i=993, epochs=6.36, elapsed=0.33, elbo=-6083.10
# i=994, epochs=6.36, elapsed=0.33, elbo=-6099.99
# i=995, epochs=6.37, elapsed=0.33, elbo=-6088.25
# i=996, epochs=6.37, elapsed=0.33, elbo=-6122.70
# i=997, epochs=6.38, elapsed=0.33, elbo=-6073.68
# i=998, epochs=6.39, elapsed=0.33, elbo=-6063.12
# i=999, epochs=6.39, elapsed=0.33, elbo=-6083.08
# i=1000, epochs=6.40, elapsed=0.33, elbo=-6111.60
# Drawing
# ...
# i=1903, epochs=12.18, elapsed=0.63, elbo=-6086.60
# i=1904, epochs=12.19, elapsed=0.63, elbo=-6106.56
# i=1905, epochs=12.19, elapsed=0.63, elbo=-6095.60
# i=1906, epochs=12.20, elapsed=0.63, elbo=-6107.08
# i=1907, epochs=12.20, elapsed=0.63, elbo=-6088.60
# i=1908, epochs=12.21, elapsed=0.63, elbo=-6075.43
# i=1909, epochs=12.22, elapsed=0.63, elbo=-6152.87
# i=1910, epochs=12.22, elapsed=0.63, elbo=-6159.93
# i=1911, epochs=12.23, elapsed=0.63, elbo=-6131.99
# i=1912, epochs=12.24, elapsed=0.63, elbo=-6047.51
# i=1913, epochs=12.24, elapsed=0.63, elbo=-6129.15
# i=1914, epochs=12.25, elapsed=0.63, elbo=-6158.73
# i=1915, epochs=12.26, elapsed=0.63, elbo=-6111.76
# i=1916, epochs=12.26, elapsed=0.63, elbo=-6125.24
# i=1917, epochs=12.27, elapsed=0.63, elbo=-6084.21
# i=1918, epochs=12.28, elapsed=0.63, elbo=-6069.09
# i=1919, epochs=12.28, elapsed=0.63, elbo=-6089.85
# i=1920, epochs=12.29, elapsed=0.63, elbo=-6178.57
# i=1921, epochs=12.29, elapsed=0.63, elbo=-6091.38
# i=1922, epochs=12.30, elapsed=0.63, elbo=-6072.20
# i=1923, epochs=12.31, elapsed=0.63, elbo=-6113.05
# i=1924, epochs=12.31, elapsed=0.64, elbo=-6030.22
# i=1925, epochs=12.32, elapsed=0.64, elbo=-6156.60
# i=1926, epochs=12.33, elapsed=0.64, elbo=-6086.25
# i=1927, epochs=12.33, elapsed=0.64, elbo=-6093.45
# i=1928, epochs=12.34, elapsed=0.64, elbo=-6105.64
# i=1929, epochs=12.35, elapsed=0.64, elbo=-6113.88
# i=1930, epochs=12.35, elapsed=0.64, elbo=-6038.48
# i=1931, epochs=12.36, elapsed=0.64, elbo=-6128.55
# i=1932, epochs=12.36, elapsed=0.64, elbo=-6157.36
# i=1933, epochs=12.37, elapsed=0.64, elbo=-6102.70
# i=1934, epochs=12.38, elapsed=0.64, elbo=-6073.93
# i=1935, epochs=12.38, elapsed=0.64, elbo=-6093.21
# i=1936, epochs=12.39, elapsed=0.64, elbo=-6070.40
# i=1937, epochs=12.40, elapsed=0.64, elbo=-6055.36
# i=1938, epochs=12.40, elapsed=0.64, elbo=-6101.19
# i=1939, epochs=12.41, elapsed=0.64, elbo=-6105.32
# i=1940, epochs=12.42, elapsed=0.64, elbo=-6070.78
# i=1941, epochs=12.42, elapsed=0.64, elbo=-6113.92
# i=1942, epochs=12.43, elapsed=0.64, elbo=-6020.05
# i=1943, epochs=12.44, elapsed=0.64, elbo=-6025.68
# i=1944, epochs=12.44, elapsed=0.64, elbo=-6083.87
# i=1945, epochs=12.45, elapsed=0.64, elbo=-6053.84
# i=1946, epochs=12.45, elapsed=0.64, elbo=-6110.25
# i=1947, epochs=12.46, elapsed=0.64, elbo=-6140.79
# i=1948, epochs=12.47, elapsed=0.64, elbo=-6105.51
# i=1949, epochs=12.47, elapsed=0.64, elbo=-6119.72
# i=1950, epochs=12.48, elapsed=0.64, elbo=-6114.28
# i=1951, epochs=12.49, elapsed=0.64, elbo=-6076.84
# i=1952, epochs=12.49, elapsed=0.64, elbo=-6110.21
# i=1953, epochs=12.50, elapsed=0.64, elbo=-6077.02
# i=1954, epochs=12.51, elapsed=0.64, elbo=-6060.47
# i=1955, epochs=12.51, elapsed=0.64, elbo=-6088.29
# i=1956, epochs=12.52, elapsed=0.64, elbo=-6102.77
# i=1957, epochs=12.52, elapsed=0.65, elbo=-6085.53
# i=1958, epochs=12.53, elapsed=0.65, elbo=-6081.78
# i=1959, epochs=12.54, elapsed=0.65, elbo=-6123.60
# i=1960, epochs=12.54, elapsed=0.65, elbo=-6106.88
# i=1961, epochs=12.55, elapsed=0.65, elbo=-6151.28
# i=1962, epochs=12.56, elapsed=0.65, elbo=-6140.54
# i=1963, epochs=12.56, elapsed=0.65, elbo=-6112.63
# i=1964, epochs=12.57, elapsed=0.65, elbo=-6121.10
# i=1965, epochs=12.58, elapsed=0.65, elbo=-6060.96
# i=1966, epochs=12.58, elapsed=0.65, elbo=-6124.85
# i=1967, epochs=12.59, elapsed=0.65, elbo=-6085.40
# i=1968, epochs=12.60, elapsed=0.65, elbo=-6128.11
# i=1969, epochs=12.60, elapsed=0.65, elbo=-6135.80
# i=1970, epochs=12.61, elapsed=0.65, elbo=-6084.27
# i=1971, epochs=12.61, elapsed=0.65, elbo=-6071.23
# i=1972, epochs=12.62, elapsed=0.65, elbo=-6022.68
# i=1973, epochs=12.63, elapsed=0.65, elbo=-6113.70
# i=1974, epochs=12.63, elapsed=0.65, elbo=-6159.03
# i=1975, epochs=12.64, elapsed=0.65, elbo=-6119.60
# i=1976, epochs=12.65, elapsed=0.65, elbo=-6109.49
# i=1977, epochs=12.65, elapsed=0.65, elbo=-6119.18
# i=1978, epochs=12.66, elapsed=0.65, elbo=-6106.54
# i=1979, epochs=12.67, elapsed=0.65, elbo=-6072.52
# i=1980, epochs=12.67, elapsed=0.65, elbo=-6062.14
# i=1981, epochs=12.68, elapsed=0.65, elbo=-6075.63
# i=1982, epochs=12.68, elapsed=0.65, elbo=-6071.77
# i=1983, epochs=12.69, elapsed=0.65, elbo=-5997.99
# i=1984, epochs=12.70, elapsed=0.65, elbo=-6144.44
# i=1985, epochs=12.70, elapsed=0.65, elbo=-6127.67
# i=1986, epochs=12.71, elapsed=0.65, elbo=-6069.76
# i=1987, epochs=12.72, elapsed=0.65, elbo=-6139.16
# i=1988, epochs=12.72, elapsed=0.65, elbo=-6101.28
# i=1989, epochs=12.73, elapsed=0.66, elbo=-6075.61
# i=1990, epochs=12.74, elapsed=0.66, elbo=-6122.21
# i=1991, epochs=12.74, elapsed=0.66, elbo=-6080.78
# i=1992, epochs=12.75, elapsed=0.66, elbo=-6107.08
# i=1993, epochs=12.76, elapsed=0.66, elbo=-6125.65
# i=1994, epochs=12.76, elapsed=0.66, elbo=-6127.90
# i=1995, epochs=12.77, elapsed=0.66, elbo=-6104.95
# i=1996, epochs=12.77, elapsed=0.66, elbo=-6156.79
# i=1997, epochs=12.78, elapsed=0.66, elbo=-6135.55
# i=1998, epochs=12.79, elapsed=0.66, elbo=-6149.14
# i=1999, epochs=12.79, elapsed=0.66, elbo=-6061.31
# i=2000, epochs=12.80, elapsed=0.66, elbo=-6111.66
# Drawing
# i=2001, epochs=12.81, elapsed=0.66, elbo=-6032.54
# i=2002, epochs=12.81, elapsed=0.66, elbo=-6108.88
# i=2003, epochs=12.82, elapsed=0.66, elbo=-6059.58
# i=2004, epochs=12.83, elapsed=0.66, elbo=-6107.55
# i=2005, epochs=12.83, elapsed=0.66, elbo=-6114.84
# i=2006, epochs=12.84, elapsed=0.66, elbo=-6117.62
# i=2007, epochs=12.84, elapsed=0.66, elbo=-6134.86
# i=2008, epochs=12.85, elapsed=0.66, elbo=-6105.01
# i=2009, epochs=12.86, elapsed=0.66, elbo=-6089.80
# i=2010, epochs=12.86, elapsed=0.66, elbo=-6116.55
# i=2011, epochs=12.87, elapsed=0.66, elbo=-6141.23
# i=2012, epochs=12.88, elapsed=0.66, elbo=-6139.96
# i=2013, epochs=12.88, elapsed=0.66, elbo=-6093.69
# i=2014, epochs=12.89, elapsed=0.66, elbo=-6148.15
# i=2015, epochs=12.90, elapsed=0.66, elbo=-6100.15
# i=2016, epochs=12.90, elapsed=0.66, elbo=-6085.12
# i=2017, epochs=12.91, elapsed=0.66, elbo=-6100.17
# i=2018, epochs=12.92, elapsed=0.66, elbo=-6080.52
# i=2019, epochs=12.92, elapsed=0.66, elbo=-6116.36
# i=2020, epochs=12.93, elapsed=0.66, elbo=-6101.13
# i=2021, epochs=12.93, elapsed=0.66, elbo=-6145.82
# i=2022, epochs=12.94, elapsed=0.67, elbo=-6122.60
# i=2023, epochs=12.95, elapsed=0.67, elbo=-6084.50
# i=2024, epochs=12.95, elapsed=0.67, elbo=-6101.55
# i=2025, epochs=12.96, elapsed=0.67, elbo=-6044.98
# i=2026, epochs=12.97, elapsed=0.67, elbo=-6046.57
# i=2027, epochs=12.97, elapsed=0.67, elbo=-6099.07
# i=2028, epochs=12.98, elapsed=0.67, elbo=-6055.35
# i=2029, epochs=12.99, elapsed=0.67, elbo=-6073.70
# i=2030, epochs=12.99, elapsed=0.67, elbo=-6095.29
# i=2031, epochs=13.00, elapsed=0.67, elbo=-6054.68
# i=2032, epochs=13.00, elapsed=0.67, elbo=-6091.37
# i=2033, epochs=13.01, elapsed=0.67, elbo=-6098.20
# i=2034, epochs=13.02, elapsed=0.67, elbo=-6119.62
# i=2035, epochs=13.02, elapsed=0.67, elbo=-6096.67
# i=2036, epochs=13.03, elapsed=0.67, elbo=-6092.04
# i=2037, epochs=13.04, elapsed=0.67, elbo=-6128.34
# i=2038, epochs=13.04, elapsed=0.67, elbo=-6123.26
# i=2039, epochs=13.05, elapsed=0.67, elbo=-6072.76
# i=2040, epochs=13.06, elapsed=0.67, elbo=-6066.84
# i=2041, epochs=13.06, elapsed=0.67, elbo=-6092.21
# i=2042, epochs=13.07, elapsed=0.67, elbo=-6135.23
# i=2043, epochs=13.08, elapsed=0.67, elbo=-6089.01
# i=2044, epochs=13.08, elapsed=0.67, elbo=-6083.26
# i=2045, epochs=13.09, elapsed=0.67, elbo=-6129.99
# i=2046, epochs=13.09, elapsed=0.67, elbo=-6125.38
# i=2047, epochs=13.10, elapsed=0.67, elbo=-6127.87
# i=2048, epochs=13.11, elapsed=0.67, elbo=-6072.52
# i=2049, epochs=13.11, elapsed=0.67, elbo=-6071.56
# i=2050, epochs=13.12, elapsed=0.67, elbo=-6098.34
# i=2051, epochs=13.13, elapsed=0.67, elbo=-6079.19
# i=2052, epochs=13.13, elapsed=0.67, elbo=-6093.15
# i=2053, epochs=13.14, elapsed=0.67, elbo=-6114.62
# i=2054, epochs=13.15, elapsed=0.68, elbo=-6111.82
# i=2055, epochs=13.15, elapsed=0.68, elbo=-6042.44
# i=2056, epochs=13.16, elapsed=0.68, elbo=-6078.12
# i=2057, epochs=13.16, elapsed=0.68, elbo=-6156.36
# i=2058, epochs=13.17, elapsed=0.68, elbo=-6083.21
# i=2059, epochs=13.18, elapsed=0.68, elbo=-6121.86
# i=2060, epochs=13.18, elapsed=0.68, elbo=-6076.18
# i=2061, epochs=13.19, elapsed=0.68, elbo=-6144.16
# i=2062, epochs=13.20, elapsed=0.68, elbo=-6108.75
# i=2063, epochs=13.20, elapsed=0.68, elbo=-6065.10
# i=2064, epochs=13.21, elapsed=0.68, elbo=-6091.54
# i=2065, epochs=13.22, elapsed=0.68, elbo=-6109.50
# i=2066, epochs=13.22, elapsed=0.68, elbo=-6138.86
# i=2067, epochs=13.23, elapsed=0.68, elbo=-6134.77
# i=2068, epochs=13.24, elapsed=0.68, elbo=-6092.63
# i=2069, epochs=13.24, elapsed=0.68, elbo=-6141.54
# i=2070, epochs=13.25, elapsed=0.68, elbo=-6072.72
# i=2071, epochs=13.25, elapsed=0.68, elbo=-6119.23
# i=2072, epochs=13.26, elapsed=0.68, elbo=-6064.11
# i=2073, epochs=13.27, elapsed=0.68, elbo=-6186.26
# i=2074, epochs=13.27, elapsed=0.68, elbo=-6120.24
# i=2075, epochs=13.28, elapsed=0.68, elbo=-6067.31
# i=2076, epochs=13.29, elapsed=0.68, elbo=-6093.91
# i=2077, epochs=13.29, elapsed=0.68, elbo=-6134.25
# i=2078, epochs=13.30, elapsed=0.68, elbo=-6110.39
# i=2079, epochs=13.31, elapsed=0.68, elbo=-6097.66
# i=2080, epochs=13.31, elapsed=0.68, elbo=-6053.15
# i=2081, epochs=13.32, elapsed=0.68, elbo=-6120.86
# i=2082, epochs=13.32, elapsed=0.68, elbo=-6084.24
# i=2083, epochs=13.33, elapsed=0.68, elbo=-6101.08
# i=2084, epochs=13.34, elapsed=0.68, elbo=-6077.23
# i=2085, epochs=13.34, elapsed=0.68, elbo=-6122.04
# i=2086, epochs=13.35, elapsed=0.69, elbo=-6102.36
# i=2087, epochs=13.36, elapsed=0.69, elbo=-6102.37
# i=2088, epochs=13.36, elapsed=0.69, elbo=-6066.47
# i=2089, epochs=13.37, elapsed=0.69, elbo=-6127.30
# i=2090, epochs=13.38, elapsed=0.69, elbo=-6073.70
# i=2091, epochs=13.38, elapsed=0.69, elbo=-6091.39
# i=2092, epochs=13.39, elapsed=0.69, elbo=-6106.39
# i=2093, epochs=13.40, elapsed=0.69, elbo=-6133.47
# i=2094, epochs=13.40, elapsed=0.69, elbo=-6111.52
# i=2095, epochs=13.41, elapsed=0.69, elbo=-6142.17
# i=2096, epochs=13.41, elapsed=0.69, elbo=-6100.34
# i=2097, epochs=13.42, elapsed=0.69, elbo=-6057.82
# i=2098, epochs=13.43, elapsed=0.69, elbo=-6055.34
# i=2099, epochs=13.43, elapsed=0.69, elbo=-6130.65
# i=2100, epochs=13.44, elapsed=0.69, elbo=-6053.66
# Drawing
# i=2101, epochs=13.45, elapsed=0.69, elbo=-6115.90
# i=2102, epochs=13.45, elapsed=0.69, elbo=-6110.86
# i=2103, epochs=13.46, elapsed=0.69, elbo=-6106.01
# i=2104, epochs=13.47, elapsed=0.69, elbo=-6119.77
# i=2105, epochs=13.47, elapsed=0.69, elbo=-6104.77
# i=2106, epochs=13.48, elapsed=0.69, elbo=-6138.62
# i=2107, epochs=13.48, elapsed=0.69, elbo=-6072.80
# i=2108, epochs=13.49, elapsed=0.69, elbo=-6101.19
# i=2109, epochs=13.50, elapsed=0.69, elbo=-6125.88
# i=2110, epochs=13.50, elapsed=0.69, elbo=-6107.52
# i=2111, epochs=13.51, elapsed=0.69, elbo=-6115.31
# i=2112, epochs=13.52, elapsed=0.69, elbo=-6077.93
# i=2113, epochs=13.52, elapsed=0.69, elbo=-6124.32
# i=2114, epochs=13.53, elapsed=0.69, elbo=-6082.24
# i=2115, epochs=13.54, elapsed=0.69, elbo=-6143.70
# i=2116, epochs=13.54, elapsed=0.69, elbo=-6114.76
# i=2117, epochs=13.55, elapsed=0.69, elbo=-6109.65
# i=2118, epochs=13.56, elapsed=0.69, elbo=-6130.75
# i=2119, epochs=13.56, elapsed=0.70, elbo=-6118.14
# i=2120, epochs=13.57, elapsed=0.70, elbo=-6069.49
# i=2121, epochs=13.57, elapsed=0.70, elbo=-6110.31
# i=2122, epochs=13.58, elapsed=0.70, elbo=-6038.09
# i=2123, epochs=13.59, elapsed=0.70, elbo=-6058.64
# i=2124, epochs=13.59, elapsed=0.70, elbo=-6064.51
# i=2125, epochs=13.60, elapsed=0.70, elbo=-6024.49
# i=2126, epochs=13.61, elapsed=0.70, elbo=-6135.27
# i=2127, epochs=13.61, elapsed=0.70, elbo=-6055.05
# i=2128, epochs=13.62, elapsed=0.70, elbo=-6053.97
# i=2129, epochs=13.63, elapsed=0.70, elbo=-6071.89
# i=2130, epochs=13.63, elapsed=0.70, elbo=-6131.66
# i=2131, epochs=13.64, elapsed=0.70, elbo=-6096.15
# i=2132, epochs=13.64, elapsed=0.70, elbo=-6103.37
# i=2133, epochs=13.65, elapsed=0.70, elbo=-6052.75
# i=2134, epochs=13.66, elapsed=0.70, elbo=-6121.43
# i=2135, epochs=13.66, elapsed=0.70, elbo=-6037.77
# i=2136, epochs=13.67, elapsed=0.70, elbo=-6052.95
# i=2137, epochs=13.68, elapsed=0.70, elbo=-6088.49
# i=2138, epochs=13.68, elapsed=0.70, elbo=-6058.18
# i=2139, epochs=13.69, elapsed=0.70, elbo=-6124.09
# i=2140, epochs=13.70, elapsed=0.70, elbo=-6123.80
# i=2141, epochs=13.70, elapsed=0.70, elbo=-6142.94
# i=2142, epochs=13.71, elapsed=0.70, elbo=-6156.94
# i=2143, epochs=13.72, elapsed=0.70, elbo=-6092.77
# i=2144, epochs=13.72, elapsed=0.70, elbo=-6112.08
# i=2145, epochs=13.73, elapsed=0.70, elbo=-6124.18
# i=2146, epochs=13.73, elapsed=0.70, elbo=-6131.17
# i=2147, epochs=13.74, elapsed=0.70, elbo=-6068.66
# i=2148, epochs=13.75, elapsed=0.70, elbo=-6119.95
# i=2149, epochs=13.75, elapsed=0.70, elbo=-6117.47
# i=2150, epochs=13.76, elapsed=0.70, elbo=-6087.13
# i=2151, epochs=13.77, elapsed=0.71, elbo=-6042.94
# i=2152, epochs=13.77, elapsed=0.71, elbo=-6097.78
# i=2153, epochs=13.78, elapsed=0.71, elbo=-6092.04
# i=2154, epochs=13.79, elapsed=0.71, elbo=-6135.12
# i=2155, epochs=13.79, elapsed=0.71, elbo=-6053.71
# i=2156, epochs=13.80, elapsed=0.71, elbo=-6052.34
# i=2157, epochs=13.80, elapsed=0.71, elbo=-6119.43
# i=2158, epochs=13.81, elapsed=0.71, elbo=-6139.72
# i=2159, epochs=13.82, elapsed=0.71, elbo=-6059.25
# i=2160, epochs=13.82, elapsed=0.71, elbo=-6059.43
# i=2161, epochs=13.83, elapsed=0.71, elbo=-6093.03
# i=2162, epochs=13.84, elapsed=0.71, elbo=-6143.05
# i=2163, epochs=13.84, elapsed=0.71, elbo=-6131.21
# i=2164, epochs=13.85, elapsed=0.71, elbo=-6098.19
# i=2165, epochs=13.86, elapsed=0.71, elbo=-6087.04
# i=2166, epochs=13.86, elapsed=0.71, elbo=-6112.67
# i=2167, epochs=13.87, elapsed=0.71, elbo=-6080.59
# i=2168, epochs=13.88, elapsed=0.71, elbo=-6125.20
# i=2169, epochs=13.88, elapsed=0.71, elbo=-6147.73
# i=2170, epochs=13.89, elapsed=0.71, elbo=-6095.57
# i=2171, epochs=13.89, elapsed=0.71, elbo=-6143.36
# i=2172, epochs=13.90, elapsed=0.71, elbo=-6131.96
# i=2173, epochs=13.91, elapsed=0.71, elbo=-6149.41
# i=2174, epochs=13.91, elapsed=0.71, elbo=-6111.84
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-c921e3e2ddd2> in <module>
#       4 for i in range(1, args.num_steps + 1):
#       5
# ----> 6     loss = svi.step(X, batch_size=args.batch_size, z_pres_prior_p=partial(z_pres_prior_p, i))
#       7
#       8     if args.progress_every > 0 and i % args.progress_every == 0:
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/pyro/infer/svi.py in step(self, *args, **kwargs)
#     126         # get loss and compute gradients
#     127         with poutine.trace(param_only=True) as param_capture:
# --> 128             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     129
#     130         params = set(site["value"].unconstrained()
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/pyro/infer/tracegraph_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     255         elbo, surrogate_loss = self._loss_and_surrogate_loss(model, guide, args, kwargs)
#     256
# --> 257         torch_backward(surrogate_loss, retain_graph=self.retain_graph)
#     258
#     259         elbo = torch_item(elbo)
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/pyro/infer/util.py in torch_backward(x, retain_graph)
#      53     """
#      54     if torch.is_tensor(x) and x.grad_fn:
# ---> 55         x.backward(retain_graph=retain_graph)
#      56
#      57
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:
