# %%
import argparse
import math
import os
import time
from functools import partial

import numpy as np
import torch
import visdom

import pyro
import pyro.contrib.examples.multi_mnist as multi_mnist
import pyro.optim as optim
import pyro.poutine as poutine
from components.AIR import AIR, latents_to_tensor
from pyro.contrib.examples.util import get_data_directory
from pyro.infer import SVI, JitTraceGraph_ELBO, TraceGraph_ELBO
from utils.viz import draw_many, tensor_to_objs

# %% [markdown]
# ## Support functions

# %%
def count_accuracy(X, true_counts, air, batch_size):
    assert X.size(0) == true_counts.size(0), 'Size mismatch.'
    assert X.size(0) % batch_size == 0, 'Input size must be multiple of batch_size.'
    counts = torch.LongTensor(3, 4).zero_()
    error_latents = []
    error_indicators = []

    def count_vec_to_mat(vec, max_index):
        out = torch.LongTensor(vec.size(0), max_index + 1).zero_()
        out.scatter_(1, vec.type(torch.LongTensor).view(vec.size(0), 1), 1)
        return out

    for i in range(X.size(0) // batch_size):
        X_batch = X[i * batch_size:(i + 1) * batch_size]
        true_counts_batch = true_counts[i * batch_size:(i + 1) * batch_size]
        z_where, z_pres = air.guide(X_batch, batch_size)
        inferred_counts = sum(z.cpu() for z in z_pres).squeeze().data
        true_counts_m = count_vec_to_mat(true_counts_batch, 2)
        inferred_counts_m = count_vec_to_mat(inferred_counts, 3)
        counts += torch.mm(true_counts_m.t(), inferred_counts_m)
        error_ind = 1 - (true_counts_batch == inferred_counts)
        error_ix = error_ind.nonzero().squeeze()
        error_latents.append(latents_to_tensor((z_where, z_pres)).index_select(0, error_ix))
        error_indicators.append(error_ind)

    acc = counts.diag().sum().float() / X.size(0)
    error_indices = torch.cat(error_indicators).nonzero().squeeze()
    if X.is_cuda:
        error_indices = error_indices.cuda()
    return acc, counts, torch.cat(error_latents), error_indices


# Defines something like a truncated geometric. Like the geometric,
# this has the property that there's a constant difference in log prob
# between p(steps=n) and p(steps=n+1).
def make_prior(k):
    assert 0 < k <= 1
    u = 1 / (1 + k + k**2 + k**3)
    p0 = 1 - u
    p1 = 1 - (k * u) / p0
    p2 = 1 - (k**2 * u) / (p0 * p1)
    trial_probs = [p0, p1, p2]
    # dist = [1 - p0, p0 * (1 - p1), p0 * p1 * (1 - p2), p0 * p1 * p2]
    # print(dist)
    return lambda t: trial_probs[t]


# Implements "prior annealing" as described in this blog post:
# http://akosiorek.github.io/ml/2017/09/03/implementing-air.html

# That implementation does something very close to the following:
# --z-pres-prior (1 - 1e-15)
# --z-pres-prior-raw
# --anneal-prior exp
# --anneal-prior-to 1e-7
# --anneal-prior-begin 1000
# --anneal-prior-duration 1e6

# e.g. After 200K steps z_pres_p will have decayed to ~0.04

# These compute the value of a decaying value at time t.
# initial: initial value
# final: final value, reached after begin + duration steps
# begin: number of steps before decay begins
# duration: number of steps over which decay occurs
# t: current time step


def lin_decay(initial, final, begin, duration, t):
    assert duration > 0
    x = (final - initial) * (t - begin) / duration + initial
    return max(min(x, initial), final)


def exp_decay(initial, final, begin, duration, t):
    assert final > 0
    assert duration > 0
    # half_life = math.log(2) / math.log(initial / final) * duration
    decay_rate = math.log(initial / final) / duration
    x = initial * math.exp(-decay_rate * (t - begin))
    return max(min(x, initial), final)

# %% [markdown]
# ## Args

# %%
parser = argparse.ArgumentParser(description="Pyro AIR example", argument_default=argparse.SUPPRESS)
parser.add_argument('-n', '--num-steps', type=int, default=int(1e8),
                    help='number of optimization steps to take')
parser.add_argument('-b', '--batch-size', type=int, default=64,
                    help='batch size')
parser.add_argument('-lr', '--learning-rate', type=float, default=1e-4,
                    help='learning rate')
parser.add_argument('-blr', '--baseline-learning-rate', type=float, default=1e-3,
                    help='baseline learning rate')
parser.add_argument('--progress-every', type=int, default=1,
                    help='number of steps between writing progress to stdout')
parser.add_argument('--eval-every', type=int, default=0,
                    help='number of steps between evaluations')
parser.add_argument('--baseline-scalar', type=float,
                    help='scale the output of the baseline nets by this value')
parser.add_argument('--no-baselines', action='store_true', default=False,
                    help='do not use data dependent baselines')
parser.add_argument('--encoder-net', type=int, nargs='+', default=[200],
                    help='encoder net hidden layer sizes')
parser.add_argument('--decoder-net', type=int, nargs='+', default=[200],
                    help='decoder net hidden layer sizes')
parser.add_argument('--predict-net', type=int, nargs='+',
                    help='predict net hidden layer sizes')
parser.add_argument('--embed-net', type=int, nargs='+',
                    help='embed net architecture')
parser.add_argument('--bl-predict-net', type=int, nargs='+',
                    help='baseline predict net hidden layer sizes')
parser.add_argument('--non-linearity', type=str,
                    help='non linearity to use throughout')
parser.add_argument('--viz', action='store_true', default=True,
                    help='generate vizualizations during optimization')
parser.add_argument('--viz-every', type=int, default=10,
                    help='number of steps between vizualizations')
parser.add_argument('--visdom-env', default='main',
                    help='visdom enviroment name')
parser.add_argument('--load', type=str,
                    help='load previously saved parameters')
parser.add_argument('--save', type=str,
                    help='save parameters to specified file')
parser.add_argument('--save-every', type=int, default=1e4,
                    help='number of steps between parameter saves')
parser.add_argument('--cuda', action='store_true', default=False,
                    help='use cuda')
parser.add_argument('--jit', action='store_true', default=False,
                    help='use PyTorch jit')
parser.add_argument('-t', '--model-steps', type=int, default=3,
                    help='number of time steps')
parser.add_argument('--rnn-hidden-size', type=int, default=256,
                    help='rnn hidden size')
parser.add_argument('--encoder-latent-size', type=int, default=50,
                    help='attention window encoder/decoder latent space size')
parser.add_argument('--decoder-output-bias', type=float,
                    help='bias added to decoder output (prior to applying non-linearity)')
parser.add_argument('--decoder-output-use-sigmoid', action='store_true',
                    help='apply sigmoid function to output of decoder network')
parser.add_argument('--window-size', type=int, default=28,
                    help='attention window size')
parser.add_argument('--z-pres-prior', type=float, default=0.5,
                    help='prior success probability for z_pres')
parser.add_argument('--z-pres-prior-raw', action='store_true', default=False,
                    help='use --z-pres-prior directly as success prob instead of a geometric like prior')
parser.add_argument('--anneal-prior', choices='none lin exp'.split(), default='none',
                    help='anneal z_pres prior during optimization')
parser.add_argument('--anneal-prior-to', type=float, default=1e-7,
                    help='target z_pres prior prob')
parser.add_argument('--anneal-prior-begin', type=int, default=0,
                    help='number of steps to wait before beginning to anneal the prior')
parser.add_argument('--anneal-prior-duration', type=int, default=100000,
                    help='number of steps over which to anneal the prior')
parser.add_argument('--pos-prior-mean', type=float,
                    help='mean of the window position prior')
parser.add_argument('--pos-prior-sd', type=float,
                    help='std. dev. of the window position prior')
parser.add_argument('--scale-prior-mean', type=float,
                    help='mean of the window scale prior')
parser.add_argument('--scale-prior-sd', type=float,
                    help='std. dev. of the window scale prior')
parser.add_argument('--no-masking', action='store_true', default=False,
                    help='do not mask out the costs of unused choices')
parser.add_argument('--seed', type=int, help='random seed', default=None)
parser.add_argument('-v', '--verbose', action='store_true', default=False,
                    help='write hyper parameters and network architecture to stdout')
# Out:
# _StoreTrueAction(option_strings=['-v', '--verbose'], dest='verbose', nargs=0, const=True, default=False, type=None, choices=None, help='write hyper parameters and network architecture to stdout', metavar=None)

# %%
# vars(parser.parse_args(""))
args = argparse.Namespace(**vars(parser.parse_args("")))

# %%
if 'save' in args:
    if os.path.exists(args.save):
        raise RuntimeError('Output file "{}" already exists.'.format(args.save))

if args.seed is not None:
    pyro.set_rng_seed(args.seed)

# Build a function to compute z_pres prior probabilities.
if args.z_pres_prior_raw:
    def base_z_pres_prior_p(t):
        return args.z_pres_prior
else:
    base_z_pres_prior_p = make_prior(args.z_pres_prior)

# Wrap with logic to apply any annealing.
def z_pres_prior_p(opt_step, time_step):
    p = base_z_pres_prior_p(time_step)
    if args.anneal_prior == 'none':
        return p
    else:
        decay = dict(lin=lin_decay, exp=exp_decay)[args.anneal_prior]
        return decay(p, args.anneal_prior_to, args.anneal_prior_begin,
                     args.anneal_prior_duration, opt_step)

# %% [markdown]
# ## Data loader

# %%
def load_data():
#     inpath = './air/.data'
#     X_np, Y = multi_mnist.load(inpath)
    X_np = np.load('/Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/data/ANTS2/masks_50x50.npy')
    X_np = X_np.astype(np.float32)
    X_np /= 255.0
    X = torch.from_numpy(X_np)
    # Using FloatTensor to allow comparison with values sampled from
    # Bernoulli.
    counts = torch.FloatTensor([1 for objs in X_np])
    return X, counts

# %%
X, true_counts = load_data()
X_size = X.size(0)
if args.cuda:
    X = X.cuda()

# %%
X.shape
# Out:
# torch.Size([5339, 50, 50])

# %% [markdown]
# ## Model

# %%
model_arg_keys = ['window_size',
                  'rnn_hidden_size',
                  'decoder_output_bias',
                  'decoder_output_use_sigmoid',
                  'baseline_scalar',
                  'encoder_net',
                  'decoder_net',
                  'predict_net',
                  'embed_net',
                  'bl_predict_net',
                  'non_linearity',
                  'pos_prior_mean',
                  'pos_prior_sd',
                  'scale_prior_mean',
                  'scale_prior_sd']
model_args = {key: getattr(args, key) for key in model_arg_keys if key in args}

# %%
air = AIR(
        num_steps=args.model_steps,
        x_size=50,
        use_masking=not args.no_masking,
        use_baselines=not args.no_baselines,
        z_what_size=args.encoder_latent_size,
        use_cuda=args.cuda,
        **model_args
    )

# %%
if 'load' in args:
    print('Loading parameters...')
    air.load_state_dict(torch.load(args.load))

# %% [markdown]
# ## Visualize

# %%
if args.viz:
    vis = visdom.Visdom(env=args.visdom_env)
    z, x = air.prior(5, z_pres_prior_p=partial(z_pres_prior_p, 0))
    vis.images(draw_many(x, tensor_to_objs(latents_to_tensor(z))))
# Out:
# Setting up a new session...
# /Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/nn/functional.py:2764: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/nn/functional.py:2705: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "

# %% [markdown]
# ## Optimizer

# %%
def isBaselineParam(module_name, param_name):
    return 'bl_' in module_name or 'bl_' in param_name

def per_param_optim_args(module_name, param_name):
    lr = args.baseline_learning_rate if isBaselineParam(module_name, param_name) else args.learning_rate
    return {'lr': lr}

adam = optim.Adam(per_param_optim_args)
elbo = JitTraceGraph_ELBO() if args.jit else TraceGraph_ELBO()
svi = SVI(air.model, air.guide, adam, loss=elbo)

# %%
t0 = time.time()
examples_to_viz = X[5:10]

for i in range(1, args.num_steps + 1):

    loss = svi.step(X, batch_size=args.batch_size, z_pres_prior_p=partial(z_pres_prior_p, i))

    if args.progress_every > 0 and i % args.progress_every == 0:
        print('i={}, epochs={:.2f}, elapsed={:.2f}, elbo={:.2f}'.format(
            i,
            (i * args.batch_size) / X_size,
            (time.time() - t0) / 3600,
            loss / X_size))

    if args.viz and i % args.viz_every == 0:
        trace = poutine.trace(air.guide).get_trace(examples_to_viz, None)
        z, recons = poutine.replay(air.prior, trace=trace)(examples_to_viz.size(0))
        z_wheres = tensor_to_objs(latents_to_tensor(z))

        # Show data with inferred objection positions.
        vis.images(draw_many(examples_to_viz, z_wheres))
        # Show reconstructions of data.
        vis.images(draw_many(recons, z_wheres))

    if args.eval_every > 0 and i % args.eval_every == 0:
        # Measure accuracy on subset of training data.
        acc, counts, error_z, error_ix = count_accuracy(X, true_counts, air, 1000)
        print('i={}, accuracy={}, counts={}'.format(i, acc, counts.numpy().tolist()))
        if args.viz and error_ix.size(0) > 0:
            vis.images(draw_many(X[error_ix[0:5]], tensor_to_objs(error_z[0:5])),
                       opts=dict(caption='errors ({})'.format(i)))

    if 'save' in args and i % args.save_every == 0:
        print('Saving parameters...')
        torch.save(air.state_dict(), args.save)
# Out:
# i=1, epochs=0.01, elapsed=0.00, elbo=-680.42
# i=2, epochs=0.02, elapsed=0.00, elbo=-679.05
# i=3, epochs=0.04, elapsed=0.00, elbo=-678.41
# i=4, epochs=0.05, elapsed=0.00, elbo=-678.74
# i=5, epochs=0.06, elapsed=0.00, elbo=-682.42
# i=6, epochs=0.07, elapsed=0.00, elbo=-681.29
# i=7, epochs=0.08, elapsed=0.00, elbo=-685.39
# i=8, epochs=0.10, elapsed=0.00, elbo=-684.21
# i=9, epochs=0.11, elapsed=0.00, elbo=-678.91
# i=10, epochs=0.12, elapsed=0.00, elbo=-681.83
# i=11, epochs=0.13, elapsed=0.00, elbo=-683.92
# i=12, epochs=0.14, elapsed=0.00, elbo=-688.95
# i=13, epochs=0.16, elapsed=0.00, elbo=-682.25
# i=14, epochs=0.17, elapsed=0.00, elbo=-679.49
# i=15, epochs=0.18, elapsed=0.00, elbo=-689.83
# i=16, epochs=0.19, elapsed=0.00, elbo=-678.59
# i=17, epochs=0.20, elapsed=0.00, elbo=-689.76
# i=18, epochs=0.22, elapsed=0.00, elbo=-685.74
# i=19, epochs=0.23, elapsed=0.00, elbo=-679.95
# i=20, epochs=0.24, elapsed=0.00, elbo=-681.76
# i=21, epochs=0.25, elapsed=0.00, elbo=-684.12
# i=22, epochs=0.26, elapsed=0.00, elbo=-685.41
# i=23, epochs=0.28, elapsed=0.00, elbo=-687.47
# i=24, epochs=0.29, elapsed=0.00, elbo=-684.10
# i=25, epochs=0.30, elapsed=0.00, elbo=-686.93
# i=26, epochs=0.31, elapsed=0.00, elbo=-682.87
# i=27, epochs=0.32, elapsed=0.00, elbo=-681.55
# i=28, epochs=0.34, elapsed=0.00, elbo=-687.37
# i=29, epochs=0.35, elapsed=0.00, elbo=-682.94
# i=30, epochs=0.36, elapsed=0.00, elbo=-686.06
# i=31, epochs=0.37, elapsed=0.00, elbo=-687.92
# i=32, epochs=0.38, elapsed=0.00, elbo=-686.65
# i=33, epochs=0.40, elapsed=0.00, elbo=-684.73
# i=34, epochs=0.41, elapsed=0.00, elbo=-682.79
# i=35, epochs=0.42, elapsed=0.00, elbo=-685.91
# i=36, epochs=0.43, elapsed=0.00, elbo=-685.99
# i=37, epochs=0.44, elapsed=0.00, elbo=-689.82
# i=38, epochs=0.46, elapsed=0.00, elbo=-689.13
# i=39, epochs=0.47, elapsed=0.00, elbo=-680.83
# i=40, epochs=0.48, elapsed=0.00, elbo=-689.87
# i=41, epochs=0.49, elapsed=0.00, elbo=-686.13
# i=42, epochs=0.50, elapsed=0.00, elbo=-686.72
# i=43, epochs=0.52, elapsed=0.00, elbo=-690.29
# i=44, epochs=0.53, elapsed=0.00, elbo=-685.73
# i=45, epochs=0.54, elapsed=0.00, elbo=-685.50
# i=46, epochs=0.55, elapsed=0.00, elbo=-689.15
# i=47, epochs=0.56, elapsed=0.00, elbo=-686.17
# i=48, epochs=0.58, elapsed=0.00, elbo=-688.97
# i=49, epochs=0.59, elapsed=0.00, elbo=-689.24
# i=50, epochs=0.60, elapsed=0.00, elbo=-685.76
# i=51, epochs=0.61, elapsed=0.00, elbo=-690.29
# i=52, epochs=0.62, elapsed=0.00, elbo=-688.37
# i=53, epochs=0.64, elapsed=0.00, elbo=-689.34
# i=54, epochs=0.65, elapsed=0.00, elbo=-691.16
# i=55, epochs=0.66, elapsed=0.00, elbo=-687.57
# i=56, epochs=0.67, elapsed=0.00, elbo=-693.54
# i=57, epochs=0.68, elapsed=0.00, elbo=-688.45
# i=58, epochs=0.70, elapsed=0.00, elbo=-685.77
# i=59, epochs=0.71, elapsed=0.00, elbo=-688.68
# i=60, epochs=0.72, elapsed=0.00, elbo=-691.89
# i=61, epochs=0.73, elapsed=0.00, elbo=-686.01
# i=62, epochs=0.74, elapsed=0.00, elbo=-690.95
# i=63, epochs=0.76, elapsed=0.00, elbo=-686.02
# i=64, epochs=0.77, elapsed=0.00, elbo=-696.14
# i=65, epochs=0.78, elapsed=0.00, elbo=-688.65
# i=66, epochs=0.79, elapsed=0.00, elbo=-687.29
# i=67, epochs=0.80, elapsed=0.00, elbo=-689.00
# i=68, epochs=0.82, elapsed=0.00, elbo=-687.26
# i=69, epochs=0.83, elapsed=0.00, elbo=-693.30
# i=70, epochs=0.84, elapsed=0.00, elbo=-690.74
# i=71, epochs=0.85, elapsed=0.00, elbo=-688.49
# i=72, epochs=0.86, elapsed=0.00, elbo=-687.05
# i=73, epochs=0.88, elapsed=0.00, elbo=-686.74
# i=74, epochs=0.89, elapsed=0.00, elbo=-689.68
# i=75, epochs=0.90, elapsed=0.00, elbo=-691.98
# i=76, epochs=0.91, elapsed=0.00, elbo=-690.72
# i=77, epochs=0.92, elapsed=0.00, elbo=-687.34
# i=78, epochs=0.94, elapsed=0.00, elbo=-689.02
# i=79, epochs=0.95, elapsed=0.00, elbo=-688.52
# i=80, epochs=0.96, elapsed=0.00, elbo=-689.04
# i=81, epochs=0.97, elapsed=0.00, elbo=-690.45
# i=82, epochs=0.98, elapsed=0.00, elbo=-692.13
# i=83, epochs=0.99, elapsed=0.00, elbo=-695.40
# i=84, epochs=1.01, elapsed=0.00, elbo=-688.81
# i=85, epochs=1.02, elapsed=0.00, elbo=-689.38
# i=86, epochs=1.03, elapsed=0.00, elbo=-685.93
# i=87, epochs=1.04, elapsed=0.00, elbo=-691.05
# i=88, epochs=1.05, elapsed=0.00, elbo=-690.92
# i=89, epochs=1.07, elapsed=0.00, elbo=-687.80
# i=90, epochs=1.08, elapsed=0.00, elbo=-689.03
# i=91, epochs=1.09, elapsed=0.00, elbo=-685.00
# i=92, epochs=1.10, elapsed=0.00, elbo=-691.28
# i=93, epochs=1.11, elapsed=0.00, elbo=-689.57
# i=94, epochs=1.13, elapsed=0.00, elbo=-687.65
# i=95, epochs=1.14, elapsed=0.00, elbo=-691.59
# i=96, epochs=1.15, elapsed=0.00, elbo=-685.66
# i=97, epochs=1.16, elapsed=0.00, elbo=-689.35
# i=98, epochs=1.17, elapsed=0.00, elbo=-688.22
# i=99, epochs=1.19, elapsed=0.01, elbo=-691.44
# i=100, epochs=1.20, elapsed=0.01, elbo=-694.48
# i=101, epochs=1.21, elapsed=0.01, elbo=-687.26
# i=102, epochs=1.22, elapsed=0.01, elbo=-693.26
# i=103, epochs=1.23, elapsed=0.01, elbo=-688.99
# i=104, epochs=1.25, elapsed=0.01, elbo=-686.54
# i=105, epochs=1.26, elapsed=0.01, elbo=-685.90
# i=106, epochs=1.27, elapsed=0.01, elbo=-691.56
# i=107, epochs=1.28, elapsed=0.01, elbo=-690.28
# i=108, epochs=1.29, elapsed=0.01, elbo=-686.59
# i=109, epochs=1.31, elapsed=0.01, elbo=-685.98
# i=110, epochs=1.32, elapsed=0.01, elbo=-686.95
# i=111, epochs=1.33, elapsed=0.01, elbo=-692.90
# i=112, epochs=1.34, elapsed=0.01, elbo=-691.41
# i=113, epochs=1.35, elapsed=0.01, elbo=-689.56
# i=114, epochs=1.37, elapsed=0.01, elbo=-692.48
# i=115, epochs=1.38, elapsed=0.01, elbo=-691.85
# i=116, epochs=1.39, elapsed=0.01, elbo=-686.42
# i=117, epochs=1.40, elapsed=0.01, elbo=-689.88
# i=118, epochs=1.41, elapsed=0.01, elbo=-690.51
# i=119, epochs=1.43, elapsed=0.01, elbo=-689.54
# i=120, epochs=1.44, elapsed=0.01, elbo=-692.59
# i=121, epochs=1.45, elapsed=0.01, elbo=-694.57
# i=122, epochs=1.46, elapsed=0.01, elbo=-690.65
# i=123, epochs=1.47, elapsed=0.01, elbo=-691.38
# i=124, epochs=1.49, elapsed=0.01, elbo=-692.42
# i=125, epochs=1.50, elapsed=0.01, elbo=-691.52
# i=126, epochs=1.51, elapsed=0.01, elbo=-690.89
# i=127, epochs=1.52, elapsed=0.01, elbo=-693.99
# i=128, epochs=1.53, elapsed=0.01, elbo=-691.61
# i=129, epochs=1.55, elapsed=0.01, elbo=-692.49
# i=130, epochs=1.56, elapsed=0.01, elbo=-691.11
# i=131, epochs=1.57, elapsed=0.01, elbo=-692.02
# i=132, epochs=1.58, elapsed=0.01, elbo=-691.13
# i=133, epochs=1.59, elapsed=0.01, elbo=-691.44
# i=134, epochs=1.61, elapsed=0.01, elbo=-685.61
# i=135, epochs=1.62, elapsed=0.01, elbo=-690.62
# i=136, epochs=1.63, elapsed=0.01, elbo=-692.77
# i=137, epochs=1.64, elapsed=0.01, elbo=-691.17
# i=138, epochs=1.65, elapsed=0.01, elbo=-691.49
# i=139, epochs=1.67, elapsed=0.01, elbo=-693.07
# i=140, epochs=1.68, elapsed=0.01, elbo=-690.94
# i=141, epochs=1.69, elapsed=0.01, elbo=-692.19
# i=142, epochs=1.70, elapsed=0.01, elbo=-690.73
# i=143, epochs=1.71, elapsed=0.01, elbo=-688.66
# i=144, epochs=1.73, elapsed=0.01, elbo=-693.95
# i=145, epochs=1.74, elapsed=0.01, elbo=-693.38
# i=146, epochs=1.75, elapsed=0.01, elbo=-692.91
# i=147, epochs=1.76, elapsed=0.01, elbo=-691.77
# i=148, epochs=1.77, elapsed=0.01, elbo=-688.16
# i=149, epochs=1.79, elapsed=0.01, elbo=-689.44
# i=150, epochs=1.80, elapsed=0.01, elbo=-692.42
# i=151, epochs=1.81, elapsed=0.01, elbo=-691.19
# i=152, epochs=1.82, elapsed=0.01, elbo=-695.35
# i=153, epochs=1.83, elapsed=0.01, elbo=-695.97
# i=154, epochs=1.85, elapsed=0.01, elbo=-693.27
# i=155, epochs=1.86, elapsed=0.01, elbo=-689.80
# i=156, epochs=1.87, elapsed=0.01, elbo=-695.53
# i=157, epochs=1.88, elapsed=0.01, elbo=-691.82
# i=158, epochs=1.89, elapsed=0.01, elbo=-690.31
# i=159, epochs=1.91, elapsed=0.01, elbo=-694.07
# i=160, epochs=1.92, elapsed=0.01, elbo=-692.40
# i=161, epochs=1.93, elapsed=0.01, elbo=-689.06
# i=162, epochs=1.94, elapsed=0.01, elbo=-690.74
# i=163, epochs=1.95, elapsed=0.01, elbo=-689.54
# i=164, epochs=1.97, elapsed=0.01, elbo=-694.65
# i=165, epochs=1.98, elapsed=0.01, elbo=-690.66
# i=166, epochs=1.99, elapsed=0.01, elbo=-689.96
# i=167, epochs=2.00, elapsed=0.01, elbo=-688.75
# i=168, epochs=2.01, elapsed=0.01, elbo=-689.51
# i=169, epochs=2.03, elapsed=0.01, elbo=-692.17
# i=170, epochs=2.04, elapsed=0.01, elbo=-694.13
# i=171, epochs=2.05, elapsed=0.01, elbo=-695.34
# i=172, epochs=2.06, elapsed=0.01, elbo=-691.58
# i=173, epochs=2.07, elapsed=0.01, elbo=-695.33
# i=174, epochs=2.09, elapsed=0.01, elbo=-692.07
# i=175, epochs=2.10, elapsed=0.01, elbo=-691.96
# i=176, epochs=2.11, elapsed=0.01, elbo=-693.91
# i=177, epochs=2.12, elapsed=0.01, elbo=-692.42
# i=178, epochs=2.13, elapsed=0.01, elbo=-692.43
# i=179, epochs=2.15, elapsed=0.01, elbo=-694.62
# i=180, epochs=2.16, elapsed=0.01, elbo=-692.25
# i=181, epochs=2.17, elapsed=0.01, elbo=-689.71
# i=182, epochs=2.18, elapsed=0.01, elbo=-691.09
# i=183, epochs=2.19, elapsed=0.01, elbo=-691.85
# i=184, epochs=2.21, elapsed=0.01, elbo=-695.07
# i=185, epochs=2.22, elapsed=0.01, elbo=-690.82
# i=186, epochs=2.23, elapsed=0.01, elbo=-693.75
# i=187, epochs=2.24, elapsed=0.01, elbo=-688.88
# i=188, epochs=2.25, elapsed=0.01, elbo=-694.11
# i=189, epochs=2.27, elapsed=0.01, elbo=-693.01
# i=190, epochs=2.28, elapsed=0.01, elbo=-693.20
# i=191, epochs=2.29, elapsed=0.01, elbo=-693.64
# i=192, epochs=2.30, elapsed=0.01, elbo=-689.25
# i=193, epochs=2.31, elapsed=0.01, elbo=-692.45
# i=194, epochs=2.33, elapsed=0.01, elbo=-694.92
# i=195, epochs=2.34, elapsed=0.01, elbo=-692.96
# i=196, epochs=2.35, elapsed=0.01, elbo=-694.56
# i=197, epochs=2.36, elapsed=0.01, elbo=-694.36
# i=198, epochs=2.37, elapsed=0.01, elbo=-692.30
# i=199, epochs=2.39, elapsed=0.01, elbo=-693.89
# i=200, epochs=2.40, elapsed=0.01, elbo=-695.55
# i=201, epochs=2.41, elapsed=0.01, elbo=-693.65
# i=202, epochs=2.42, elapsed=0.01, elbo=-690.48
# i=203, epochs=2.43, elapsed=0.01, elbo=-691.53
# i=204, epochs=2.45, elapsed=0.01, elbo=-694.89
# i=205, epochs=2.46, elapsed=0.01, elbo=-694.14
# i=206, epochs=2.47, elapsed=0.01, elbo=-694.17
# i=207, epochs=2.48, elapsed=0.01, elbo=-696.25
# i=208, epochs=2.49, elapsed=0.01, elbo=-693.47
# i=209, epochs=2.51, elapsed=0.01, elbo=-690.76
# i=210, epochs=2.52, elapsed=0.01, elbo=-692.60
# i=211, epochs=2.53, elapsed=0.01, elbo=-692.45
# i=212, epochs=2.54, elapsed=0.01, elbo=-693.85
# i=213, epochs=2.55, elapsed=0.01, elbo=-693.96
# i=214, epochs=2.57, elapsed=0.01, elbo=-694.25
# i=215, epochs=2.58, elapsed=0.01, elbo=-691.83
# i=216, epochs=2.59, elapsed=0.01, elbo=-691.59
# i=217, epochs=2.60, elapsed=0.01, elbo=-690.66
# i=218, epochs=2.61, elapsed=0.01, elbo=-695.45
# i=219, epochs=2.63, elapsed=0.01, elbo=-694.60
# i=220, epochs=2.64, elapsed=0.01, elbo=-694.01
# i=221, epochs=2.65, elapsed=0.01, elbo=-695.56
# i=222, epochs=2.66, elapsed=0.01, elbo=-693.09
# i=223, epochs=2.67, elapsed=0.01, elbo=-696.35
# i=224, epochs=2.69, elapsed=0.01, elbo=-690.51
# i=225, epochs=2.70, elapsed=0.01, elbo=-695.41
# i=226, epochs=2.71, elapsed=0.01, elbo=-691.09
# i=227, epochs=2.72, elapsed=0.01, elbo=-695.48
# i=228, epochs=2.73, elapsed=0.01, elbo=-692.38
# i=229, epochs=2.75, elapsed=0.01, elbo=-691.81
# i=230, epochs=2.76, elapsed=0.01, elbo=-695.37
# i=231, epochs=2.77, elapsed=0.01, elbo=-693.66
# i=232, epochs=2.78, elapsed=0.01, elbo=-694.64
# i=233, epochs=2.79, elapsed=0.01, elbo=-695.86
# i=234, epochs=2.81, elapsed=0.01, elbo=-693.58
# i=235, epochs=2.82, elapsed=0.01, elbo=-692.38
# i=236, epochs=2.83, elapsed=0.01, elbo=-694.02
# i=237, epochs=2.84, elapsed=0.01, elbo=-694.09
# i=238, epochs=2.85, elapsed=0.01, elbo=-696.49
# i=239, epochs=2.86, elapsed=0.01, elbo=-692.82
# i=240, epochs=2.88, elapsed=0.01, elbo=-695.27
# i=241, epochs=2.89, elapsed=0.01, elbo=-690.26
# i=242, epochs=2.90, elapsed=0.01, elbo=-696.18
# i=243, epochs=2.91, elapsed=0.01, elbo=-695.85
# i=244, epochs=2.92, elapsed=0.01, elbo=-689.90
# i=245, epochs=2.94, elapsed=0.01, elbo=-694.09
# i=246, epochs=2.95, elapsed=0.01, elbo=-693.01
# i=247, epochs=2.96, elapsed=0.01, elbo=-694.02
# i=248, epochs=2.97, elapsed=0.01, elbo=-691.96
# i=249, epochs=2.98, elapsed=0.01, elbo=-692.82
# i=250, epochs=3.00, elapsed=0.01, elbo=-695.73
# i=251, epochs=3.01, elapsed=0.01, elbo=-692.99
# i=252, epochs=3.02, elapsed=0.01, elbo=-693.11
# i=253, epochs=3.03, elapsed=0.01, elbo=-693.15
# i=254, epochs=3.04, elapsed=0.01, elbo=-693.87
# i=255, epochs=3.06, elapsed=0.01, elbo=-692.55
# i=256, epochs=3.07, elapsed=0.01, elbo=-695.91
# i=257, epochs=3.08, elapsed=0.01, elbo=-693.44
# i=258, epochs=3.09, elapsed=0.01, elbo=-695.98
# i=259, epochs=3.10, elapsed=0.01, elbo=-691.47
# i=260, epochs=3.12, elapsed=0.01, elbo=-693.28
# i=261, epochs=3.13, elapsed=0.01, elbo=-692.91
# i=262, epochs=3.14, elapsed=0.01, elbo=-692.98
# i=263, epochs=3.15, elapsed=0.01, elbo=-693.36
# i=264, epochs=3.16, elapsed=0.01, elbo=-694.02
# i=265, epochs=3.18, elapsed=0.01, elbo=-694.77
# i=266, epochs=3.19, elapsed=0.01, elbo=-696.87
# i=267, epochs=3.20, elapsed=0.01, elbo=-694.21
# i=268, epochs=3.21, elapsed=0.01, elbo=-695.22
# i=269, epochs=3.22, elapsed=0.01, elbo=-691.02
# i=270, epochs=3.24, elapsed=0.01, elbo=-696.01
# i=271, epochs=3.25, elapsed=0.01, elbo=-694.69
# i=272, epochs=3.26, elapsed=0.01, elbo=-694.44
# i=273, epochs=3.27, elapsed=0.01, elbo=-692.30
# i=274, epochs=3.28, elapsed=0.01, elbo=-696.61
# i=275, epochs=3.30, elapsed=0.01, elbo=-697.17
# i=276, epochs=3.31, elapsed=0.01, elbo=-696.22
# i=277, epochs=3.32, elapsed=0.01, elbo=-694.22
# i=278, epochs=3.33, elapsed=0.01, elbo=-692.27
# i=279, epochs=3.34, elapsed=0.01, elbo=-692.41
# i=280, epochs=3.36, elapsed=0.01, elbo=-692.74
# i=281, epochs=3.37, elapsed=0.01, elbo=-693.93
# i=282, epochs=3.38, elapsed=0.01, elbo=-697.68
# i=283, epochs=3.39, elapsed=0.01, elbo=-696.37
# i=284, epochs=3.40, elapsed=0.01, elbo=-695.35
# i=285, epochs=3.42, elapsed=0.01, elbo=-698.43
# i=286, epochs=3.43, elapsed=0.01, elbo=-694.68
# i=287, epochs=3.44, elapsed=0.01, elbo=-696.32
# i=288, epochs=3.45, elapsed=0.01, elbo=-697.48
# i=289, epochs=3.46, elapsed=0.01, elbo=-692.03
# i=290, epochs=3.48, elapsed=0.02, elbo=-695.04
# i=291, epochs=3.49, elapsed=0.02, elbo=-695.87
# i=292, epochs=3.50, elapsed=0.02, elbo=-699.09
# i=293, epochs=3.51, elapsed=0.02, elbo=-694.79
# i=294, epochs=3.52, elapsed=0.02, elbo=-694.27
# i=295, epochs=3.54, elapsed=0.02, elbo=-692.59
# i=296, epochs=3.55, elapsed=0.02, elbo=-695.32
# i=297, epochs=3.56, elapsed=0.02, elbo=-694.05
# i=298, epochs=3.57, elapsed=0.02, elbo=-696.53
# i=299, epochs=3.58, elapsed=0.02, elbo=-695.16
# i=300, epochs=3.60, elapsed=0.02, elbo=-693.75
# i=301, epochs=3.61, elapsed=0.02, elbo=-694.65
# i=302, epochs=3.62, elapsed=0.02, elbo=-694.48
# i=303, epochs=3.63, elapsed=0.02, elbo=-696.03
# i=304, epochs=3.64, elapsed=0.02, elbo=-693.90
# i=305, epochs=3.66, elapsed=0.02, elbo=-696.29
# i=306, epochs=3.67, elapsed=0.02, elbo=-695.58
# i=307, epochs=3.68, elapsed=0.02, elbo=-696.55
# i=308, epochs=3.69, elapsed=0.02, elbo=-696.78
# i=309, epochs=3.70, elapsed=0.02, elbo=-695.20
# i=310, epochs=3.72, elapsed=0.02, elbo=-692.68
# i=311, epochs=3.73, elapsed=0.02, elbo=-695.43
# i=312, epochs=3.74, elapsed=0.02, elbo=-696.35
# i=313, epochs=3.75, elapsed=0.02, elbo=-695.10
# i=314, epochs=3.76, elapsed=0.02, elbo=-697.65
# i=315, epochs=3.78, elapsed=0.02, elbo=-693.58
# i=316, epochs=3.79, elapsed=0.02, elbo=-698.75
# i=317, epochs=3.80, elapsed=0.02, elbo=-694.76
# i=318, epochs=3.81, elapsed=0.02, elbo=-694.76
# i=319, epochs=3.82, elapsed=0.02, elbo=-694.74
# i=320, epochs=3.84, elapsed=0.02, elbo=-696.70
# i=321, epochs=3.85, elapsed=0.02, elbo=-694.31
# i=322, epochs=3.86, elapsed=0.02, elbo=-694.66
# i=323, epochs=3.87, elapsed=0.02, elbo=-694.65
# i=324, epochs=3.88, elapsed=0.02, elbo=-694.36
# i=325, epochs=3.90, elapsed=0.02, elbo=-698.99
# i=326, epochs=3.91, elapsed=0.02, elbo=-688.77
# i=327, epochs=3.92, elapsed=0.02, elbo=-695.19
# i=328, epochs=3.93, elapsed=0.02, elbo=-696.10
# i=329, epochs=3.94, elapsed=0.02, elbo=-696.80
# i=330, epochs=3.96, elapsed=0.02, elbo=-696.22
# i=331, epochs=3.97, elapsed=0.02, elbo=-696.13
# i=332, epochs=3.98, elapsed=0.02, elbo=-696.64
# i=333, epochs=3.99, elapsed=0.02, elbo=-696.00
# i=334, epochs=4.00, elapsed=0.02, elbo=-695.92
# i=335, epochs=4.02, elapsed=0.02, elbo=-694.56
# i=336, epochs=4.03, elapsed=0.02, elbo=-693.08
# i=337, epochs=4.04, elapsed=0.02, elbo=-695.75
# i=338, epochs=4.05, elapsed=0.02, elbo=-695.62
# i=339, epochs=4.06, elapsed=0.02, elbo=-697.15
# i=340, epochs=4.08, elapsed=0.02, elbo=-695.20
# i=341, epochs=4.09, elapsed=0.02, elbo=-694.05
# i=342, epochs=4.10, elapsed=0.02, elbo=-695.58
# i=343, epochs=4.11, elapsed=0.02, elbo=-698.35
# i=344, epochs=4.12, elapsed=0.02, elbo=-699.98
# i=345, epochs=4.14, elapsed=0.02, elbo=-695.46
# i=346, epochs=4.15, elapsed=0.02, elbo=-696.04
# i=347, epochs=4.16, elapsed=0.02, elbo=-697.52
# i=348, epochs=4.17, elapsed=0.02, elbo=-696.28
# i=349, epochs=4.18, elapsed=0.02, elbo=-696.62
# i=350, epochs=4.20, elapsed=0.02, elbo=-694.99
# i=351, epochs=4.21, elapsed=0.02, elbo=-698.33
# i=352, epochs=4.22, elapsed=0.02, elbo=-698.51
# i=353, epochs=4.23, elapsed=0.02, elbo=-696.83
# i=354, epochs=4.24, elapsed=0.02, elbo=-694.20
# i=355, epochs=4.26, elapsed=0.02, elbo=-695.41
# i=356, epochs=4.27, elapsed=0.02, elbo=-697.81
# i=357, epochs=4.28, elapsed=0.02, elbo=-695.69
# i=358, epochs=4.29, elapsed=0.02, elbo=-695.36
# i=359, epochs=4.30, elapsed=0.02, elbo=-697.42
# i=360, epochs=4.32, elapsed=0.02, elbo=-696.73
# i=361, epochs=4.33, elapsed=0.02, elbo=-694.22
# i=362, epochs=4.34, elapsed=0.02, elbo=-694.50
# i=363, epochs=4.35, elapsed=0.02, elbo=-694.97
# i=364, epochs=4.36, elapsed=0.02, elbo=-697.42
# i=365, epochs=4.38, elapsed=0.02, elbo=-697.87
# i=366, epochs=4.39, elapsed=0.02, elbo=-694.05
# i=367, epochs=4.40, elapsed=0.02, elbo=-696.58
# i=368, epochs=4.41, elapsed=0.02, elbo=-692.42
# i=369, epochs=4.42, elapsed=0.02, elbo=-698.59
# i=370, epochs=4.44, elapsed=0.02, elbo=-696.65
# i=371, epochs=4.45, elapsed=0.02, elbo=-695.82
# i=372, epochs=4.46, elapsed=0.02, elbo=-695.04
# i=373, epochs=4.47, elapsed=0.02, elbo=-696.46
# i=374, epochs=4.48, elapsed=0.02, elbo=-695.37
# i=375, epochs=4.50, elapsed=0.02, elbo=-695.78
# i=376, epochs=4.51, elapsed=0.02, elbo=-694.01
# i=377, epochs=4.52, elapsed=0.02, elbo=-694.20
# i=378, epochs=4.53, elapsed=0.02, elbo=-694.06
# i=379, epochs=4.54, elapsed=0.02, elbo=-697.40
# i=380, epochs=4.56, elapsed=0.02, elbo=-696.29
# i=381, epochs=4.57, elapsed=0.02, elbo=-695.96
# i=382, epochs=4.58, elapsed=0.02, elbo=-698.44
# i=383, epochs=4.59, elapsed=0.02, elbo=-695.14
# i=384, epochs=4.60, elapsed=0.02, elbo=-697.71
# i=385, epochs=4.62, elapsed=0.02, elbo=-696.37
# i=386, epochs=4.63, elapsed=0.02, elbo=-695.76
# i=387, epochs=4.64, elapsed=0.02, elbo=-696.29
# i=388, epochs=4.65, elapsed=0.02, elbo=-696.42
# i=389, epochs=4.66, elapsed=0.02, elbo=-695.11
# i=390, epochs=4.68, elapsed=0.02, elbo=-694.94
# i=391, epochs=4.69, elapsed=0.02, elbo=-696.06
# i=392, epochs=4.70, elapsed=0.02, elbo=-694.81
# i=393, epochs=4.71, elapsed=0.02, elbo=-696.18
# i=394, epochs=4.72, elapsed=0.02, elbo=-696.91
# i=395, epochs=4.73, elapsed=0.02, elbo=-697.06
# i=396, epochs=4.75, elapsed=0.02, elbo=-696.76
# i=397, epochs=4.76, elapsed=0.02, elbo=-695.52
# i=398, epochs=4.77, elapsed=0.02, elbo=-699.22
# i=399, epochs=4.78, elapsed=0.02, elbo=-696.30
# i=400, epochs=4.79, elapsed=0.02, elbo=-696.37
# i=401, epochs=4.81, elapsed=0.02, elbo=-696.62
# i=402, epochs=4.82, elapsed=0.02, elbo=-697.42
# i=403, epochs=4.83, elapsed=0.02, elbo=-696.28
# i=404, epochs=4.84, elapsed=0.02, elbo=-696.41
# i=405, epochs=4.85, elapsed=0.02, elbo=-695.06
# i=406, epochs=4.87, elapsed=0.02, elbo=-696.76
# i=407, epochs=4.88, elapsed=0.02, elbo=-696.07
# i=408, epochs=4.89, elapsed=0.02, elbo=-696.11
# i=409, epochs=4.90, elapsed=0.02, elbo=-696.04
# i=410, epochs=4.91, elapsed=0.02, elbo=-698.45
# i=411, epochs=4.93, elapsed=0.02, elbo=-698.36
# i=412, epochs=4.94, elapsed=0.02, elbo=-694.25
# i=413, epochs=4.95, elapsed=0.02, elbo=-698.10
# i=414, epochs=4.96, elapsed=0.02, elbo=-695.29
# i=415, epochs=4.97, elapsed=0.02, elbo=-697.06
# i=416, epochs=4.99, elapsed=0.02, elbo=-695.57
# i=417, epochs=5.00, elapsed=0.02, elbo=-697.06
# i=418, epochs=5.01, elapsed=0.02, elbo=-696.57
# i=419, epochs=5.02, elapsed=0.02, elbo=-697.69
# i=420, epochs=5.03, elapsed=0.02, elbo=-695.86
# i=421, epochs=5.05, elapsed=0.02, elbo=-696.19
# i=422, epochs=5.06, elapsed=0.02, elbo=-697.06
# i=423, epochs=5.07, elapsed=0.02, elbo=-697.53
# i=424, epochs=5.08, elapsed=0.02, elbo=-696.90
# i=425, epochs=5.09, elapsed=0.02, elbo=-696.96
# i=426, epochs=5.11, elapsed=0.02, elbo=-695.95
# i=427, epochs=5.12, elapsed=0.02, elbo=-696.76
# i=428, epochs=5.13, elapsed=0.02, elbo=-697.59
# i=429, epochs=5.14, elapsed=0.02, elbo=-697.86
# i=430, epochs=5.15, elapsed=0.02, elbo=-697.45
# i=431, epochs=5.17, elapsed=0.02, elbo=-696.95
# i=432, epochs=5.18, elapsed=0.02, elbo=-695.75
# i=433, epochs=5.19, elapsed=0.02, elbo=-697.75
# i=434, epochs=5.20, elapsed=0.02, elbo=-698.19
# i=435, epochs=5.21, elapsed=0.02, elbo=-696.03
# i=436, epochs=5.23, elapsed=0.02, elbo=-697.58
# i=437, epochs=5.24, elapsed=0.02, elbo=-697.42
# i=438, epochs=5.25, elapsed=0.02, elbo=-696.83
# i=439, epochs=5.26, elapsed=0.02, elbo=-696.20
# i=440, epochs=5.27, elapsed=0.02, elbo=-698.04
# i=441, epochs=5.29, elapsed=0.02, elbo=-696.30
# i=442, epochs=5.30, elapsed=0.02, elbo=-697.91
# i=443, epochs=5.31, elapsed=0.02, elbo=-697.67
# i=444, epochs=5.32, elapsed=0.02, elbo=-697.59
# i=445, epochs=5.33, elapsed=0.02, elbo=-699.01
# i=446, epochs=5.35, elapsed=0.02, elbo=-693.66
# i=447, epochs=5.36, elapsed=0.02, elbo=-698.32
# i=448, epochs=5.37, elapsed=0.02, elbo=-698.88
# i=449, epochs=5.38, elapsed=0.02, elbo=-696.95
# i=450, epochs=5.39, elapsed=0.02, elbo=-697.86
# i=451, epochs=5.41, elapsed=0.02, elbo=-698.21
# i=452, epochs=5.42, elapsed=0.02, elbo=-698.06
# i=453, epochs=5.43, elapsed=0.02, elbo=-697.30
# i=454, epochs=5.44, elapsed=0.02, elbo=-697.82
# i=455, epochs=5.45, elapsed=0.02, elbo=-698.88
# i=456, epochs=5.47, elapsed=0.02, elbo=-698.36
# i=457, epochs=5.48, elapsed=0.02, elbo=-699.03
# i=458, epochs=5.49, elapsed=0.02, elbo=-695.67
# i=459, epochs=5.50, elapsed=0.02, elbo=-696.29
# i=460, epochs=5.51, elapsed=0.02, elbo=-697.19
# i=461, epochs=5.53, elapsed=0.02, elbo=-696.36
# i=462, epochs=5.54, elapsed=0.02, elbo=-697.73
# i=463, epochs=5.55, elapsed=0.02, elbo=-697.26
# i=464, epochs=5.56, elapsed=0.02, elbo=-697.75
# i=465, epochs=5.57, elapsed=0.02, elbo=-697.81
# i=466, epochs=5.59, elapsed=0.02, elbo=-696.36
# i=467, epochs=5.60, elapsed=0.02, elbo=-698.98
# i=468, epochs=5.61, elapsed=0.02, elbo=-697.03
# i=469, epochs=5.62, elapsed=0.02, elbo=-696.22
# i=470, epochs=5.63, elapsed=0.02, elbo=-695.79
# i=471, epochs=5.65, elapsed=0.02, elbo=-699.08
# i=472, epochs=5.66, elapsed=0.02, elbo=-698.57
# i=473, epochs=5.67, elapsed=0.02, elbo=-697.86
# i=474, epochs=5.68, elapsed=0.02, elbo=-699.31
# i=475, epochs=5.69, elapsed=0.02, elbo=-697.35
# i=476, epochs=5.71, elapsed=0.02, elbo=-698.11
# i=477, epochs=5.72, elapsed=0.02, elbo=-697.33
# i=478, epochs=5.73, elapsed=0.02, elbo=-697.70
# i=479, epochs=5.74, elapsed=0.02, elbo=-700.67
# i=480, epochs=5.75, elapsed=0.02, elbo=-697.72
# i=481, epochs=5.77, elapsed=0.02, elbo=-695.77
# i=482, epochs=5.78, elapsed=0.03, elbo=-699.07
# i=483, epochs=5.79, elapsed=0.03, elbo=-698.24
# i=484, epochs=5.80, elapsed=0.03, elbo=-700.49
# i=485, epochs=5.81, elapsed=0.03, elbo=-696.73
# i=486, epochs=5.83, elapsed=0.03, elbo=-695.47
# i=487, epochs=5.84, elapsed=0.03, elbo=-697.99
# i=488, epochs=5.85, elapsed=0.03, elbo=-698.32
# i=489, epochs=5.86, elapsed=0.03, elbo=-695.44
# i=490, epochs=5.87, elapsed=0.03, elbo=-695.51
# i=491, epochs=5.89, elapsed=0.03, elbo=-697.16
# i=492, epochs=5.90, elapsed=0.03, elbo=-697.29
# i=493, epochs=5.91, elapsed=0.03, elbo=-696.41
# i=494, epochs=5.92, elapsed=0.03, elbo=-698.41
# i=495, epochs=5.93, elapsed=0.03, elbo=-695.97
# i=496, epochs=5.95, elapsed=0.03, elbo=-698.17
# i=497, epochs=5.96, elapsed=0.03, elbo=-697.55
# i=498, epochs=5.97, elapsed=0.03, elbo=-697.09
# i=499, epochs=5.98, elapsed=0.03, elbo=-698.52
# i=500, epochs=5.99, elapsed=0.03, elbo=-698.34
# i=501, epochs=6.01, elapsed=0.03, elbo=-696.33
# i=502, epochs=6.02, elapsed=0.03, elbo=-700.31
# i=503, epochs=6.03, elapsed=0.03, elbo=-698.58
# i=504, epochs=6.04, elapsed=0.03, elbo=-697.47
# i=505, epochs=6.05, elapsed=0.03, elbo=-697.88
# i=506, epochs=6.07, elapsed=0.03, elbo=-696.60
# i=507, epochs=6.08, elapsed=0.03, elbo=-700.45
# i=508, epochs=6.09, elapsed=0.03, elbo=-699.25
# i=509, epochs=6.10, elapsed=0.03, elbo=-698.52
# i=510, epochs=6.11, elapsed=0.03, elbo=-696.63
# i=511, epochs=6.13, elapsed=0.03, elbo=-698.79
# i=512, epochs=6.14, elapsed=0.03, elbo=-697.90
# i=513, epochs=6.15, elapsed=0.03, elbo=-698.53
# i=514, epochs=6.16, elapsed=0.03, elbo=-699.02
# i=515, epochs=6.17, elapsed=0.03, elbo=-700.15
# i=516, epochs=6.19, elapsed=0.03, elbo=-697.26
# i=517, epochs=6.20, elapsed=0.03, elbo=-697.37
# i=518, epochs=6.21, elapsed=0.03, elbo=-697.77
# i=519, epochs=6.22, elapsed=0.03, elbo=-698.31
# i=520, epochs=6.23, elapsed=0.03, elbo=-699.47
# i=521, epochs=6.25, elapsed=0.03, elbo=-697.98
# i=522, epochs=6.26, elapsed=0.03, elbo=-697.49
# i=523, epochs=6.27, elapsed=0.03, elbo=-698.49
# i=524, epochs=6.28, elapsed=0.03, elbo=-698.05
# i=525, epochs=6.29, elapsed=0.03, elbo=-697.86
# i=526, epochs=6.31, elapsed=0.03, elbo=-696.77
# i=527, epochs=6.32, elapsed=0.03, elbo=-697.45
# i=528, epochs=6.33, elapsed=0.03, elbo=-699.10
# i=529, epochs=6.34, elapsed=0.03, elbo=-700.45
# i=530, epochs=6.35, elapsed=0.03, elbo=-698.18
# i=531, epochs=6.37, elapsed=0.03, elbo=-696.20
# i=532, epochs=6.38, elapsed=0.03, elbo=-697.21
# i=533, epochs=6.39, elapsed=0.03, elbo=-699.31
# i=534, epochs=6.40, elapsed=0.03, elbo=-698.21
# i=535, epochs=6.41, elapsed=0.03, elbo=-696.83
# i=536, epochs=6.43, elapsed=0.03, elbo=-697.62
# i=537, epochs=6.44, elapsed=0.03, elbo=-699.21
# i=538, epochs=6.45, elapsed=0.03, elbo=-698.55
# i=539, epochs=6.46, elapsed=0.03, elbo=-698.40
# i=540, epochs=6.47, elapsed=0.03, elbo=-699.09
# i=541, epochs=6.49, elapsed=0.03, elbo=-695.44
# i=542, epochs=6.50, elapsed=0.03, elbo=-696.56
# i=543, epochs=6.51, elapsed=0.03, elbo=-700.27
# i=544, epochs=6.52, elapsed=0.03, elbo=-697.95
# i=545, epochs=6.53, elapsed=0.03, elbo=-698.57
# i=546, epochs=6.55, elapsed=0.03, elbo=-700.19
# i=547, epochs=6.56, elapsed=0.03, elbo=-699.10
# i=548, epochs=6.57, elapsed=0.03, elbo=-697.48
# i=549, epochs=6.58, elapsed=0.03, elbo=-699.58
# i=550, epochs=6.59, elapsed=0.03, elbo=-695.44
# i=551, epochs=6.60, elapsed=0.03, elbo=-699.10
# i=552, epochs=6.62, elapsed=0.03, elbo=-699.54
# i=553, epochs=6.63, elapsed=0.03, elbo=-698.78
# i=554, epochs=6.64, elapsed=0.03, elbo=-698.53
# i=555, epochs=6.65, elapsed=0.03, elbo=-699.38
# i=556, epochs=6.66, elapsed=0.03, elbo=-698.42
# i=557, epochs=6.68, elapsed=0.03, elbo=-696.72
# i=558, epochs=6.69, elapsed=0.03, elbo=-699.22
# i=559, epochs=6.70, elapsed=0.03, elbo=-701.30
# i=560, epochs=6.71, elapsed=0.03, elbo=-698.78
# i=561, epochs=6.72, elapsed=0.03, elbo=-698.87
# i=562, epochs=6.74, elapsed=0.03, elbo=-699.57
# i=563, epochs=6.75, elapsed=0.03, elbo=-698.80
# i=564, epochs=6.76, elapsed=0.03, elbo=-700.33
# i=565, epochs=6.77, elapsed=0.03, elbo=-699.59
# i=566, epochs=6.78, elapsed=0.03, elbo=-699.56
# i=567, epochs=6.80, elapsed=0.03, elbo=-699.45
# i=568, epochs=6.81, elapsed=0.03, elbo=-697.68
# i=569, epochs=6.82, elapsed=0.03, elbo=-698.61
# i=570, epochs=6.83, elapsed=0.03, elbo=-700.44
# i=571, epochs=6.84, elapsed=0.03, elbo=-696.89
# i=572, epochs=6.86, elapsed=0.03, elbo=-700.05
# i=573, epochs=6.87, elapsed=0.03, elbo=-699.10
# i=574, epochs=6.88, elapsed=0.03, elbo=-694.63
# i=575, epochs=6.89, elapsed=0.03, elbo=-699.49
# i=576, epochs=6.90, elapsed=0.03, elbo=-698.15
# i=577, epochs=6.92, elapsed=0.03, elbo=-700.54
# i=578, epochs=6.93, elapsed=0.03, elbo=-700.06
# i=579, epochs=6.94, elapsed=0.03, elbo=-698.28
# i=580, epochs=6.95, elapsed=0.03, elbo=-699.99
# i=581, epochs=6.96, elapsed=0.03, elbo=-698.31
# i=582, epochs=6.98, elapsed=0.03, elbo=-700.55
# i=583, epochs=6.99, elapsed=0.03, elbo=-699.64
# i=584, epochs=7.00, elapsed=0.03, elbo=-699.67
# i=585, epochs=7.01, elapsed=0.03, elbo=-700.61
# i=586, epochs=7.02, elapsed=0.03, elbo=-699.45
# i=587, epochs=7.04, elapsed=0.03, elbo=-700.09
# i=588, epochs=7.05, elapsed=0.03, elbo=-699.50
# i=589, epochs=7.06, elapsed=0.03, elbo=-699.66
# i=590, epochs=7.07, elapsed=0.03, elbo=-700.27
# i=591, epochs=7.08, elapsed=0.03, elbo=-698.99
# i=592, epochs=7.10, elapsed=0.03, elbo=-699.63
# i=593, epochs=7.11, elapsed=0.03, elbo=-696.80
# i=594, epochs=7.12, elapsed=0.03, elbo=-699.23
# i=595, epochs=7.13, elapsed=0.03, elbo=-698.42
# i=596, epochs=7.14, elapsed=0.03, elbo=-699.79
# i=597, epochs=7.16, elapsed=0.03, elbo=-699.71
# i=598, epochs=7.17, elapsed=0.03, elbo=-697.77
# i=599, epochs=7.18, elapsed=0.03, elbo=-697.97
# i=600, epochs=7.19, elapsed=0.03, elbo=-700.04
# i=601, epochs=7.20, elapsed=0.03, elbo=-699.07
# i=602, epochs=7.22, elapsed=0.03, elbo=-700.55
# i=603, epochs=7.23, elapsed=0.03, elbo=-699.73
# i=604, epochs=7.24, elapsed=0.03, elbo=-699.03
# i=605, epochs=7.25, elapsed=0.03, elbo=-699.73
# i=606, epochs=7.26, elapsed=0.03, elbo=-697.77
# i=607, epochs=7.28, elapsed=0.03, elbo=-700.20
# i=608, epochs=7.29, elapsed=0.03, elbo=-698.64
# i=609, epochs=7.30, elapsed=0.03, elbo=-698.78
# i=610, epochs=7.31, elapsed=0.03, elbo=-698.17
# i=611, epochs=7.32, elapsed=0.03, elbo=-699.50
# i=612, epochs=7.34, elapsed=0.03, elbo=-699.68
# i=613, epochs=7.35, elapsed=0.03, elbo=-698.66
# i=614, epochs=7.36, elapsed=0.03, elbo=-701.85
# i=615, epochs=7.37, elapsed=0.03, elbo=-698.08
# i=616, epochs=7.38, elapsed=0.03, elbo=-699.09
# i=617, epochs=7.40, elapsed=0.03, elbo=-698.95
# i=618, epochs=7.41, elapsed=0.03, elbo=-700.03
# i=619, epochs=7.42, elapsed=0.03, elbo=-700.71
# i=620, epochs=7.43, elapsed=0.03, elbo=-699.42
# i=621, epochs=7.44, elapsed=0.03, elbo=-698.47
# i=622, epochs=7.46, elapsed=0.03, elbo=-698.59
# i=623, epochs=7.47, elapsed=0.03, elbo=-700.21
# i=624, epochs=7.48, elapsed=0.03, elbo=-699.71
# i=625, epochs=7.49, elapsed=0.03, elbo=-699.77
# i=626, epochs=7.50, elapsed=0.03, elbo=-700.16
# i=627, epochs=7.52, elapsed=0.03, elbo=-699.56
# i=628, epochs=7.53, elapsed=0.03, elbo=-699.80
# i=629, epochs=7.54, elapsed=0.03, elbo=-699.51
# i=630, epochs=7.55, elapsed=0.03, elbo=-697.95
# i=631, epochs=7.56, elapsed=0.03, elbo=-700.33
# i=632, epochs=7.58, elapsed=0.03, elbo=-698.96
# i=633, epochs=7.59, elapsed=0.03, elbo=-700.87
# i=634, epochs=7.60, elapsed=0.03, elbo=-700.88
# i=635, epochs=7.61, elapsed=0.03, elbo=-699.08
# i=636, epochs=7.62, elapsed=0.03, elbo=-699.31
# i=637, epochs=7.64, elapsed=0.03, elbo=-699.08
# i=638, epochs=7.65, elapsed=0.03, elbo=-698.61
# i=639, epochs=7.66, elapsed=0.03, elbo=-699.75
# i=640, epochs=7.67, elapsed=0.03, elbo=-699.02
# i=641, epochs=7.68, elapsed=0.03, elbo=-698.37
# i=642, epochs=7.70, elapsed=0.03, elbo=-700.04
# i=643, epochs=7.71, elapsed=0.03, elbo=-698.96
# i=644, epochs=7.72, elapsed=0.03, elbo=-701.36
# i=645, epochs=7.73, elapsed=0.03, elbo=-701.19
# i=646, epochs=7.74, elapsed=0.03, elbo=-699.70
# i=647, epochs=7.76, elapsed=0.03, elbo=-698.36
# i=648, epochs=7.77, elapsed=0.03, elbo=-698.24
# i=649, epochs=7.78, elapsed=0.03, elbo=-699.98
# i=650, epochs=7.79, elapsed=0.03, elbo=-698.76
# i=651, epochs=7.80, elapsed=0.03, elbo=-698.18
# i=652, epochs=7.82, elapsed=0.03, elbo=-699.13
# i=653, epochs=7.83, elapsed=0.03, elbo=-699.77
# i=654, epochs=7.84, elapsed=0.03, elbo=-700.49
# i=655, epochs=7.85, elapsed=0.03, elbo=-700.07
# i=656, epochs=7.86, elapsed=0.03, elbo=-699.83
# i=657, epochs=7.88, elapsed=0.03, elbo=-699.59
# i=658, epochs=7.89, elapsed=0.03, elbo=-700.54
# i=659, epochs=7.90, elapsed=0.03, elbo=-700.42
# i=660, epochs=7.91, elapsed=0.03, elbo=-700.01
# i=661, epochs=7.92, elapsed=0.03, elbo=-699.54
# i=662, epochs=7.94, elapsed=0.03, elbo=-699.18
# i=663, epochs=7.95, elapsed=0.03, elbo=-699.79
# i=664, epochs=7.96, elapsed=0.03, elbo=-699.45
# i=665, epochs=7.97, elapsed=0.03, elbo=-699.09
# i=666, epochs=7.98, elapsed=0.03, elbo=-699.96
# i=667, epochs=8.00, elapsed=0.03, elbo=-699.97
# i=668, epochs=8.01, elapsed=0.03, elbo=-699.03
# i=669, epochs=8.02, elapsed=0.03, elbo=-698.92
# i=670, epochs=8.03, elapsed=0.03, elbo=-700.88
# i=671, epochs=8.04, elapsed=0.03, elbo=-699.39
# i=672, epochs=8.06, elapsed=0.03, elbo=-699.10
# i=673, epochs=8.07, elapsed=0.03, elbo=-700.48
# i=674, epochs=8.08, elapsed=0.03, elbo=-699.98
# i=675, epochs=8.09, elapsed=0.03, elbo=-699.12
# i=676, epochs=8.10, elapsed=0.03, elbo=-700.21
# i=677, epochs=8.12, elapsed=0.03, elbo=-699.47
# i=678, epochs=8.13, elapsed=0.03, elbo=-700.71
# i=679, epochs=8.14, elapsed=0.03, elbo=-699.05
# i=680, epochs=8.15, elapsed=0.03, elbo=-699.83
# i=681, epochs=8.16, elapsed=0.04, elbo=-699.66
# i=682, epochs=8.18, elapsed=0.04, elbo=-700.89
# i=683, epochs=8.19, elapsed=0.04, elbo=-700.29
# i=684, epochs=8.20, elapsed=0.04, elbo=-699.12
# i=685, epochs=8.21, elapsed=0.04, elbo=-701.37
# i=686, epochs=8.22, elapsed=0.04, elbo=-699.31
# i=687, epochs=8.24, elapsed=0.04, elbo=-700.05
# i=688, epochs=8.25, elapsed=0.04, elbo=-699.81
# i=689, epochs=8.26, elapsed=0.04, elbo=-699.99
# i=690, epochs=8.27, elapsed=0.04, elbo=-699.87
# i=691, epochs=8.28, elapsed=0.04, elbo=-699.67
# i=692, epochs=8.30, elapsed=0.04, elbo=-699.41
# i=693, epochs=8.31, elapsed=0.04, elbo=-699.40
# i=694, epochs=8.32, elapsed=0.04, elbo=-699.48
# i=695, epochs=8.33, elapsed=0.04, elbo=-697.87
# i=696, epochs=8.34, elapsed=0.04, elbo=-697.74
# i=697, epochs=8.36, elapsed=0.04, elbo=-700.90
# i=698, epochs=8.37, elapsed=0.04, elbo=-698.13
# i=699, epochs=8.38, elapsed=0.04, elbo=-700.23
# i=700, epochs=8.39, elapsed=0.04, elbo=-696.85
# i=701, epochs=8.40, elapsed=0.04, elbo=-698.94
# i=702, epochs=8.42, elapsed=0.04, elbo=-699.23
# i=703, epochs=8.43, elapsed=0.04, elbo=-698.92
# i=704, epochs=8.44, elapsed=0.04, elbo=-699.89
# i=705, epochs=8.45, elapsed=0.04, elbo=-701.57
# i=706, epochs=8.46, elapsed=0.04, elbo=-695.99
# i=707, epochs=8.47, elapsed=0.04, elbo=-699.89
# i=708, epochs=8.49, elapsed=0.04, elbo=-700.33
# i=709, epochs=8.50, elapsed=0.04, elbo=-700.42
# i=710, epochs=8.51, elapsed=0.04, elbo=-700.79
# i=711, epochs=8.52, elapsed=0.04, elbo=-697.19
# i=712, epochs=8.53, elapsed=0.04, elbo=-699.74
# i=713, epochs=8.55, elapsed=0.04, elbo=-701.19
# i=714, epochs=8.56, elapsed=0.04, elbo=-699.98
# i=715, epochs=8.57, elapsed=0.04, elbo=-701.57
# i=716, epochs=8.58, elapsed=0.04, elbo=-699.66
# i=717, epochs=8.59, elapsed=0.04, elbo=-700.44
# i=718, epochs=8.61, elapsed=0.04, elbo=-699.82
# i=719, epochs=8.62, elapsed=0.04, elbo=-701.00
# i=720, epochs=8.63, elapsed=0.04, elbo=-699.11
# i=721, epochs=8.64, elapsed=0.04, elbo=-700.86
# i=722, epochs=8.65, elapsed=0.04, elbo=-700.17
# i=723, epochs=8.67, elapsed=0.04, elbo=-699.10
# i=724, epochs=8.68, elapsed=0.04, elbo=-699.50
# i=725, epochs=8.69, elapsed=0.04, elbo=-696.91
# i=726, epochs=8.70, elapsed=0.04, elbo=-700.89
# i=727, epochs=8.71, elapsed=0.04, elbo=-699.14
# i=728, epochs=8.73, elapsed=0.04, elbo=-699.53
# i=729, epochs=8.74, elapsed=0.04, elbo=-699.56
# i=730, epochs=8.75, elapsed=0.04, elbo=-699.45
# i=731, epochs=8.76, elapsed=0.04, elbo=-698.11
# i=732, epochs=8.77, elapsed=0.04, elbo=-701.08
# i=733, epochs=8.79, elapsed=0.04, elbo=-699.50
# i=734, epochs=8.80, elapsed=0.04, elbo=-700.47
# i=735, epochs=8.81, elapsed=0.04, elbo=-700.12
# i=736, epochs=8.82, elapsed=0.04, elbo=-700.53
# i=737, epochs=8.83, elapsed=0.04, elbo=-698.03
# i=738, epochs=8.85, elapsed=0.04, elbo=-699.53
# i=739, epochs=8.86, elapsed=0.04, elbo=-701.32
# i=740, epochs=8.87, elapsed=0.04, elbo=-699.51
# i=741, epochs=8.88, elapsed=0.04, elbo=-700.22
# i=742, epochs=8.89, elapsed=0.04, elbo=-700.98
# i=743, epochs=8.91, elapsed=0.04, elbo=-701.10
# i=744, epochs=8.92, elapsed=0.04, elbo=-700.11
# i=745, epochs=8.93, elapsed=0.04, elbo=-699.68
# i=746, epochs=8.94, elapsed=0.04, elbo=-699.55
# i=747, epochs=8.95, elapsed=0.04, elbo=-699.85
# i=748, epochs=8.97, elapsed=0.04, elbo=-700.96
# i=749, epochs=8.98, elapsed=0.04, elbo=-698.51
# i=750, epochs=8.99, elapsed=0.04, elbo=-699.85
# i=751, epochs=9.00, elapsed=0.04, elbo=-699.46
# i=752, epochs=9.01, elapsed=0.04, elbo=-700.81
# i=753, epochs=9.03, elapsed=0.04, elbo=-697.63
# i=754, epochs=9.04, elapsed=0.04, elbo=-702.46
# i=755, epochs=9.05, elapsed=0.04, elbo=-699.49
# i=756, epochs=9.06, elapsed=0.04, elbo=-698.50
# i=757, epochs=9.07, elapsed=0.04, elbo=-701.05
# i=758, epochs=9.09, elapsed=0.04, elbo=-701.23
# i=759, epochs=9.10, elapsed=0.04, elbo=-699.23
# i=760, epochs=9.11, elapsed=0.04, elbo=-699.94
# i=761, epochs=9.12, elapsed=0.04, elbo=-701.00
# i=762, epochs=9.13, elapsed=0.04, elbo=-699.46
# i=763, epochs=9.15, elapsed=0.04, elbo=-700.84
# i=764, epochs=9.16, elapsed=0.04, elbo=-700.62
# i=765, epochs=9.17, elapsed=0.04, elbo=-700.88
# i=766, epochs=9.18, elapsed=0.04, elbo=-700.65
# i=767, epochs=9.19, elapsed=0.04, elbo=-698.47
# i=768, epochs=9.21, elapsed=0.04, elbo=-700.21
# i=769, epochs=9.22, elapsed=0.04, elbo=-694.77
# i=770, epochs=9.23, elapsed=0.04, elbo=-700.57
# i=771, epochs=9.24, elapsed=0.04, elbo=-700.35
# i=772, epochs=9.25, elapsed=0.04, elbo=-699.38
# i=773, epochs=9.27, elapsed=0.04, elbo=-699.65
# i=774, epochs=9.28, elapsed=0.04, elbo=-700.58
# i=775, epochs=9.29, elapsed=0.04, elbo=-701.87
# i=776, epochs=9.30, elapsed=0.04, elbo=-699.10
# i=777, epochs=9.31, elapsed=0.04, elbo=-700.96
# i=778, epochs=9.33, elapsed=0.04, elbo=-699.46
# i=779, epochs=9.34, elapsed=0.04, elbo=-700.83
# i=780, epochs=9.35, elapsed=0.04, elbo=-699.78
# i=781, epochs=9.36, elapsed=0.04, elbo=-699.22
# i=782, epochs=9.37, elapsed=0.04, elbo=-700.74
# i=783, epochs=9.39, elapsed=0.04, elbo=-700.70
# i=784, epochs=9.40, elapsed=0.04, elbo=-700.38
# i=785, epochs=9.41, elapsed=0.04, elbo=-699.81
# i=786, epochs=9.42, elapsed=0.04, elbo=-700.94
# i=787, epochs=9.43, elapsed=0.04, elbo=-700.36
# i=788, epochs=9.45, elapsed=0.04, elbo=-699.88
# i=789, epochs=9.46, elapsed=0.04, elbo=-701.76
# i=790, epochs=9.47, elapsed=0.04, elbo=-699.74
# i=791, epochs=9.48, elapsed=0.04, elbo=-699.79
# i=792, epochs=9.49, elapsed=0.04, elbo=-701.81
# i=793, epochs=9.51, elapsed=0.04, elbo=-701.33
# i=794, epochs=9.52, elapsed=0.04, elbo=-701.70
# i=795, epochs=9.53, elapsed=0.04, elbo=-699.49
# i=796, epochs=9.54, elapsed=0.04, elbo=-700.74
# i=797, epochs=9.55, elapsed=0.04, elbo=-698.86
# i=798, epochs=9.57, elapsed=0.04, elbo=-701.07
# i=799, epochs=9.58, elapsed=0.04, elbo=-700.46
# i=800, epochs=9.59, elapsed=0.04, elbo=-700.33
# i=801, epochs=9.60, elapsed=0.04, elbo=-698.69
# i=802, epochs=9.61, elapsed=0.04, elbo=-702.00
# i=803, epochs=9.63, elapsed=0.04, elbo=-698.28
# i=804, epochs=9.64, elapsed=0.04, elbo=-701.64
# i=805, epochs=9.65, elapsed=0.04, elbo=-701.02
# i=806, epochs=9.66, elapsed=0.04, elbo=-700.60
# i=807, epochs=9.67, elapsed=0.04, elbo=-699.93
# i=808, epochs=9.69, elapsed=0.04, elbo=-701.02
# i=809, epochs=9.70, elapsed=0.04, elbo=-700.34
# i=810, epochs=9.71, elapsed=0.04, elbo=-699.29
# i=811, epochs=9.72, elapsed=0.04, elbo=-700.39
# i=812, epochs=9.73, elapsed=0.04, elbo=-699.11
# i=813, epochs=9.75, elapsed=0.04, elbo=-700.38
# i=814, epochs=9.76, elapsed=0.04, elbo=-700.90
# i=815, epochs=9.77, elapsed=0.04, elbo=-700.18
# i=816, epochs=9.78, elapsed=0.04, elbo=-699.62
# i=817, epochs=9.79, elapsed=0.04, elbo=-700.92
# i=818, epochs=9.81, elapsed=0.04, elbo=-699.91
# i=819, epochs=9.82, elapsed=0.04, elbo=-701.07
# i=820, epochs=9.83, elapsed=0.04, elbo=-697.51
# i=821, epochs=9.84, elapsed=0.04, elbo=-701.20
# i=822, epochs=9.85, elapsed=0.04, elbo=-701.25
# i=823, epochs=9.87, elapsed=0.04, elbo=-700.24
# i=824, epochs=9.88, elapsed=0.04, elbo=-701.20
# i=825, epochs=9.89, elapsed=0.04, elbo=-701.20
# i=826, epochs=9.90, elapsed=0.04, elbo=-700.73
# i=827, epochs=9.91, elapsed=0.04, elbo=-700.48
# i=828, epochs=9.93, elapsed=0.04, elbo=-698.72
# i=829, epochs=9.94, elapsed=0.04, elbo=-699.94
# i=830, epochs=9.95, elapsed=0.04, elbo=-700.82
# i=831, epochs=9.96, elapsed=0.04, elbo=-701.05
# i=832, epochs=9.97, elapsed=0.04, elbo=-700.08
# i=833, epochs=9.99, elapsed=0.04, elbo=-700.57
# i=834, epochs=10.00, elapsed=0.04, elbo=-698.17
# i=835, epochs=10.01, elapsed=0.04, elbo=-702.45
# i=836, epochs=10.02, elapsed=0.04, elbo=-700.42
# i=837, epochs=10.03, elapsed=0.04, elbo=-698.78
# i=838, epochs=10.05, elapsed=0.04, elbo=-701.05
# i=839, epochs=10.06, elapsed=0.04, elbo=-702.81
# i=840, epochs=10.07, elapsed=0.04, elbo=-701.05
# i=841, epochs=10.08, elapsed=0.04, elbo=-700.84
# i=842, epochs=10.09, elapsed=0.04, elbo=-701.37
# i=843, epochs=10.11, elapsed=0.04, elbo=-701.38
# i=844, epochs=10.12, elapsed=0.04, elbo=-697.35
# i=845, epochs=10.13, elapsed=0.04, elbo=-701.97
# i=846, epochs=10.14, elapsed=0.04, elbo=-701.80
# i=847, epochs=10.15, elapsed=0.04, elbo=-699.92
# i=848, epochs=10.17, elapsed=0.04, elbo=-700.45
# i=849, epochs=10.18, elapsed=0.04, elbo=-701.36
# i=850, epochs=10.19, elapsed=0.04, elbo=-699.63
# i=851, epochs=10.20, elapsed=0.04, elbo=-701.25
# i=852, epochs=10.21, elapsed=0.04, elbo=-699.53
# i=853, epochs=10.23, elapsed=0.04, elbo=-701.43
# i=854, epochs=10.24, elapsed=0.04, elbo=-699.84
# i=855, epochs=10.25, elapsed=0.04, elbo=-701.10
# i=856, epochs=10.26, elapsed=0.04, elbo=-700.92
# i=857, epochs=10.27, elapsed=0.04, elbo=-700.35
# i=858, epochs=10.29, elapsed=0.04, elbo=-700.49
# i=859, epochs=10.30, elapsed=0.04, elbo=-700.65
# i=860, epochs=10.31, elapsed=0.04, elbo=-701.61
# i=861, epochs=10.32, elapsed=0.04, elbo=-701.19
# i=862, epochs=10.33, elapsed=0.04, elbo=-700.79
# i=863, epochs=10.35, elapsed=0.04, elbo=-701.76
# i=864, epochs=10.36, elapsed=0.04, elbo=-699.81
# i=865, epochs=10.37, elapsed=0.04, elbo=-700.45
# i=866, epochs=10.38, elapsed=0.04, elbo=-700.23
# i=867, epochs=10.39, elapsed=0.04, elbo=-701.25
# i=868, epochs=10.40, elapsed=0.04, elbo=-702.16
# i=869, epochs=10.42, elapsed=0.04, elbo=-700.23
# i=870, epochs=10.43, elapsed=0.05, elbo=-700.48
# i=871, epochs=10.44, elapsed=0.05, elbo=-699.25
# i=872, epochs=10.45, elapsed=0.05, elbo=-700.69
# i=873, epochs=10.46, elapsed=0.05, elbo=-700.02
# i=874, epochs=10.48, elapsed=0.05, elbo=-700.69
# i=875, epochs=10.49, elapsed=0.05, elbo=-700.53
# i=876, epochs=10.50, elapsed=0.05, elbo=-695.63
# i=877, epochs=10.51, elapsed=0.05, elbo=-701.26
# i=878, epochs=10.52, elapsed=0.05, elbo=-701.34
# i=879, epochs=10.54, elapsed=0.05, elbo=-702.38
# i=880, epochs=10.55, elapsed=0.05, elbo=-698.60
# i=881, epochs=10.56, elapsed=0.05, elbo=-699.86
# i=882, epochs=10.57, elapsed=0.05, elbo=-702.04
# i=883, epochs=10.58, elapsed=0.05, elbo=-700.92
# i=884, epochs=10.60, elapsed=0.05, elbo=-701.10
# i=885, epochs=10.61, elapsed=0.05, elbo=-700.80
# i=886, epochs=10.62, elapsed=0.05, elbo=-701.01
# i=887, epochs=10.63, elapsed=0.05, elbo=-700.80
# i=888, epochs=10.64, elapsed=0.05, elbo=-702.02
# i=889, epochs=10.66, elapsed=0.05, elbo=-701.05
# i=890, epochs=10.67, elapsed=0.05, elbo=-699.60
# i=891, epochs=10.68, elapsed=0.05, elbo=-701.48
# i=892, epochs=10.69, elapsed=0.05, elbo=-702.59
# i=893, epochs=10.70, elapsed=0.05, elbo=-700.94
# i=894, epochs=10.72, elapsed=0.05, elbo=-701.01
# i=895, epochs=10.73, elapsed=0.05, elbo=-702.13
# i=896, epochs=10.74, elapsed=0.05, elbo=-699.56
# i=897, epochs=10.75, elapsed=0.05, elbo=-700.02
# i=898, epochs=10.76, elapsed=0.05, elbo=-700.89
# i=899, epochs=10.78, elapsed=0.05, elbo=-699.99
# i=900, epochs=10.79, elapsed=0.05, elbo=-699.87
# i=901, epochs=10.80, elapsed=0.05, elbo=-696.85
# i=902, epochs=10.81, elapsed=0.05, elbo=-700.51
# i=903, epochs=10.82, elapsed=0.05, elbo=-702.02
# i=904, epochs=10.84, elapsed=0.05, elbo=-699.71
# i=905, epochs=10.85, elapsed=0.05, elbo=-698.52
# i=906, epochs=10.86, elapsed=0.05, elbo=-700.91
# i=907, epochs=10.87, elapsed=0.05, elbo=-700.50
# i=908, epochs=10.88, elapsed=0.05, elbo=-699.86
# i=909, epochs=10.90, elapsed=0.05, elbo=-701.66
# i=910, epochs=10.91, elapsed=0.05, elbo=-701.00
# i=911, epochs=10.92, elapsed=0.05, elbo=-698.99
# i=912, epochs=10.93, elapsed=0.05, elbo=-700.36
# i=913, epochs=10.94, elapsed=0.05, elbo=-699.33
# i=914, epochs=10.96, elapsed=0.05, elbo=-700.31
# i=915, epochs=10.97, elapsed=0.05, elbo=-700.38
# i=916, epochs=10.98, elapsed=0.05, elbo=-700.69
# i=917, epochs=10.99, elapsed=0.05, elbo=-700.96
# i=918, epochs=11.00, elapsed=0.05, elbo=-700.03
# i=919, epochs=11.02, elapsed=0.05, elbo=-702.10
# i=920, epochs=11.03, elapsed=0.05, elbo=-700.32
# i=921, epochs=11.04, elapsed=0.05, elbo=-700.41
# i=922, epochs=11.05, elapsed=0.05, elbo=-700.89
# i=923, epochs=11.06, elapsed=0.05, elbo=-700.61
# i=924, epochs=11.08, elapsed=0.05, elbo=-700.56
# i=925, epochs=11.09, elapsed=0.05, elbo=-701.42
# i=926, epochs=11.10, elapsed=0.05, elbo=-702.16
# i=927, epochs=11.11, elapsed=0.05, elbo=-700.25
# i=928, epochs=11.12, elapsed=0.05, elbo=-701.23
# i=929, epochs=11.14, elapsed=0.05, elbo=-700.38
# i=930, epochs=11.15, elapsed=0.05, elbo=-702.20
# i=931, epochs=11.16, elapsed=0.05, elbo=-701.58
# i=932, epochs=11.17, elapsed=0.05, elbo=-701.86
# i=933, epochs=11.18, elapsed=0.05, elbo=-700.90
# i=934, epochs=11.20, elapsed=0.05, elbo=-701.27
# i=935, epochs=11.21, elapsed=0.05, elbo=-697.39
# i=936, epochs=11.22, elapsed=0.05, elbo=-700.79
# i=937, epochs=11.23, elapsed=0.05, elbo=-699.85
# i=938, epochs=11.24, elapsed=0.05, elbo=-700.44
# i=939, epochs=11.26, elapsed=0.05, elbo=-695.69
# i=940, epochs=11.27, elapsed=0.05, elbo=-697.95
# i=941, epochs=11.28, elapsed=0.05, elbo=-700.23
# i=942, epochs=11.29, elapsed=0.05, elbo=-699.93
# i=943, epochs=11.30, elapsed=0.05, elbo=-701.56
# i=944, epochs=11.32, elapsed=0.05, elbo=-702.26
# i=945, epochs=11.33, elapsed=0.05, elbo=-700.86
# i=946, epochs=11.34, elapsed=0.05, elbo=-700.52
# i=947, epochs=11.35, elapsed=0.05, elbo=-700.29
# i=948, epochs=11.36, elapsed=0.05, elbo=-701.27
# i=949, epochs=11.38, elapsed=0.05, elbo=-700.10
# i=950, epochs=11.39, elapsed=0.05, elbo=-699.94
# i=951, epochs=11.40, elapsed=0.05, elbo=-701.78
# i=952, epochs=11.41, elapsed=0.05, elbo=-699.83
# i=953, epochs=11.42, elapsed=0.05, elbo=-700.36
# i=954, epochs=11.44, elapsed=0.05, elbo=-700.81
# i=955, epochs=11.45, elapsed=0.05, elbo=-700.34
# i=956, epochs=11.46, elapsed=0.05, elbo=-698.84
# i=957, epochs=11.47, elapsed=0.05, elbo=-702.67
# i=958, epochs=11.48, elapsed=0.05, elbo=-702.03
# i=959, epochs=11.50, elapsed=0.05, elbo=-702.48
# i=960, epochs=11.51, elapsed=0.05, elbo=-699.56
# i=961, epochs=11.52, elapsed=0.05, elbo=-699.64
# i=962, epochs=11.53, elapsed=0.05, elbo=-700.52
# i=963, epochs=11.54, elapsed=0.05, elbo=-700.90
# i=964, epochs=11.56, elapsed=0.05, elbo=-698.91
# i=965, epochs=11.57, elapsed=0.05, elbo=-702.44
# i=966, epochs=11.58, elapsed=0.05, elbo=-701.53
# i=967, epochs=11.59, elapsed=0.05, elbo=-701.30
# i=968, epochs=11.60, elapsed=0.05, elbo=-699.68
# i=969, epochs=11.62, elapsed=0.05, elbo=-700.91
# i=970, epochs=11.63, elapsed=0.05, elbo=-702.91
# i=971, epochs=11.64, elapsed=0.05, elbo=-702.29
# i=972, epochs=11.65, elapsed=0.05, elbo=-701.30
# i=973, epochs=11.66, elapsed=0.05, elbo=-700.90
# i=974, epochs=11.68, elapsed=0.05, elbo=-701.20
# i=975, epochs=11.69, elapsed=0.05, elbo=-701.31
# i=976, epochs=11.70, elapsed=0.05, elbo=-701.29
# i=977, epochs=11.71, elapsed=0.05, elbo=-700.97
# i=978, epochs=11.72, elapsed=0.05, elbo=-701.58
# i=979, epochs=11.74, elapsed=0.05, elbo=-701.91
# i=980, epochs=11.75, elapsed=0.05, elbo=-701.23
# i=981, epochs=11.76, elapsed=0.05, elbo=-700.78
# i=982, epochs=11.77, elapsed=0.05, elbo=-700.57
# i=983, epochs=11.78, elapsed=0.05, elbo=-701.85
# i=984, epochs=11.80, elapsed=0.05, elbo=-701.07
# i=985, epochs=11.81, elapsed=0.05, elbo=-701.83
# i=986, epochs=11.82, elapsed=0.05, elbo=-699.99
# i=987, epochs=11.83, elapsed=0.05, elbo=-700.80
# i=988, epochs=11.84, elapsed=0.05, elbo=-699.89
# i=989, epochs=11.86, elapsed=0.05, elbo=-700.85
# i=990, epochs=11.87, elapsed=0.05, elbo=-702.32
# i=991, epochs=11.88, elapsed=0.05, elbo=-700.15
# i=992, epochs=11.89, elapsed=0.05, elbo=-700.02
# i=993, epochs=11.90, elapsed=0.05, elbo=-699.64
# i=994, epochs=11.92, elapsed=0.05, elbo=-700.94
# i=995, epochs=11.93, elapsed=0.05, elbo=-700.64
# i=996, epochs=11.94, elapsed=0.05, elbo=-701.53
# i=997, epochs=11.95, elapsed=0.05, elbo=-700.50
# i=998, epochs=11.96, elapsed=0.05, elbo=-700.67
# i=999, epochs=11.98, elapsed=0.05, elbo=-701.09
# i=1000, epochs=11.99, elapsed=0.05, elbo=-700.67
# i=1001, epochs=12.00, elapsed=0.05, elbo=-701.38
# i=1002, epochs=12.01, elapsed=0.05, elbo=-700.55
# i=1003, epochs=12.02, elapsed=0.05, elbo=-701.14
# i=1004, epochs=12.04, elapsed=0.05, elbo=-699.09
# i=1005, epochs=12.05, elapsed=0.05, elbo=-700.48
# i=1006, epochs=12.06, elapsed=0.05, elbo=-702.59
# i=1007, epochs=12.07, elapsed=0.05, elbo=-701.03
# i=1008, epochs=12.08, elapsed=0.05, elbo=-698.65
# i=1009, epochs=12.10, elapsed=0.05, elbo=-700.64
# i=1010, epochs=12.11, elapsed=0.05, elbo=-700.34
# i=1011, epochs=12.12, elapsed=0.05, elbo=-700.84
# i=1012, epochs=12.13, elapsed=0.05, elbo=-700.66
# i=1013, epochs=12.14, elapsed=0.05, elbo=-701.34
# i=1014, epochs=12.16, elapsed=0.05, elbo=-701.09
# i=1015, epochs=12.17, elapsed=0.05, elbo=-698.94
# i=1016, epochs=12.18, elapsed=0.05, elbo=-701.84
# i=1017, epochs=12.19, elapsed=0.05, elbo=-700.92
# i=1018, epochs=12.20, elapsed=0.05, elbo=-702.85
# i=1019, epochs=12.22, elapsed=0.05, elbo=-701.49
# ...
# i=2769, epochs=33.19, elapsed=0.15, elbo=-703.81
# i=2770, epochs=33.20, elapsed=0.15, elbo=-700.62
# i=2771, epochs=33.22, elapsed=0.15, elbo=-703.58
# i=2772, epochs=33.23, elapsed=0.15, elbo=-702.49
# i=2773, epochs=33.24, elapsed=0.15, elbo=-701.93
# i=2774, epochs=33.25, elapsed=0.15, elbo=-702.22
# i=2775, epochs=33.26, elapsed=0.15, elbo=-700.86
# i=2776, epochs=33.28, elapsed=0.15, elbo=-702.60
# i=2777, epochs=33.29, elapsed=0.15, elbo=-703.10
# i=2778, epochs=33.30, elapsed=0.15, elbo=-702.89
# i=2779, epochs=33.31, elapsed=0.15, elbo=-701.76
# i=2780, epochs=33.32, elapsed=0.15, elbo=-702.77
# i=2781, epochs=33.34, elapsed=0.15, elbo=-702.25
# i=2782, epochs=33.35, elapsed=0.15, elbo=-702.89
# i=2783, epochs=33.36, elapsed=0.15, elbo=-702.99
# i=2784, epochs=33.37, elapsed=0.15, elbo=-702.71
# i=2785, epochs=33.38, elapsed=0.15, elbo=-702.58
# i=2786, epochs=33.40, elapsed=0.15, elbo=-699.17
# i=2787, epochs=33.41, elapsed=0.15, elbo=-700.01
# i=2788, epochs=33.42, elapsed=0.15, elbo=-701.31
# i=2789, epochs=33.43, elapsed=0.15, elbo=-702.11
# i=2790, epochs=33.44, elapsed=0.15, elbo=-703.15
# i=2791, epochs=33.46, elapsed=0.15, elbo=-703.40
# i=2792, epochs=33.47, elapsed=0.15, elbo=-702.43
# i=2793, epochs=33.48, elapsed=0.15, elbo=-703.33
# i=2794, epochs=33.49, elapsed=0.15, elbo=-704.59
# i=2795, epochs=33.50, elapsed=0.15, elbo=-703.24
# i=2796, epochs=33.52, elapsed=0.15, elbo=-702.40
# i=2797, epochs=33.53, elapsed=0.15, elbo=-703.10
# i=2798, epochs=33.54, elapsed=0.15, elbo=-701.91
# i=2799, epochs=33.55, elapsed=0.15, elbo=-704.11
# i=2800, epochs=33.56, elapsed=0.15, elbo=-703.63
# i=2801, epochs=33.58, elapsed=0.15, elbo=-704.23
# i=2802, epochs=33.59, elapsed=0.15, elbo=-702.08
# i=2803, epochs=33.60, elapsed=0.15, elbo=-702.97
# i=2804, epochs=33.61, elapsed=0.15, elbo=-702.76
# i=2805, epochs=33.62, elapsed=0.15, elbo=-701.69
# i=2806, epochs=33.64, elapsed=0.15, elbo=-703.15
# i=2807, epochs=33.65, elapsed=0.15, elbo=-702.06
# i=2808, epochs=33.66, elapsed=0.15, elbo=-702.83
# i=2809, epochs=33.67, elapsed=0.15, elbo=-702.08
# i=2810, epochs=33.68, elapsed=0.15, elbo=-702.94
# i=2811, epochs=33.70, elapsed=0.15, elbo=-702.97
# i=2812, epochs=33.71, elapsed=0.15, elbo=-701.76
# i=2813, epochs=33.72, elapsed=0.15, elbo=-704.39
# i=2814, epochs=33.73, elapsed=0.15, elbo=-701.92
# i=2815, epochs=33.74, elapsed=0.15, elbo=-702.88
# i=2816, epochs=33.76, elapsed=0.15, elbo=-702.60
# i=2817, epochs=33.77, elapsed=0.15, elbo=-702.81
# i=2818, epochs=33.78, elapsed=0.15, elbo=-703.00
# i=2819, epochs=33.79, elapsed=0.15, elbo=-702.96
# i=2820, epochs=33.80, elapsed=0.15, elbo=-702.22
# i=2821, epochs=33.82, elapsed=0.15, elbo=-703.63
# i=2822, epochs=33.83, elapsed=0.15, elbo=-703.28
# i=2823, epochs=33.84, elapsed=0.15, elbo=-702.41
# i=2824, epochs=33.85, elapsed=0.15, elbo=-702.89
# i=2825, epochs=33.86, elapsed=0.15, elbo=-700.84
# i=2826, epochs=33.88, elapsed=0.15, elbo=-703.41
# i=2827, epochs=33.89, elapsed=0.15, elbo=-703.56
# i=2828, epochs=33.90, elapsed=0.15, elbo=-701.63
# i=2829, epochs=33.91, elapsed=0.15, elbo=-704.06
# i=2830, epochs=33.92, elapsed=0.15, elbo=-700.86
# i=2831, epochs=33.94, elapsed=0.15, elbo=-702.33
# i=2832, epochs=33.95, elapsed=0.15, elbo=-702.52
# i=2833, epochs=33.96, elapsed=0.15, elbo=-703.43
# i=2834, epochs=33.97, elapsed=0.15, elbo=-702.46
# i=2835, epochs=33.98, elapsed=0.15, elbo=-703.45
# i=2836, epochs=34.00, elapsed=0.15, elbo=-702.53
# i=2837, epochs=34.01, elapsed=0.15, elbo=-701.69
# i=2838, epochs=34.02, elapsed=0.15, elbo=-702.09
# i=2839, epochs=34.03, elapsed=0.15, elbo=-701.67
# i=2840, epochs=34.04, elapsed=0.15, elbo=-701.39
# i=2841, epochs=34.06, elapsed=0.15, elbo=-702.18
# i=2842, epochs=34.07, elapsed=0.15, elbo=-703.33
# i=2843, epochs=34.08, elapsed=0.15, elbo=-703.56
# i=2844, epochs=34.09, elapsed=0.15, elbo=-703.36
# i=2845, epochs=34.10, elapsed=0.15, elbo=-703.17
# i=2846, epochs=34.12, elapsed=0.15, elbo=-703.36
# i=2847, epochs=34.13, elapsed=0.15, elbo=-702.21
# i=2848, epochs=34.14, elapsed=0.15, elbo=-702.65
# i=2849, epochs=34.15, elapsed=0.15, elbo=-703.10
# i=2850, epochs=34.16, elapsed=0.15, elbo=-702.64
# i=2851, epochs=34.18, elapsed=0.15, elbo=-702.69
# i=2852, epochs=34.19, elapsed=0.15, elbo=-702.63
# i=2853, epochs=34.20, elapsed=0.15, elbo=-702.45
# i=2854, epochs=34.21, elapsed=0.15, elbo=-703.58
# i=2855, epochs=34.22, elapsed=0.15, elbo=-702.14
# i=2856, epochs=34.24, elapsed=0.15, elbo=-703.41
# i=2857, epochs=34.25, elapsed=0.15, elbo=-703.41
# i=2858, epochs=34.26, elapsed=0.15, elbo=-701.57
# i=2859, epochs=34.27, elapsed=0.15, elbo=-702.67
# i=2860, epochs=34.28, elapsed=0.15, elbo=-701.02
# i=2861, epochs=34.30, elapsed=0.15, elbo=-702.64
# i=2862, epochs=34.31, elapsed=0.15, elbo=-701.74
# i=2863, epochs=34.32, elapsed=0.15, elbo=-702.99
# i=2864, epochs=34.33, elapsed=0.15, elbo=-703.52
# i=2865, epochs=34.34, elapsed=0.15, elbo=-702.34
# i=2866, epochs=34.36, elapsed=0.15, elbo=-700.70
# i=2867, epochs=34.37, elapsed=0.15, elbo=-704.03
# i=2868, epochs=34.38, elapsed=0.15, elbo=-703.58
# i=2869, epochs=34.39, elapsed=0.15, elbo=-698.56
# i=2870, epochs=34.40, elapsed=0.15, elbo=-700.24
# i=2871, epochs=34.42, elapsed=0.15, elbo=-703.05
# i=2872, epochs=34.43, elapsed=0.15, elbo=-703.10
# i=2873, epochs=34.44, elapsed=0.15, elbo=-703.09
# i=2874, epochs=34.45, elapsed=0.15, elbo=-702.28
# i=2875, epochs=34.46, elapsed=0.15, elbo=-703.57
# i=2876, epochs=34.48, elapsed=0.15, elbo=-703.08
# i=2877, epochs=34.49, elapsed=0.15, elbo=-703.58
# i=2878, epochs=34.50, elapsed=0.15, elbo=-702.51
# i=2879, epochs=34.51, elapsed=0.15, elbo=-703.68
# i=2880, epochs=34.52, elapsed=0.15, elbo=-702.11
# i=2881, epochs=34.54, elapsed=0.15, elbo=-702.75
# i=2882, epochs=34.55, elapsed=0.15, elbo=-702.40
# i=2883, epochs=34.56, elapsed=0.15, elbo=-702.57
# i=2884, epochs=34.57, elapsed=0.15, elbo=-703.30
# i=2885, epochs=34.58, elapsed=0.15, elbo=-701.97
# i=2886, epochs=34.60, elapsed=0.15, elbo=-703.65
# i=2887, epochs=34.61, elapsed=0.15, elbo=-701.72
# i=2888, epochs=34.62, elapsed=0.15, elbo=-702.48
# i=2889, epochs=34.63, elapsed=0.15, elbo=-701.84
# i=2890, epochs=34.64, elapsed=0.15, elbo=-703.05
# i=2891, epochs=34.66, elapsed=0.15, elbo=-704.01
# i=2892, epochs=34.67, elapsed=0.15, elbo=-700.41
# i=2893, epochs=34.68, elapsed=0.15, elbo=-703.10
# i=2894, epochs=34.69, elapsed=0.15, elbo=-702.22
# i=2895, epochs=34.70, elapsed=0.15, elbo=-702.98
# i=2896, epochs=34.72, elapsed=0.15, elbo=-702.89
# i=2897, epochs=34.73, elapsed=0.15, elbo=-703.43
# i=2898, epochs=34.74, elapsed=0.15, elbo=-700.06
# i=2899, epochs=34.75, elapsed=0.16, elbo=-702.65
# i=2900, epochs=34.76, elapsed=0.16, elbo=-702.94
# i=2901, epochs=34.78, elapsed=0.16, elbo=-702.68
# i=2902, epochs=34.79, elapsed=0.16, elbo=-702.65
# i=2903, epochs=34.80, elapsed=0.16, elbo=-703.80
# i=2904, epochs=34.81, elapsed=0.16, elbo=-701.42
# i=2905, epochs=34.82, elapsed=0.16, elbo=-703.53
# i=2906, epochs=34.83, elapsed=0.16, elbo=-702.90
# i=2907, epochs=34.85, elapsed=0.16, elbo=-703.50
# i=2908, epochs=34.86, elapsed=0.16, elbo=-702.44
# i=2909, epochs=34.87, elapsed=0.16, elbo=-703.96
# i=2910, epochs=34.88, elapsed=0.16, elbo=-702.85
# i=2911, epochs=34.89, elapsed=0.16, elbo=-703.79
# i=2912, epochs=34.91, elapsed=0.16, elbo=-702.42
# i=2913, epochs=34.92, elapsed=0.16, elbo=-702.50
# i=2914, epochs=34.93, elapsed=0.16, elbo=-703.67
# i=2915, epochs=34.94, elapsed=0.16, elbo=-702.83
# i=2916, epochs=34.95, elapsed=0.16, elbo=-702.01
# i=2917, epochs=34.97, elapsed=0.16, elbo=-701.67
# i=2918, epochs=34.98, elapsed=0.16, elbo=-702.85
# i=2919, epochs=34.99, elapsed=0.16, elbo=-701.28
# i=2920, epochs=35.00, elapsed=0.16, elbo=-701.58
# i=2921, epochs=35.01, elapsed=0.16, elbo=-703.36
# i=2922, epochs=35.03, elapsed=0.16, elbo=-703.00
# i=2923, epochs=35.04, elapsed=0.16, elbo=-703.88
# i=2924, epochs=35.05, elapsed=0.16, elbo=-702.74
# i=2925, epochs=35.06, elapsed=0.16, elbo=-701.93
# i=2926, epochs=35.07, elapsed=0.16, elbo=-699.52
# i=2927, epochs=35.09, elapsed=0.16, elbo=-703.38
# i=2928, epochs=35.10, elapsed=0.16, elbo=-702.45
# i=2929, epochs=35.11, elapsed=0.16, elbo=-701.95
# i=2930, epochs=35.12, elapsed=0.16, elbo=-702.73
# i=2931, epochs=35.13, elapsed=0.16, elbo=-702.45
# i=2932, epochs=35.15, elapsed=0.16, elbo=-702.24
# i=2933, epochs=35.16, elapsed=0.16, elbo=-703.89
# i=2934, epochs=35.17, elapsed=0.16, elbo=-702.91
# i=2935, epochs=35.18, elapsed=0.16, elbo=-704.17
# i=2936, epochs=35.19, elapsed=0.16, elbo=-703.94
# i=2937, epochs=35.21, elapsed=0.16, elbo=-703.90
# i=2938, epochs=35.22, elapsed=0.16, elbo=-703.02
# i=2939, epochs=35.23, elapsed=0.16, elbo=-702.85
# i=2940, epochs=35.24, elapsed=0.16, elbo=-702.48
# i=2941, epochs=35.25, elapsed=0.16, elbo=-700.97
# i=2942, epochs=35.27, elapsed=0.16, elbo=-701.04
# i=2943, epochs=35.28, elapsed=0.16, elbo=-701.96
# i=2944, epochs=35.29, elapsed=0.16, elbo=-702.37
# i=2945, epochs=35.30, elapsed=0.16, elbo=-702.56
# i=2946, epochs=35.31, elapsed=0.16, elbo=-703.02
# i=2947, epochs=35.33, elapsed=0.16, elbo=-702.44
# i=2948, epochs=35.34, elapsed=0.16, elbo=-703.29
# i=2949, epochs=35.35, elapsed=0.16, elbo=-702.71
# i=2950, epochs=35.36, elapsed=0.16, elbo=-702.83
# i=2951, epochs=35.37, elapsed=0.16, elbo=-702.95
# i=2952, epochs=35.39, elapsed=0.16, elbo=-701.31
# i=2953, epochs=35.40, elapsed=0.16, elbo=-702.00
# i=2954, epochs=35.41, elapsed=0.16, elbo=-700.90
# i=2955, epochs=35.42, elapsed=0.16, elbo=-701.86
# i=2956, epochs=35.43, elapsed=0.16, elbo=-702.92
# i=2957, epochs=35.45, elapsed=0.16, elbo=-703.82
# i=2958, epochs=35.46, elapsed=0.16, elbo=-703.06
# i=2959, epochs=35.47, elapsed=0.16, elbo=-702.83
# i=2960, epochs=35.48, elapsed=0.16, elbo=-700.07
# i=2961, epochs=35.49, elapsed=0.16, elbo=-701.54
# i=2962, epochs=35.51, elapsed=0.16, elbo=-703.35
# i=2963, epochs=35.52, elapsed=0.16, elbo=-702.26
# i=2964, epochs=35.53, elapsed=0.16, elbo=-702.12
# i=2965, epochs=35.54, elapsed=0.16, elbo=-703.98
# i=2966, epochs=35.55, elapsed=0.16, elbo=-703.85
# i=2967, epochs=35.57, elapsed=0.16, elbo=-699.96
# i=2968, epochs=35.58, elapsed=0.16, elbo=-702.07
# i=2969, epochs=35.59, elapsed=0.16, elbo=-703.76
# i=2970, epochs=35.60, elapsed=0.16, elbo=-701.55
# i=2971, epochs=35.61, elapsed=0.16, elbo=-703.20
# i=2972, epochs=35.63, elapsed=0.16, elbo=-703.85
# i=2973, epochs=35.64, elapsed=0.16, elbo=-702.12
# i=2974, epochs=35.65, elapsed=0.16, elbo=-702.58
# i=2975, epochs=35.66, elapsed=0.16, elbo=-703.83
# i=2976, epochs=35.67, elapsed=0.16, elbo=-704.35
# i=2977, epochs=35.69, elapsed=0.16, elbo=-702.74
# i=2978, epochs=35.70, elapsed=0.16, elbo=-702.33
# i=2979, epochs=35.71, elapsed=0.16, elbo=-702.64
# i=2980, epochs=35.72, elapsed=0.16, elbo=-702.32
# i=2981, epochs=35.73, elapsed=0.16, elbo=-701.75
# i=2982, epochs=35.75, elapsed=0.16, elbo=-702.13
# i=2983, epochs=35.76, elapsed=0.16, elbo=-699.50
# i=2984, epochs=35.77, elapsed=0.16, elbo=-702.56
# i=2985, epochs=35.78, elapsed=0.16, elbo=-703.26
# i=2986, epochs=35.79, elapsed=0.16, elbo=-702.46
# i=2987, epochs=35.81, elapsed=0.16, elbo=-702.60
# i=2988, epochs=35.82, elapsed=0.16, elbo=-703.42
# i=2989, epochs=35.83, elapsed=0.16, elbo=-701.82
# i=2990, epochs=35.84, elapsed=0.16, elbo=-703.22
# i=2991, epochs=35.85, elapsed=0.16, elbo=-702.59
# i=2992, epochs=35.87, elapsed=0.16, elbo=-703.00
# i=2993, epochs=35.88, elapsed=0.16, elbo=-702.58
# i=2994, epochs=35.89, elapsed=0.16, elbo=-702.32
# i=2995, epochs=35.90, elapsed=0.16, elbo=-703.05
# i=2996, epochs=35.91, elapsed=0.16, elbo=-703.77
# i=2997, epochs=35.93, elapsed=0.16, elbo=-700.03
# i=2998, epochs=35.94, elapsed=0.16, elbo=-703.13
# i=2999, epochs=35.95, elapsed=0.16, elbo=-703.36
# i=3000, epochs=35.96, elapsed=0.16, elbo=-701.57
# i=3001, epochs=35.97, elapsed=0.16, elbo=-702.43
# i=3002, epochs=35.99, elapsed=0.16, elbo=-703.96
# i=3003, epochs=36.00, elapsed=0.16, elbo=-702.40
# i=3004, epochs=36.01, elapsed=0.16, elbo=-702.53
# i=3005, epochs=36.02, elapsed=0.16, elbo=-702.42
# i=3006, epochs=36.03, elapsed=0.16, elbo=-702.99
# i=3007, epochs=36.05, elapsed=0.16, elbo=-701.52
# i=3008, epochs=36.06, elapsed=0.16, elbo=-702.91
# i=3009, epochs=36.07, elapsed=0.16, elbo=-703.64
# i=3010, epochs=36.08, elapsed=0.16, elbo=-701.98
# i=3011, epochs=36.09, elapsed=0.16, elbo=-703.10
# i=3012, epochs=36.11, elapsed=0.16, elbo=-701.45
# i=3013, epochs=36.12, elapsed=0.16, elbo=-702.31
# i=3014, epochs=36.13, elapsed=0.16, elbo=-703.10
# i=3015, epochs=36.14, elapsed=0.16, elbo=-701.12
# i=3016, epochs=36.15, elapsed=0.16, elbo=-703.65
# i=3017, epochs=36.17, elapsed=0.16, elbo=-703.05
# i=3018, epochs=36.18, elapsed=0.16, elbo=-701.36
# i=3019, epochs=36.19, elapsed=0.16, elbo=-701.56
# i=3020, epochs=36.20, elapsed=0.16, elbo=-703.79
# i=3021, epochs=36.21, elapsed=0.16, elbo=-702.74
# i=3022, epochs=36.23, elapsed=0.16, elbo=-701.66
# i=3023, epochs=36.24, elapsed=0.16, elbo=-702.53
# i=3024, epochs=36.25, elapsed=0.16, elbo=-702.53
# i=3025, epochs=36.26, elapsed=0.16, elbo=-701.83
# i=3026, epochs=36.27, elapsed=0.16, elbo=-701.75
# i=3027, epochs=36.29, elapsed=0.16, elbo=-703.14
# i=3028, epochs=36.30, elapsed=0.16, elbo=-702.80
# i=3029, epochs=36.31, elapsed=0.16, elbo=-701.83
# i=3030, epochs=36.32, elapsed=0.16, elbo=-702.08
# i=3031, epochs=36.33, elapsed=0.16, elbo=-702.46
# i=3032, epochs=36.35, elapsed=0.16, elbo=-702.51
# i=3033, epochs=36.36, elapsed=0.16, elbo=-702.54
# i=3034, epochs=36.37, elapsed=0.16, elbo=-702.40
# i=3035, epochs=36.38, elapsed=0.16, elbo=-703.49
# i=3036, epochs=36.39, elapsed=0.16, elbo=-702.98
# i=3037, epochs=36.41, elapsed=0.16, elbo=-702.20
# i=3038, epochs=36.42, elapsed=0.16, elbo=-703.73
# i=3039, epochs=36.43, elapsed=0.16, elbo=-703.09
# i=3040, epochs=36.44, elapsed=0.16, elbo=-703.26
# i=3041, epochs=36.45, elapsed=0.16, elbo=-702.87
# i=3042, epochs=36.47, elapsed=0.16, elbo=-703.73
# i=3043, epochs=36.48, elapsed=0.16, elbo=-702.28
# i=3044, epochs=36.49, elapsed=0.16, elbo=-704.11
# i=3045, epochs=36.50, elapsed=0.16, elbo=-703.12
# i=3046, epochs=36.51, elapsed=0.16, elbo=-703.10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-6f19898a5050> in <module>
#       4 for i in range(1, args.num_steps + 1):
#       5
# ----> 6     loss = svi.step(X, batch_size=args.batch_size, z_pres_prior_p=partial(z_pres_prior_p, i))
#       7
#       8     if args.progress_every > 0 and i % args.progress_every == 0:
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/pyro/infer/svi.py in step(self, *args, **kwargs)
#     126         # get loss and compute gradients
#     127         with poutine.trace(param_only=True) as param_capture:
# --> 128             loss = self.loss_and_grads(self.model, self.guide, *args, **kwargs)
#     129
#     130         params = set(site["value"].unconstrained()
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/pyro/infer/tracegraph_elbo.py in loss_and_grads(self, model, guide, *args, **kwargs)
#     255         elbo, surrogate_loss = self._loss_and_surrogate_loss(model, guide, args, kwargs)
#     256
# --> 257         torch_backward(surrogate_loss, retain_graph=self.retain_graph)
#     258
#     259         elbo = torch_item(elbo)
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/pyro/infer/util.py in torch_backward(x, retain_graph)
#      53     """
#      54     if torch.is_tensor(x) and x.grad_fn:
# ---> 55         x.backward(retain_graph=retain_graph)
#      56
#      57
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     193                 products. Defaults to ``False``.
#     194         """
# --> 195         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     196
#     197     def register_hook(self, hook):
#
# ~/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:
