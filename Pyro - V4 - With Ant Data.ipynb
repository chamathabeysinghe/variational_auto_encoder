# %%
import argparse
import math
import os
import time
from functools import partial

import numpy as np
import torch
import visdom

import pyro
import pyro.contrib.examples.multi_mnist as multi_mnist
import pyro.optim as optim
import pyro.poutine as poutine
from components.AIR import AIR, latents_to_tensor
from pyro.contrib.examples.util import get_data_directory
from pyro.infer import SVI, JitTraceGraph_ELBO, TraceGraph_ELBO
from utils.viz import draw_many, tensor_to_objs
from utils.visualizer import plot_mnist_sample

# %% [markdown]
# ## Support functions

# %%
def count_accuracy(X, true_counts, air, batch_size):
    assert X.size(0) == true_counts.size(0), 'Size mismatch.'
    assert X.size(0) % batch_size == 0, 'Input size must be multiple of batch_size.'
    counts = torch.LongTensor(3, 4).zero_()
    error_latents = []
    error_indicators = []

    def count_vec_to_mat(vec, max_index):
        out = torch.LongTensor(vec.size(0), max_index + 1).zero_()
        out.scatter_(1, vec.type(torch.LongTensor).view(vec.size(0), 1), 1)
        return out

    for i in range(X.size(0) // batch_size):
        X_batch = X[i * batch_size:(i + 1) * batch_size]
        true_counts_batch = true_counts[i * batch_size:(i + 1) * batch_size]
        z_where, z_pres = air.guide(X_batch, batch_size)
        inferred_counts = sum(z.cpu() for z in z_pres).squeeze().data
        true_counts_m = count_vec_to_mat(true_counts_batch, 2)
        inferred_counts_m = count_vec_to_mat(inferred_counts, 3)
        counts += torch.mm(true_counts_m.t(), inferred_counts_m)
        error_ind = 1 - (true_counts_batch == inferred_counts)
        error_ix = error_ind.nonzero().squeeze()
        error_latents.append(latents_to_tensor((z_where, z_pres)).index_select(0, error_ix))
        error_indicators.append(error_ind)

    acc = counts.diag().sum().float() / X.size(0)
    error_indices = torch.cat(error_indicators).nonzero().squeeze()
    if X.is_cuda:
        error_indices = error_indices.cuda()
    return acc, counts, torch.cat(error_latents), error_indices


# Defines something like a truncated geometric. Like the geometric,
# this has the property that there's a constant difference in log prob
# between p(steps=n) and p(steps=n+1).
def make_prior(k):
    assert 0 < k <= 1
    u = 1 / (1 + k + k**2 + k**3)
    p0 = 1 - u
    p1 = 1 - (k * u) / p0
    p2 = 1 - (k**2 * u) / (p0 * p1)
    trial_probs = [p0, p1, p2]
    # dist = [1 - p0, p0 * (1 - p1), p0 * p1 * (1 - p2), p0 * p1 * p2]
    # print(dist)
    return lambda t: trial_probs[t]


# Implements "prior annealing" as described in this blog post:
# http://akosiorek.github.io/ml/2017/09/03/implementing-air.html

# That implementation does something very close to the following:
# --z-pres-prior (1 - 1e-15)
# --z-pres-prior-raw
# --anneal-prior exp
# --anneal-prior-to 1e-7
# --anneal-prior-begin 1000
# --anneal-prior-duration 1e6

# e.g. After 200K steps z_pres_p will have decayed to ~0.04

# These compute the value of a decaying value at time t.
# initial: initial value
# final: final value, reached after begin + duration steps
# begin: number of steps before decay begins
# duration: number of steps over which decay occurs
# t: current time step


def lin_decay(initial, final, begin, duration, t):
    assert duration > 0
    x = (final - initial) * (t - begin) / duration + initial
    return max(min(x, initial), final)


def exp_decay(initial, final, begin, duration, t):
    assert final > 0
    assert duration > 0
    # half_life = math.log(2) / math.log(initial / final) * duration
    decay_rate = math.log(initial / final) / duration
    x = initial * math.exp(-decay_rate * (t - begin))
    return max(min(x, initial), final)

# %% [markdown]
# ## Args

# %%
parser = argparse.ArgumentParser(description="Pyro AIR example", argument_default=argparse.SUPPRESS)
parser.add_argument('-n', '--num-steps', type=int, default=int(1e8),
                    help='number of optimization steps to take')
parser.add_argument('-b', '--batch-size', type=int, default=64,
                    help='batch size')
parser.add_argument('-lr', '--learning-rate', type=float, default=1e-4,
                    help='learning rate')
parser.add_argument('-blr', '--baseline-learning-rate', type=float, default=1e-3,
                    help='baseline learning rate')
parser.add_argument('--progress-every', type=int, default=1,
                    help='number of steps between writing progress to stdout')
parser.add_argument('--eval-every', type=int, default=0,
                    help='number of steps between evaluations')
parser.add_argument('--baseline-scalar', type=float,
                    help='scale the output of the baseline nets by this value')
parser.add_argument('--no-baselines', action='store_true', default=False,
                    help='do not use data dependent baselines')
parser.add_argument('--encoder-net', type=int, nargs='+', default=[200],
                    help='encoder net hidden layer sizes')
parser.add_argument('--decoder-net', type=int, nargs='+', default=[200],
                    help='decoder net hidden layer sizes')
parser.add_argument('--predict-net', type=int, nargs='+',
                    help='predict net hidden layer sizes')
parser.add_argument('--embed-net', type=int, nargs='+',
                    help='embed net architecture')
parser.add_argument('--bl-predict-net', type=int, nargs='+',
                    help='baseline predict net hidden layer sizes')
parser.add_argument('--non-linearity', type=str,
                    help='non linearity to use throughout')
parser.add_argument('--viz', action='store_true', default=True,
                    help='generate vizualizations during optimization')
parser.add_argument('--viz-every', type=int, default=2,
                    help='number of steps between vizualizations')
parser.add_argument('--visdom-env', default='main',
                    help='visdom enviroment name')
parser.add_argument('--load', type=str,
                    help='load previously saved parameters')
parser.add_argument('--save', type=str,
                    help='save parameters to specified file')
parser.add_argument('--save-every', type=int, default=1e4,
                    help='number of steps between parameter saves')
parser.add_argument('--cuda', action='store_true', default=False,
                    help='use cuda')
parser.add_argument('--jit', action='store_true', default=False,
                    help='use PyTorch jit')
parser.add_argument('-t', '--model-steps', type=int, default=3,
                    help='number of time steps')
parser.add_argument('--rnn-hidden-size', type=int, default=256,
                    help='rnn hidden size')
parser.add_argument('--encoder-latent-size', type=int, default=50,
                    help='attention window encoder/decoder latent space size')
parser.add_argument('--decoder-output-bias', type=float,
                    help='bias added to decoder output (prior to applying non-linearity)')
parser.add_argument('--decoder-output-use-sigmoid', action='store_true',
                    help='apply sigmoid function to output of decoder network')
parser.add_argument('--window-size', type=int, default=60,
                    help='attention window size')
parser.add_argument('--z-pres-prior', type=float, default=0.5,
                    help='prior success probability for z_pres')
parser.add_argument('--z-pres-prior-raw', action='store_true', default=False,
                    help='use --z-pres-prior directly as success prob instead of a geometric like prior')
parser.add_argument('--anneal-prior', choices='none lin exp'.split(), default='none',
                    help='anneal z_pres prior during optimization')
parser.add_argument('--anneal-prior-to', type=float, default=1e-7,
                    help='target z_pres prior prob')
parser.add_argument('--anneal-prior-begin', type=int, default=0,
                    help='number of steps to wait before beginning to anneal the prior')
parser.add_argument('--anneal-prior-duration', type=int, default=100000,
                    help='number of steps over which to anneal the prior')
parser.add_argument('--pos-prior-mean', type=float,
                    help='mean of the window position prior')
parser.add_argument('--pos-prior-sd', type=float,
                    help='std. dev. of the window position prior')
parser.add_argument('--scale-prior-mean', type=float,
                    help='mean of the window scale prior')
parser.add_argument('--scale-prior-sd', type=float,
                    help='std. dev. of the window scale prior')
parser.add_argument('--no-masking', action='store_true', default=False,
                    help='do not mask out the costs of unused choices')
parser.add_argument('--seed', type=int, help='random seed', default=None)
parser.add_argument('-v', '--verbose', action='store_true', default=False,
                    help='write hyper parameters and network architecture to stdout')
# Out:
# _StoreTrueAction(option_strings=['-v', '--verbose'], dest='verbose', nargs=0, const=True, default=False, type=None, choices=None, help='write hyper parameters and network architecture to stdout', metavar=None)

# %%
# vars(parser.parse_args(""))
args = argparse.Namespace(**vars(parser.parse_args("")))

# %%
if 'save' in args:
    if os.path.exists(args.save):
        raise RuntimeError('Output file "{}" already exists.'.format(args.save))

if args.seed is not None:
    pyro.set_rng_seed(args.seed)

# Build a function to compute z_pres prior probabilities.
if args.z_pres_prior_raw:
    def base_z_pres_prior_p(t):
        return args.z_pres_prior
else:
    base_z_pres_prior_p = make_prior(args.z_pres_prior)

# Wrap with logic to apply any annealing.
def z_pres_prior_p(opt_step, time_step):
    p = base_z_pres_prior_p(time_step)
    if args.anneal_prior == 'none':
        return p
    else:
        decay = dict(lin=lin_decay, exp=exp_decay)[args.anneal_prior]
        return decay(p, args.anneal_prior_to, args.anneal_prior_begin,
                     args.anneal_prior_duration, opt_step)

# %% [markdown]
# ## Data loader

# %%
def load_data():
#     inpath = './air/.data'
#     X_np, Y = multi_mnist.load(inpath)
    X_np = np.load('/Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/data/ANTS2/masks_400x400.npy')
    X_np = X_np.astype(np.float32)
    X_np /= 255.0
    X = torch.from_numpy(X_np)
    # Using FloatTensor to allow comparison with values sampled from
    # Bernoulli.
    counts = torch.FloatTensor([1 for objs in X_np])
    return X, counts

# %%
X, true_counts = load_data()
X_size = X.size(0)
if args.cuda:
    X = X.cuda()

# %% [markdown]
# ## Model

# %%
model_arg_keys = ['window_size',
                  'rnn_hidden_size',
                  'decoder_output_bias',
                  'decoder_output_use_sigmoid',
                  'baseline_scalar',
                  'encoder_net',
                  'decoder_net',
                  'predict_net',
                  'embed_net',
                  'bl_predict_net',
                  'non_linearity',
                  'pos_prior_mean',
                  'pos_prior_sd',
                  'scale_prior_mean',
                  'scale_prior_sd']
model_args = {key: getattr(args, key) for key in model_arg_keys if key in args}

# %%
air = AIR(
        num_steps=args.model_steps,
        x_size=400,
        use_masking=not args.no_masking,
        use_baselines=not args.no_baselines,
        z_what_size=args.encoder_latent_size,
        use_cuda=args.cuda,
        **model_args
    )

# %%
if 'load' in args:
    print('Loading parameters...')
    air.load_state_dict(torch.load(args.load))

# %% [markdown]
# ## Visualize

# %%
if args.viz:
    vis = visdom.Visdom(env=args.visdom_env)
    z, x = air.prior(5, z_pres_prior_p=partial(z_pres_prior_p, 0))
    vis.images(draw_many(x, tensor_to_objs(latents_to_tensor(z))))
# Out:
# Setting up a new session...
# /Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/nn/functional.py:2764: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "
# /Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/venv_pytorch/lib/python3.7/site-packages/torch/nn/functional.py:2705: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn("Default grid_sample and affine_grid behavior has changed "

# %% [markdown]
# ## Optimizer

# %%
def isBaselineParam(module_name, param_name):
    return 'bl_' in module_name or 'bl_' in param_name

def per_param_optim_args(module_name, param_name):
    lr = args.baseline_learning_rate if isBaselineParam(module_name, param_name) else args.learning_rate
    return {'lr': lr}

adam = optim.Adam(per_param_optim_args)
elbo = JitTraceGraph_ELBO() if args.jit else TraceGraph_ELBO()
svi = SVI(air.model, air.guide, adam, loss=elbo)

# %%
t0 = time.time()
examples_to_viz = X[5:10]

for i in range(1, args.num_steps + 1):

    loss = svi.step(X, batch_size=args.batch_size, z_pres_prior_p=partial(z_pres_prior_p, i))

    if args.progress_every > 0 and i % args.progress_every == 0:
        print('i={}, epochs={:.2f}, elapsed={:.2f}, elbo={:.2f}'.format(
            i,
            (i * args.batch_size) / X_size,
            (time.time() - t0) / 3600,
            loss / X_size))

    if args.viz and i % args.viz_every == 0:
        print('Drawing')
        trace = poutine.trace(air.guide).get_trace(examples_to_viz, None)
        z, recons = poutine.replay(air.prior, trace=trace)(examples_to_viz.size(0))
        z_wheres = tensor_to_objs(latents_to_tensor(z))

        # Show data with inferred objection positions.
        vis.images(draw_many(examples_to_viz, z_wheres))
        # Show reconstructions of data.
        vis.images(draw_many(recons, z_wheres))

    if args.eval_every > 0 and i % args.eval_every == 0:
        # Measure accuracy on subset of training data.
        acc, counts, error_z, error_ix = count_accuracy(X, true_counts, air, 1000)
        print('i={}, accuracy={}, counts={}'.format(i, acc, counts.numpy().tolist()))
        if args.viz and error_ix.size(0) > 0:
            vis.images(draw_many(X[error_ix[0:5]], tensor_to_objs(error_z[0:5])),
                       opts=dict(caption='errors ({})'.format(i)))

    if 'save' in args and i % args.save_every == 0:
        print('Saving parameters...')
        torch.save(air.state_dict(), args.save)
# Out:
# i=1, epochs=0.01, elapsed=0.00, elbo=-43560.35
# i=2, epochs=0.02, elapsed=0.01, elbo=-43873.53
# Drawing
# i=3, epochs=0.04, elapsed=0.01, elbo=-43901.61
# i=4, epochs=0.05, elapsed=0.01, elbo=-44116.16
# Drawing
# i=5, epochs=0.06, elapsed=0.02, elbo=-44038.20
# i=6, epochs=0.07, elapsed=0.02, elbo=-44024.16
# Drawing
# i=7, epochs=0.08, elapsed=0.02, elbo=-44176.02
# i=8, epochs=0.10, elapsed=0.02, elbo=-44100.34
# Drawing
# i=9, epochs=0.11, elapsed=0.03, elbo=-44242.08
# i=10, epochs=0.12, elapsed=0.03, elbo=-43942.19
# Drawing
# i=11, epochs=0.13, elapsed=0.03, elbo=-43981.84
# i=12, epochs=0.14, elapsed=0.04, elbo=-44189.46
# Drawing
# i=13, epochs=0.16, elapsed=0.04, elbo=-44119.58
# i=14, epochs=0.17, elapsed=0.04, elbo=-44366.00
# Drawing
# i=15, epochs=0.18, elapsed=0.04, elbo=-44322.22
# i=16, epochs=0.19, elapsed=0.05, elbo=-44235.07
# Drawing
# i=17, epochs=0.20, elapsed=0.05, elbo=-44080.97
# i=18, epochs=0.22, elapsed=0.05, elbo=-44302.06
# Drawing
# i=19, epochs=0.23, elapsed=0.06, elbo=-44056.67
# i=20, epochs=0.24, elapsed=0.06, elbo=-44282.33
# Drawing
# i=21, epochs=0.25, elapsed=0.06, elbo=-44125.23
# i=22, epochs=0.26, elapsed=0.06, elbo=-44333.66
# Drawing
# i=23, epochs=0.28, elapsed=0.07, elbo=-44192.23
# i=24, epochs=0.29, elapsed=0.07, elbo=-44418.19
# Drawing
# i=25, epochs=0.30, elapsed=0.08, elbo=-44377.09
# i=26, epochs=0.31, elapsed=0.08, elbo=-44253.34
# Drawing
# i=27, epochs=0.32, elapsed=0.08, elbo=-44336.60
# i=28, epochs=0.34, elapsed=0.09, elbo=-44319.51
# Drawing
# i=29, epochs=0.35, elapsed=0.09, elbo=-44329.16
# i=30, epochs=0.36, elapsed=0.09, elbo=-44570.22
# Drawing
# i=31, epochs=0.37, elapsed=0.10, elbo=-44385.77
# i=32, epochs=0.38, elapsed=0.10, elbo=-44400.72
# Drawing
# i=33, epochs=0.40, elapsed=0.10, elbo=-44401.85
# i=34, epochs=0.41, elapsed=0.11, elbo=-44330.12
# Drawing
# i=35, epochs=0.42, elapsed=0.11, elbo=-44268.99
# i=36, epochs=0.43, elapsed=0.11, elbo=-44533.63
# Drawing
# i=37, epochs=0.44, elapsed=0.12, elbo=-44569.70
# i=38, epochs=0.46, elapsed=0.12, elbo=-44487.34
# Drawing
# i=39, epochs=0.47, elapsed=0.12, elbo=-44505.99
# i=40, epochs=0.48, elapsed=0.13, elbo=-44507.61
# Drawing
# i=41, epochs=0.49, elapsed=0.13, elbo=-44323.88
# i=42, epochs=0.50, elapsed=0.13, elbo=-44533.36
# Drawing
# i=43, epochs=0.52, elapsed=0.14, elbo=-44469.11
# i=44, epochs=0.53, elapsed=0.14, elbo=-44499.30
# Drawing
# i=45, epochs=0.54, elapsed=0.14, elbo=-44396.51
# i=46, epochs=0.55, elapsed=0.15, elbo=-44434.95
# Drawing
# i=47, epochs=0.56, elapsed=0.15, elbo=-44449.04
# i=48, epochs=0.58, elapsed=0.15, elbo=-44658.48
# Drawing
# i=49, epochs=0.59, elapsed=0.15, elbo=-44552.43
# i=50, epochs=0.60, elapsed=0.16, elbo=-44429.52
# Drawing
# i=51, epochs=0.61, elapsed=0.16, elbo=-44483.71
# i=52, epochs=0.62, elapsed=0.16, elbo=-44745.21
# Drawing
# i=53, epochs=0.64, elapsed=0.17, elbo=-44598.06
# i=54, epochs=0.65, elapsed=0.17, elbo=-44438.99
# Drawing
# i=55, epochs=0.66, elapsed=0.17, elbo=-44529.66
# i=56, epochs=0.67, elapsed=0.18, elbo=-44529.90
# Drawing
# i=57, epochs=0.68, elapsed=0.18, elbo=-44453.99
# i=58, epochs=0.70, elapsed=0.18, elbo=-44635.64
# Drawing
# i=59, epochs=0.71, elapsed=0.19, elbo=-44676.62
# i=60, epochs=0.72, elapsed=0.19, elbo=-44529.56
# Drawing
# i=61, epochs=0.73, elapsed=0.19, elbo=-44576.16
# i=62, epochs=0.74, elapsed=0.19, elbo=-44624.96
# Drawing
# i=63, epochs=0.76, elapsed=0.20, elbo=-44773.30
# i=64, epochs=0.77, elapsed=0.20, elbo=-44590.90
# Drawing
# i=65, epochs=0.78, elapsed=0.20, elbo=-44426.37
# i=66, epochs=0.79, elapsed=0.20, elbo=-44576.89
# Drawing
# i=67, epochs=0.80, elapsed=0.21, elbo=-44486.27
# i=68, epochs=0.82, elapsed=0.21, elbo=-44667.12
# Drawing
# i=69, epochs=0.83, elapsed=0.21, elbo=-44528.58
# i=70, epochs=0.84, elapsed=0.22, elbo=-44618.73
# Drawing
# i=71, epochs=0.85, elapsed=0.22, elbo=-44653.11
# i=72, epochs=0.86, elapsed=0.22, elbo=-44601.43
# Drawing
# i=73, epochs=0.88, elapsed=0.22, elbo=-44600.71
# i=74, epochs=0.89, elapsed=0.23, elbo=-44646.25
# Drawing
# i=75, epochs=0.90, elapsed=0.23, elbo=-44724.78
# i=76, epochs=0.91, elapsed=0.23, elbo=-44577.24
# Drawing
# i=77, epochs=0.92, elapsed=0.24, elbo=-44603.49
# i=78, epochs=0.94, elapsed=0.24, elbo=-44705.02
# Drawing
# i=79, epochs=0.95, elapsed=0.24, elbo=-44675.91
# i=80, epochs=0.96, elapsed=0.24, elbo=-44670.68
# Drawing
# i=81, epochs=0.97, elapsed=0.25, elbo=-44740.99
# i=82, epochs=0.98, elapsed=0.25, elbo=-44696.12
# Drawing
# i=83, epochs=0.99, elapsed=0.25, elbo=-44706.81
# i=84, epochs=1.01, elapsed=0.25, elbo=-44673.90
# Drawing
# i=85, epochs=1.02, elapsed=0.26, elbo=-44544.89
# i=86, epochs=1.03, elapsed=0.26, elbo=-44564.18
# Drawing
# i=87, epochs=1.04, elapsed=0.26, elbo=-44623.44
# i=88, epochs=1.05, elapsed=0.27, elbo=-44664.67
# Drawing
# i=89, epochs=1.07, elapsed=0.27, elbo=-44654.26
# i=90, epochs=1.08, elapsed=0.27, elbo=-44657.31
# Drawing
# i=91, epochs=1.09, elapsed=0.27, elbo=-44607.26
# i=92, epochs=1.10, elapsed=0.28, elbo=-44558.45
# Drawing
# i=93, epochs=1.11, elapsed=0.28, elbo=-44797.69
# i=94, epochs=1.13, elapsed=0.28, elbo=-44588.15
# Drawing
# i=95, epochs=1.14, elapsed=0.29, elbo=-44578.88
# i=96, epochs=1.15, elapsed=0.29, elbo=-44679.59
# Drawing
# i=97, epochs=1.16, elapsed=0.29, elbo=-44816.80
# i=98, epochs=1.17, elapsed=0.30, elbo=-44734.55
# Drawing
# i=99, epochs=1.19, elapsed=0.30, elbo=-44625.38
# i=100, epochs=1.20, elapsed=0.30, elbo=-44735.43
# Drawing
# i=101, epochs=1.21, elapsed=0.31, elbo=-44728.65
# i=102, epochs=1.22, elapsed=0.31, elbo=-44674.78
# Drawing
# i=103, epochs=1.23, elapsed=0.31, elbo=-44765.91
# i=104, epochs=1.25, elapsed=0.31, elbo=-44755.20
# Drawing
# i=105, epochs=1.26, elapsed=0.32, elbo=-44642.92
# i=106, epochs=1.27, elapsed=0.32, elbo=-44760.52
# Drawing
# i=107, epochs=1.28, elapsed=0.32, elbo=-44647.29
# i=108, epochs=1.29, elapsed=0.33, elbo=-44712.55
# Drawing
# i=109, epochs=1.31, elapsed=0.33, elbo=-44703.32
# i=110, epochs=1.32, elapsed=0.33, elbo=-44795.23
# Drawing
# i=111, epochs=1.33, elapsed=0.33, elbo=-44609.32
# i=112, epochs=1.34, elapsed=0.34, elbo=-44757.81
# Drawing
# i=113, epochs=1.35, elapsed=0.34, elbo=-44641.65
# i=114, epochs=1.37, elapsed=0.34, elbo=-44854.17
# Drawing
# i=115, epochs=1.38, elapsed=0.34, elbo=-44737.71
# i=116, epochs=1.39, elapsed=0.35, elbo=-44798.09
# Drawing
# i=117, epochs=1.40, elapsed=0.35, elbo=-44417.94
# i=118, epochs=1.41, elapsed=0.35, elbo=-44739.68
# Drawing
# i=119, epochs=1.43, elapsed=0.36, elbo=-44638.92
# i=120, epochs=1.44, elapsed=0.36, elbo=-44766.90
# Drawing
# i=121, epochs=1.45, elapsed=0.36, elbo=-44765.50
# i=122, epochs=1.46, elapsed=0.36, elbo=-44850.32
# Drawing
# i=123, epochs=1.47, elapsed=0.37, elbo=-44837.77
# i=124, epochs=1.49, elapsed=0.37, elbo=-44749.04
# Drawing
# i=125, epochs=1.50, elapsed=0.37, elbo=-44715.46
# i=126, epochs=1.51, elapsed=0.38, elbo=-44797.12
# Drawing
# i=127, epochs=1.52, elapsed=0.38, elbo=-44721.34
# i=128, epochs=1.53, elapsed=0.38, elbo=-44591.29
# Drawing
# i=129, epochs=1.55, elapsed=0.39, elbo=-44623.94
# i=130, epochs=1.56, elapsed=0.39, elbo=-44833.55
# Drawing
# i=131, epochs=1.57, elapsed=0.39, elbo=-44693.58
# i=132, epochs=1.58, elapsed=0.40, elbo=-44763.60
# Drawing
# i=133, epochs=1.59, elapsed=0.40, elbo=-44762.72
# i=134, epochs=1.61, elapsed=0.40, elbo=-44612.86
# Drawing
# i=135, epochs=1.62, elapsed=0.41, elbo=-44765.96
# i=136, epochs=1.63, elapsed=0.41, elbo=-44796.78
# Drawing
# i=137, epochs=1.64, elapsed=0.41, elbo=-44713.52
# i=138, epochs=1.65, elapsed=0.41, elbo=-44740.68
# Drawing
# i=139, epochs=1.67, elapsed=0.42, elbo=-44695.88
# i=140, epochs=1.68, elapsed=0.42, elbo=-44545.12
# Drawing
# i=141, epochs=1.69, elapsed=0.42, elbo=-44724.10
# i=142, epochs=1.70, elapsed=0.43, elbo=-44771.55
# Drawing
# i=143, epochs=1.71, elapsed=0.43, elbo=-44779.08
# i=144, epochs=1.73, elapsed=0.43, elbo=-44802.50
# Drawing
# i=145, epochs=1.74, elapsed=0.43, elbo=-44712.54
# i=146, epochs=1.75, elapsed=0.44, elbo=-44726.36
# Drawing
# i=147, epochs=1.76, elapsed=0.44, elbo=-44799.69
# i=148, epochs=1.77, elapsed=0.44, elbo=-44701.54
# Drawing
# i=149, epochs=1.79, elapsed=0.45, elbo=-44801.17
# i=150, epochs=1.80, elapsed=0.45, elbo=-44746.18
# Drawing
# i=151, epochs=1.81, elapsed=0.45, elbo=-44714.91
# i=152, epochs=1.82, elapsed=0.46, elbo=-44725.56
# Drawing
# i=153, epochs=1.83, elapsed=0.46, elbo=-44726.50
# i=154, epochs=1.85, elapsed=0.46, elbo=-44659.58
# Drawing
# i=155, epochs=1.86, elapsed=0.47, elbo=-44776.87
# i=156, epochs=1.87, elapsed=0.47, elbo=-44748.69
# Drawing
# i=157, epochs=1.88, elapsed=0.47, elbo=-44860.64
# i=158, epochs=1.89, elapsed=0.48, elbo=-44791.90
# Drawing
# i=159, epochs=1.91, elapsed=0.48, elbo=-44738.40
# i=160, epochs=1.92, elapsed=0.48, elbo=-44658.90
# Drawing
# i=161, epochs=1.93, elapsed=0.49, elbo=-44830.29
# i=162, epochs=1.94, elapsed=0.49, elbo=-44758.25
# Drawing
# i=163, epochs=1.95, elapsed=0.49, elbo=-44771.63
# i=164, epochs=1.97, elapsed=0.50, elbo=-44770.99
# Drawing
# i=165, epochs=1.98, elapsed=0.50, elbo=-44773.30
# i=166, epochs=1.99, elapsed=0.50, elbo=-44812.80
# Drawing
# i=167, epochs=2.00, elapsed=0.51, elbo=-44778.30
# i=168, epochs=2.01, elapsed=0.51, elbo=-44838.49
# Drawing
# i=169, epochs=2.03, elapsed=0.51, elbo=-44788.57
# i=170, epochs=2.04, elapsed=0.51, elbo=-44740.50
# Drawing
# i=171, epochs=2.05, elapsed=0.52, elbo=-44750.89
# i=172, epochs=2.06, elapsed=0.52, elbo=-44828.99
# Drawing
# i=173, epochs=2.07, elapsed=0.52, elbo=-44790.37
# i=174, epochs=2.09, elapsed=0.53, elbo=-44843.07
# Drawing
# i=175, epochs=2.10, elapsed=0.53, elbo=-44813.33
# i=176, epochs=2.11, elapsed=0.53, elbo=-44886.95
# Drawing
# i=177, epochs=2.12, elapsed=0.53, elbo=-44846.44
# i=178, epochs=2.13, elapsed=0.54, elbo=-44846.69
# Drawing
# i=179, epochs=2.15, elapsed=0.54, elbo=-44744.45
# i=180, epochs=2.16, elapsed=0.54, elbo=-44704.91
# Drawing
# i=181, epochs=2.17, elapsed=0.55, elbo=-44764.24
# i=182, epochs=2.18, elapsed=0.55, elbo=-44806.24
# Drawing
# i=183, epochs=2.19, elapsed=0.55, elbo=-44840.90
# i=184, epochs=2.21, elapsed=0.55, elbo=-44661.01
# Drawing
# i=185, epochs=2.22, elapsed=0.56, elbo=-44807.92
# i=186, epochs=2.23, elapsed=0.56, elbo=-44873.99
# Drawing
# i=187, epochs=2.24, elapsed=0.56, elbo=-44882.95
# i=188, epochs=2.25, elapsed=0.57, elbo=-44872.07
# Drawing
# i=189, epochs=2.27, elapsed=0.57, elbo=-44844.89
# i=190, epochs=2.28, elapsed=0.57, elbo=-44753.19
# Drawing
# i=191, epochs=2.29, elapsed=0.58, elbo=-44799.81
# i=192, epochs=2.30, elapsed=0.58, elbo=-44855.86
# Drawing
# i=193, epochs=2.31, elapsed=0.58, elbo=-44774.96
# i=194, epochs=2.33, elapsed=0.58, elbo=-44806.53
# Drawing
# i=195, epochs=2.34, elapsed=0.59, elbo=-44840.20
# i=196, epochs=2.35, elapsed=0.59, elbo=-44889.00
# Drawing
# i=197, epochs=2.36, elapsed=0.59, elbo=-44694.29
# i=198, epochs=2.37, elapsed=0.59, elbo=-44841.65
# Drawing
# i=199, epochs=2.39, elapsed=0.60, elbo=-44843.56
# i=200, epochs=2.40, elapsed=0.60, elbo=-44916.37
# Drawing
# i=201, epochs=2.41, elapsed=0.60, elbo=-44829.96
# i=202, epochs=2.42, elapsed=0.61, elbo=-44886.10
# Drawing
# i=203, epochs=2.43, elapsed=0.61, elbo=-44713.17
# i=204, epochs=2.45, elapsed=0.61, elbo=-44839.93
# Drawing
# i=205, epochs=2.46, elapsed=0.61, elbo=-44794.25
# i=206, epochs=2.47, elapsed=0.62, elbo=-44603.99
# Drawing
# i=207, epochs=2.48, elapsed=0.62, elbo=-44892.61
# i=208, epochs=2.49, elapsed=0.62, elbo=-44872.03
# Drawing
# i=209, epochs=2.51, elapsed=0.63, elbo=-44865.76
# i=210, epochs=2.52, elapsed=0.63, elbo=-44843.29
# Drawing
# i=211, epochs=2.53, elapsed=0.63, elbo=-44661.63
# i=212, epochs=2.54, elapsed=0.64, elbo=-44879.92
# Drawing
# i=213, epochs=2.55, elapsed=0.64, elbo=-44760.08
# i=214, epochs=2.57, elapsed=0.64, elbo=-44901.74
# Drawing
# i=215, epochs=2.58, elapsed=0.65, elbo=-44785.06
# i=216, epochs=2.59, elapsed=0.65, elbo=-44870.73
# Drawing
# i=217, epochs=2.60, elapsed=0.65, elbo=-44797.89
# i=218, epochs=2.61, elapsed=0.65, elbo=-44876.75
# Drawing
# i=219, epochs=2.63, elapsed=0.66, elbo=-44830.76
# i=220, epochs=2.64, elapsed=0.66, elbo=-44830.98
# Drawing
# i=221, epochs=2.65, elapsed=0.66, elbo=-44893.86
# i=222, epochs=2.66, elapsed=0.67, elbo=-44860.42
# Drawing
# i=223, epochs=2.67, elapsed=0.67, elbo=-44821.79
# i=224, epochs=2.69, elapsed=0.67, elbo=-44877.66
# Drawing
# i=225, epochs=2.70, elapsed=0.67, elbo=-44754.30
# i=226, epochs=2.71, elapsed=0.68, elbo=-44867.52
# Drawing
# i=227, epochs=2.72, elapsed=0.68, elbo=-44828.76
# i=228, epochs=2.73, elapsed=0.68, elbo=-44825.92
# Drawing
# i=229, epochs=2.75, elapsed=0.69, elbo=-44883.99
# i=230, epochs=2.76, elapsed=0.69, elbo=-44870.41
# Drawing
# i=231, epochs=2.77, elapsed=0.69, elbo=-44835.20
# i=232, epochs=2.78, elapsed=0.69, elbo=-44842.53
# Drawing
# i=233, epochs=2.79, elapsed=0.70, elbo=-44816.83
# i=234, epochs=2.81, elapsed=0.70, elbo=-44906.32
# Drawing
# i=235, epochs=2.82, elapsed=0.70, elbo=-44769.62
# i=236, epochs=2.83, elapsed=0.71, elbo=-44891.29
# Drawing
# i=237, epochs=2.84, elapsed=0.71, elbo=-44871.94
# i=238, epochs=2.85, elapsed=0.71, elbo=-44870.44
# Drawing
# i=239, epochs=2.86, elapsed=0.72, elbo=-44822.53
# i=240, epochs=2.88, elapsed=0.72, elbo=-44906.89
# Drawing
# i=241, epochs=2.89, elapsed=0.72, elbo=-44812.00
# i=242, epochs=2.90, elapsed=0.72, elbo=-44851.04
# Drawing
# i=243, epochs=2.91, elapsed=0.73, elbo=-44878.93
# i=244, epochs=2.92, elapsed=0.73, elbo=-44814.85
# Drawing
# i=245, epochs=2.94, elapsed=0.73, elbo=-44827.66
# i=246, epochs=2.95, elapsed=0.74, elbo=-44856.28
# Drawing
# i=247, epochs=2.96, elapsed=0.74, elbo=-44846.33
# i=248, epochs=2.97, elapsed=0.74, elbo=-44817.65
# Drawing
# i=249, epochs=2.98, elapsed=0.75, elbo=-44876.19
# i=250, epochs=3.00, elapsed=0.75, elbo=-44878.15
# Drawing
# i=251, epochs=3.01, elapsed=0.75, elbo=-44815.65
# i=252, epochs=3.02, elapsed=0.75, elbo=-44836.89
# Drawing
# i=253, epochs=3.03, elapsed=0.76, elbo=-44879.11
# i=254, epochs=3.04, elapsed=0.76, elbo=-44835.56
# Drawing
# i=255, epochs=3.06, elapsed=0.76, elbo=-44837.48
# i=256, epochs=3.07, elapsed=0.77, elbo=-44822.56
# Drawing
# i=257, epochs=3.08, elapsed=0.77, elbo=-44859.38
# i=258, epochs=3.09, elapsed=0.77, elbo=-44846.70
# Drawing
# i=259, epochs=3.10, elapsed=0.78, elbo=-44853.89
# i=260, epochs=3.12, elapsed=0.78, elbo=-44829.30
# Drawing
# i=261, epochs=3.13, elapsed=0.78, elbo=-44845.12
# i=262, epochs=3.14, elapsed=0.78, elbo=-44844.09
# Drawing
# i=263, epochs=3.15, elapsed=0.79, elbo=-44874.31
# i=264, epochs=3.16, elapsed=0.79, elbo=-44940.25
# Drawing
# i=265, epochs=3.18, elapsed=0.79, elbo=-44822.80
# i=266, epochs=3.19, elapsed=0.80, elbo=-44893.82
# Drawing
# i=267, epochs=3.20, elapsed=0.80, elbo=-44863.70
# i=268, epochs=3.21, elapsed=0.80, elbo=-44852.72
# Drawing
# i=269, epochs=3.22, elapsed=0.81, elbo=-44843.07
# i=270, epochs=3.24, elapsed=0.81, elbo=-44845.13
# Drawing
# i=271, epochs=3.25, elapsed=0.82, elbo=-44878.55
# i=272, epochs=3.26, elapsed=0.82, elbo=-44877.74
# Drawing
# i=273, epochs=3.27, elapsed=0.82, elbo=-44858.46
# i=274, epochs=3.28, elapsed=0.82, elbo=-44954.25
# Drawing
# i=275, epochs=3.30, elapsed=0.83, elbo=-44918.77
# i=276, epochs=3.31, elapsed=0.83, elbo=-44818.88
# Drawing
# i=277, epochs=3.32, elapsed=0.83, elbo=-44853.93
# i=278, epochs=3.33, elapsed=0.84, elbo=-44845.77
# Drawing
# i=279, epochs=3.34, elapsed=0.84, elbo=-44925.79
# i=280, epochs=3.36, elapsed=0.84, elbo=-44856.98
# Drawing
# i=281, epochs=3.37, elapsed=0.84, elbo=-44899.69
# i=282, epochs=3.38, elapsed=0.85, elbo=-44812.00
# Drawing
# i=283, epochs=3.39, elapsed=0.85, elbo=-44850.32
# i=284, epochs=3.40, elapsed=0.85, elbo=-44835.37
# Drawing
# i=285, epochs=3.42, elapsed=0.86, elbo=-44873.24
# i=286, epochs=3.43, elapsed=0.86, elbo=-44881.72
# Drawing
# i=287, epochs=3.44, elapsed=0.86, elbo=-44934.97
# i=288, epochs=3.45, elapsed=0.87, elbo=-44841.40
# Drawing
# i=289, epochs=3.46, elapsed=0.87, elbo=-44886.67
# i=290, epochs=3.48, elapsed=0.87, elbo=-44883.57
# Drawing
# i=291, epochs=3.49, elapsed=0.87, elbo=-44863.60
# i=292, epochs=3.50, elapsed=0.88, elbo=-44859.12
# Drawing
# i=293, epochs=3.51, elapsed=0.88, elbo=-44651.27
# i=294, epochs=3.52, elapsed=0.88, elbo=-44822.90
# Drawing
# i=295, epochs=3.54, elapsed=0.89, elbo=-44825.74
# i=296, epochs=3.55, elapsed=0.89, elbo=-44908.60
# Drawing
# i=297, epochs=3.56, elapsed=0.89, elbo=-44815.43
# i=298, epochs=3.57, elapsed=0.89, elbo=-44864.79
# Drawing
# i=299, epochs=3.58, elapsed=0.90, elbo=-44869.82
# i=300, epochs=3.60, elapsed=0.90, elbo=-44908.75
# Drawing
# i=301, epochs=3.61, elapsed=0.90, elbo=-44908.22
# i=302, epochs=3.62, elapsed=0.91, elbo=-44886.48
# Drawing
# i=303, epochs=3.63, elapsed=0.91, elbo=-44907.02
# i=304, epochs=3.64, elapsed=0.91, elbo=-44869.39
# Drawing
# i=305, epochs=3.66, elapsed=0.92, elbo=-44920.21
# i=306, epochs=3.67, elapsed=0.92, elbo=-44900.27
# Drawing
# i=307, epochs=3.68, elapsed=0.92, elbo=-44917.10
# i=308, epochs=3.69, elapsed=0.92, elbo=-44890.50
# Drawing
# i=309, epochs=3.70, elapsed=0.93, elbo=-44885.75
# i=310, epochs=3.72, elapsed=0.93, elbo=-44900.88
# Drawing
# i=311, epochs=3.73, elapsed=0.93, elbo=-44838.46
# i=312, epochs=3.74, elapsed=0.94, elbo=-44814.02
# Drawing
# i=313, epochs=3.75, elapsed=0.94, elbo=-44857.96
# i=314, epochs=3.76, elapsed=0.94, elbo=-44860.69
# Drawing
# i=315, epochs=3.78, elapsed=0.94, elbo=-44876.70
# i=316, epochs=3.79, elapsed=0.95, elbo=-44910.30
# Drawing
# i=317, epochs=3.80, elapsed=0.95, elbo=-44806.77
# i=318, epochs=3.81, elapsed=0.95, elbo=-44880.70
# Drawing
# i=319, epochs=3.82, elapsed=0.96, elbo=-44812.94
# i=320, epochs=3.84, elapsed=0.96, elbo=-44816.67
# Drawing
# i=321, epochs=3.85, elapsed=0.96, elbo=-44923.76
# i=322, epochs=3.86, elapsed=0.96, elbo=-44935.16
# Drawing
# i=323, epochs=3.87, elapsed=0.97, elbo=-44774.40
# i=324, epochs=3.88, elapsed=0.97, elbo=-44923.27
# Drawing
# i=325, epochs=3.90, elapsed=0.97, elbo=-44927.30
# i=326, epochs=3.91, elapsed=0.98, elbo=-44830.79
# Drawing
# i=327, epochs=3.92, elapsed=0.98, elbo=-44822.06
# i=328, epochs=3.93, elapsed=0.98, elbo=-44879.51
# Drawing
# i=329, epochs=3.94, elapsed=0.99, elbo=-44676.35
# i=330, epochs=3.96, elapsed=0.99, elbo=-44840.45
# Drawing
# i=331, epochs=3.97, elapsed=0.99, elbo=-44918.94
# i=332, epochs=3.98, elapsed=0.99, elbo=-44857.30
# Drawing
# i=333, epochs=3.99, elapsed=1.00, elbo=-44909.85
# i=334, epochs=4.00, elapsed=1.00, elbo=-44798.87
# Drawing
# i=335, epochs=4.02, elapsed=1.00, elbo=-44915.36
# i=336, epochs=4.03, elapsed=1.00, elbo=-44907.06
# Drawing
# i=337, epochs=4.04, elapsed=1.01, elbo=-44919.37
# i=338, epochs=4.05, elapsed=1.01, elbo=-44969.81
# Drawing
# i=339, epochs=4.06, elapsed=1.01, elbo=-44846.20
# i=340, epochs=4.08, elapsed=1.02, elbo=-44808.60
# Drawing
# i=341, epochs=4.09, elapsed=1.02, elbo=-44902.36
# i=342, epochs=4.10, elapsed=1.02, elbo=-44909.98
# Drawing
# i=343, epochs=4.11, elapsed=1.03, elbo=-44874.24
# i=344, epochs=4.12, elapsed=1.03, elbo=-44847.66
# Drawing
# i=345, epochs=4.14, elapsed=1.03, elbo=-44846.02
# i=346, epochs=4.15, elapsed=1.03, elbo=-44934.22
# Drawing
# i=347, epochs=4.16, elapsed=1.04, elbo=-44888.68
# i=348, epochs=4.17, elapsed=1.04, elbo=-44863.65
# Drawing
# i=349, epochs=4.18, elapsed=1.04, elbo=-44882.68
# i=350, epochs=4.20, elapsed=1.05, elbo=-44908.27
# Drawing
# i=351, epochs=4.21, elapsed=1.05, elbo=-44936.45
# i=352, epochs=4.22, elapsed=1.05, elbo=-44566.52
# Drawing
# i=353, epochs=4.23, elapsed=1.06, elbo=-45010.31
# i=354, epochs=4.24, elapsed=1.06, elbo=-44876.06
# Drawing
# i=355, epochs=4.26, elapsed=1.06, elbo=-44930.12
# i=356, epochs=4.27, elapsed=1.07, elbo=-44904.47
# Drawing
# i=357, epochs=4.28, elapsed=1.07, elbo=-44819.38
# i=358, epochs=4.29, elapsed=1.07, elbo=-44851.50
# Drawing
# i=359, epochs=4.30, elapsed=1.08, elbo=-44861.35
# i=360, epochs=4.32, elapsed=1.08, elbo=-44823.89
# Drawing
# i=361, epochs=4.33, elapsed=1.08, elbo=-44919.78
# i=362, epochs=4.34, elapsed=1.09, elbo=-44838.60
# Drawing
# i=363, epochs=4.35, elapsed=1.09, elbo=-44910.62
# i=364, epochs=4.36, elapsed=1.09, elbo=-44844.80
# Drawing
# i=365, epochs=4.38, elapsed=1.10, elbo=-44891.05
# i=366, epochs=4.39, elapsed=1.10, elbo=-44812.69
# Drawing
# i=367, epochs=4.40, elapsed=1.10, elbo=-44916.81
# i=368, epochs=4.41, elapsed=1.11, elbo=-44868.43
# Drawing
# i=369, epochs=4.42, elapsed=1.11, elbo=-44884.61
# i=370, epochs=4.44, elapsed=1.12, elbo=-44901.02
# Drawing
# i=371, epochs=4.45, elapsed=1.12, elbo=-44937.31
# i=372, epochs=4.46, elapsed=1.12, elbo=-44895.84
# Drawing
# i=373, epochs=4.47, elapsed=1.13, elbo=-44819.33
# i=374, epochs=4.48, elapsed=1.13, elbo=-44858.42
# Drawing
# i=375, epochs=4.50, elapsed=1.13, elbo=-44871.42
# i=376, epochs=4.51, elapsed=1.14, elbo=-44906.51
# Drawing
# i=377, epochs=4.52, elapsed=1.14, elbo=-44898.49
# i=378, epochs=4.53, elapsed=1.14, elbo=-44965.11
# Drawing
# i=379, epochs=4.54, elapsed=1.15, elbo=-44851.96
# i=380, epochs=4.56, elapsed=1.15, elbo=-44719.00
# Drawing
# i=381, epochs=4.57, elapsed=1.15, elbo=-44713.85
# i=382, epochs=4.58, elapsed=1.16, elbo=-44893.20
# Drawing
# i=383, epochs=4.59, elapsed=1.16, elbo=-44939.37
# i=384, epochs=4.60, elapsed=1.16, elbo=-44972.06
# Drawing
# i=385, epochs=4.62, elapsed=1.17, elbo=-44874.56
# i=386, epochs=4.63, elapsed=1.17, elbo=-44913.24
# Drawing
# i=387, epochs=4.64, elapsed=1.17, elbo=-44873.10
# i=388, epochs=4.65, elapsed=1.17, elbo=-44994.17
# Drawing
# i=389, epochs=4.66, elapsed=1.18, elbo=-44892.01
# i=390, epochs=4.68, elapsed=1.18, elbo=-44864.91
# Drawing
# i=391, epochs=4.69, elapsed=1.19, elbo=-44918.28
# i=392, epochs=4.70, elapsed=1.19, elbo=-44892.65
# Drawing
# i=393, epochs=4.71, elapsed=1.20, elbo=-44884.49
# i=394, epochs=4.72, elapsed=1.20, elbo=-44915.93
# Drawing
# i=395, epochs=4.73, elapsed=1.21, elbo=-44865.83
# i=396, epochs=4.75, elapsed=1.21, elbo=-44905.22
# Drawing
# i=397, epochs=4.76, elapsed=1.22, elbo=-44899.88
# i=398, epochs=4.77, elapsed=1.22, elbo=-44880.08
# Drawing
# i=399, epochs=4.78, elapsed=1.23, elbo=-44897.92
# i=400, epochs=4.79, elapsed=1.23, elbo=-44746.50
# Drawing
# i=401, epochs=4.81, elapsed=1.24, elbo=-44881.05
# i=402, epochs=4.82, elapsed=1.24, elbo=-44884.49
# Drawing
# i=403, epochs=4.83, elapsed=1.24, elbo=-44989.75
# i=404, epochs=4.84, elapsed=1.24, elbo=-44887.25
# Drawing
# i=405, epochs=4.85, elapsed=1.25, elbo=-44938.89
# i=406, epochs=4.87, elapsed=1.25, elbo=-44888.51
# Drawing
# i=407, epochs=4.88, elapsed=1.25, elbo=-44905.74
# i=408, epochs=4.89, elapsed=1.26, elbo=-44880.52
# Drawing
# i=409, epochs=4.90, elapsed=1.26, elbo=-44928.25
# i=410, epochs=4.91, elapsed=1.26, elbo=-44912.81
# Drawing
# i=411, epochs=4.93, elapsed=1.27, elbo=-44933.68
# i=412, epochs=4.94, elapsed=1.27, elbo=-44886.00
# Drawing
# i=413, epochs=4.95, elapsed=1.27, elbo=-44862.48
# i=414, epochs=4.96, elapsed=1.28, elbo=-44880.62
# Drawing
# i=415, epochs=4.97, elapsed=1.28, elbo=-44876.26
# i=416, epochs=4.99, elapsed=1.28, elbo=-44956.70
# Drawing
# i=417, epochs=5.00, elapsed=1.29, elbo=-44906.23
# i=418, epochs=5.01, elapsed=1.29, elbo=-44841.98
# Drawing
# i=419, epochs=5.02, elapsed=1.29, elbo=-44830.71
# i=420, epochs=5.03, elapsed=1.30, elbo=-44853.38
# Drawing
# i=421, epochs=5.05, elapsed=1.30, elbo=-44834.23
# i=422, epochs=5.06, elapsed=1.30, elbo=-44921.31
# Drawing
# i=423, epochs=5.07, elapsed=1.31, elbo=-44932.07
# i=424, epochs=5.08, elapsed=1.31, elbo=-44951.17
# Drawing
# i=425, epochs=5.09, elapsed=1.31, elbo=-44917.34
# i=426, epochs=5.11, elapsed=1.32, elbo=-44928.77
# Drawing
# i=427, epochs=5.12, elapsed=1.32, elbo=-44904.86
# i=428, epochs=5.13, elapsed=1.32, elbo=-44959.06
# Drawing
# i=429, epochs=5.14, elapsed=1.33, elbo=-44958.31
# i=430, epochs=5.15, elapsed=1.33, elbo=-44877.57
# Drawing
# i=431, epochs=5.17, elapsed=1.34, elbo=-44931.60
# i=432, epochs=5.18, elapsed=1.34, elbo=-44921.53
# Drawing
# i=433, epochs=5.19, elapsed=1.34, elbo=-44914.31
# i=434, epochs=5.20, elapsed=1.35, elbo=-44944.43
# Drawing
# i=435, epochs=5.21, elapsed=1.35, elbo=-44931.54
# i=436, epochs=5.23, elapsed=1.36, elbo=-44929.61
# Drawing
# i=437, epochs=5.24, elapsed=1.36, elbo=-44837.03
# i=438, epochs=5.25, elapsed=1.36, elbo=-44916.18
# Drawing
# i=439, epochs=5.26, elapsed=1.37, elbo=-44947.82
# i=440, epochs=5.27, elapsed=1.37, elbo=-44875.80
# Drawing
# i=441, epochs=5.29, elapsed=1.37, elbo=-44931.53
# i=442, epochs=5.30, elapsed=1.38, elbo=-44888.71
# Drawing
# i=443, epochs=5.31, elapsed=1.38, elbo=-44879.50
# i=444, epochs=5.32, elapsed=1.38, elbo=-44816.25
# Drawing
# i=445, epochs=5.33, elapsed=1.39, elbo=-44947.30
# i=446, epochs=5.35, elapsed=1.39, elbo=-44941.90
# Drawing
# i=447, epochs=5.36, elapsed=1.39, elbo=-44927.94
# i=448, epochs=5.37, elapsed=1.40, elbo=-44908.01
# Drawing
# i=449, epochs=5.38, elapsed=1.40, elbo=-44880.36
# i=450, epochs=5.39, elapsed=1.40, elbo=-44886.50
# Drawing
# i=451, epochs=5.41, elapsed=1.41, elbo=-44904.81
# i=452, epochs=5.42, elapsed=1.41, elbo=-44695.94
# Drawing
# i=453, epochs=5.43, elapsed=1.41, elbo=-44968.70
# i=454, epochs=5.44, elapsed=1.42, elbo=-44928.51
# Drawing
# i=455, epochs=5.45, elapsed=1.42, elbo=-44912.82
# i=456, epochs=5.47, elapsed=1.42, elbo=-44896.93
# Drawing
# i=457, epochs=5.48, elapsed=1.43, elbo=-44926.93
# i=458, epochs=5.49, elapsed=1.43, elbo=-44854.06
# Drawing
# i=459, epochs=5.50, elapsed=1.44, elbo=-44912.39
# i=460, epochs=5.51, elapsed=1.44, elbo=-44973.52
# Drawing
# i=461, epochs=5.53, elapsed=1.45, elbo=-44945.43
# i=462, epochs=5.54, elapsed=1.45, elbo=-44974.32
# Drawing
# i=463, epochs=5.55, elapsed=1.45, elbo=-44965.21
# i=464, epochs=5.56, elapsed=1.46, elbo=-44884.82
# Drawing
# i=465, epochs=5.57, elapsed=1.48, elbo=-44979.61
# i=466, epochs=5.59, elapsed=1.48, elbo=-44946.99
# Drawing
# i=467, epochs=5.60, elapsed=1.48, elbo=-44901.06
# i=468, epochs=5.61, elapsed=1.49, elbo=-44959.33
# Drawing
# i=469, epochs=5.62, elapsed=1.49, elbo=-44951.52
# i=470, epochs=5.63, elapsed=1.49, elbo=-44906.79
# Drawing
# i=471, epochs=5.65, elapsed=1.50, elbo=-44813.09
# i=472, epochs=5.66, elapsed=1.50, elbo=-44896.76
# Drawing
# i=473, epochs=5.67, elapsed=1.50, elbo=-44950.56
# i=474, epochs=5.68, elapsed=1.51, elbo=-44893.75
# Drawing
# i=475, epochs=5.69, elapsed=1.51, elbo=-44908.28
# i=476, epochs=5.71, elapsed=1.51, elbo=-44882.53
# Drawing
# i=477, epochs=5.72, elapsed=1.52, elbo=-44900.23
# i=478, epochs=5.73, elapsed=1.52, elbo=-44881.21
# Drawing
# i=479, epochs=5.74, elapsed=1.52, elbo=-44944.81
# i=480, epochs=5.75, elapsed=1.53, elbo=-44934.93
# Drawing
# i=481, epochs=5.77, elapsed=1.53, elbo=-44925.61
# i=482, epochs=5.78, elapsed=1.53, elbo=-44928.10
# Drawing
# i=483, epochs=5.79, elapsed=1.54, elbo=-44857.07
# i=484, epochs=5.80, elapsed=1.54, elbo=-44937.80
# Drawing
# i=485, epochs=5.81, elapsed=1.54, elbo=-44945.33
# i=486, epochs=5.83, elapsed=1.55, elbo=-44932.90
# Drawing
# i=487, epochs=5.84, elapsed=1.55, elbo=-44933.94
# i=488, epochs=5.85, elapsed=1.55, elbo=-44988.52
# Drawing
# i=489, epochs=5.86, elapsed=1.56, elbo=-44961.88
# i=490, epochs=5.87, elapsed=1.56, elbo=-44980.68
# Drawing
# i=491, epochs=5.89, elapsed=1.56, elbo=-44916.35
# i=492, epochs=5.90, elapsed=1.57, elbo=-44921.41
# Drawing
# i=493, epochs=5.91, elapsed=1.57, elbo=-44886.62
# i=494, epochs=5.92, elapsed=1.57, elbo=-44965.68
# Drawing
# i=495, epochs=5.93, elapsed=1.58, elbo=-44968.00
# i=496, epochs=5.95, elapsed=1.58, elbo=-44768.07
# Drawing
# i=497, epochs=5.96, elapsed=1.58, elbo=-44942.88
# i=498, epochs=5.97, elapsed=1.59, elbo=-44908.19
# Drawing
# i=499, epochs=5.98, elapsed=1.59, elbo=-44894.73
# i=500, epochs=5.99, elapsed=1.59, elbo=-44945.85
# Drawing
# i=501, epochs=6.01, elapsed=1.60, elbo=-44939.51
# i=502, epochs=6.02, elapsed=1.60, elbo=-44826.95
# Drawing
# i=503, epochs=6.03, elapsed=1.61, elbo=-44953.09
# i=504, epochs=6.04, elapsed=1.61, elbo=-44902.11
# Drawing
# i=505, epochs=6.05, elapsed=1.61, elbo=-44996.59
# i=506, epochs=6.07, elapsed=1.62, elbo=-44928.63
# Drawing
# i=507, epochs=6.08, elapsed=1.62, elbo=-45031.88
# i=508, epochs=6.09, elapsed=1.62, elbo=-44902.53
# Drawing
# i=509, epochs=6.10, elapsed=1.63, elbo=-44927.90
# i=510, epochs=6.11, elapsed=1.63, elbo=-44951.49
# Drawing
# i=511, epochs=6.13, elapsed=1.63, elbo=-44978.12
# i=512, epochs=6.14, elapsed=1.64, elbo=-44838.80
# Drawing
# i=513, epochs=6.15, elapsed=1.64, elbo=-44966.04
# i=514, epochs=6.16, elapsed=1.64, elbo=-44887.58
# Drawing
# i=515, epochs=6.17, elapsed=1.65, elbo=-44946.83
# i=516, epochs=6.19, elapsed=1.65, elbo=-44958.09
# Drawing
# i=517, epochs=6.20, elapsed=1.65, elbo=-44915.18
# i=518, epochs=6.21, elapsed=1.66, elbo=-44911.11
# Drawing
# i=519, epochs=6.22, elapsed=1.66, elbo=-44923.41
# i=520, epochs=6.23, elapsed=1.66, elbo=-44974.43
# Drawing
# i=521, epochs=6.25, elapsed=1.67, elbo=-44927.02
# i=522, epochs=6.26, elapsed=1.67, elbo=-44923.29
# Drawing
# i=523, epochs=6.27, elapsed=1.67, elbo=-44938.97
# i=524, epochs=6.28, elapsed=1.68, elbo=-44932.61
# Drawing
# i=525, epochs=6.29, elapsed=1.68, elbo=-44958.97
# i=526, epochs=6.31, elapsed=1.68, elbo=-44978.36
# Drawing
# i=527, epochs=6.32, elapsed=1.69, elbo=-44899.00
# i=528, epochs=6.33, elapsed=1.69, elbo=-44893.26
# Drawing
# i=529, epochs=6.34, elapsed=1.69, elbo=-44927.01
# i=530, epochs=6.35, elapsed=1.70, elbo=-44913.92
# Drawing
# i=531, epochs=6.37, elapsed=1.70, elbo=-44934.20
# i=532, epochs=6.38, elapsed=1.71, elbo=-45013.50
# Drawing
# i=533, epochs=6.39, elapsed=1.71, elbo=-44965.89
# i=534, epochs=6.40, elapsed=1.71, elbo=-44967.18
# Drawing
# i=535, epochs=6.41, elapsed=1.72, elbo=-44929.10
# i=536, epochs=6.43, elapsed=1.72, elbo=-44982.14
# Drawing
# i=537, epochs=6.44, elapsed=1.72, elbo=-44863.89
# i=538, epochs=6.45, elapsed=1.72, elbo=-44806.78
# Drawing
# i=539, epochs=6.46, elapsed=1.73, elbo=-45005.43
# i=540, epochs=6.47, elapsed=1.73, elbo=-44992.33
# Drawing
# i=541, epochs=6.49, elapsed=1.73, elbo=-44923.75
# i=542, epochs=6.50, elapsed=1.74, elbo=-44994.85
# Drawing
# i=543, epochs=6.51, elapsed=1.74, elbo=-44942.44
# i=544, epochs=6.52, elapsed=1.74, elbo=-44890.27
# Drawing
# i=545, epochs=6.53, elapsed=1.74, elbo=-44956.35
# i=546, epochs=6.55, elapsed=1.75, elbo=-44973.53
# Drawing
# i=547, epochs=6.56, elapsed=1.75, elbo=-44884.36
# i=548, epochs=6.57, elapsed=1.75, elbo=-44947.96
# Drawing
# i=549, epochs=6.58, elapsed=1.76, elbo=-44952.26
# i=550, epochs=6.59, elapsed=1.76, elbo=-44920.04
# Drawing
# i=551, epochs=6.60, elapsed=1.76, elbo=-44816.17
# i=552, epochs=6.62, elapsed=1.76, elbo=-44975.09
# Drawing
# i=553, epochs=6.63, elapsed=1.77, elbo=-44857.39
# i=554, epochs=6.64, elapsed=1.77, elbo=-44987.79
# Drawing
# i=555, epochs=6.65, elapsed=1.77, elbo=-44973.95
# i=556, epochs=6.66, elapsed=1.78, elbo=-44972.38
# Drawing
# i=557, epochs=6.68, elapsed=1.78, elbo=-44947.05
# i=558, epochs=6.69, elapsed=1.78, elbo=-44909.07
# Drawing
# i=559, epochs=6.70, elapsed=1.79, elbo=-44951.17
# i=560, epochs=6.71, elapsed=1.79, elbo=-44996.40
# Drawing
# i=561, epochs=6.72, elapsed=1.79, elbo=-44945.05
# i=562, epochs=6.74, elapsed=1.80, elbo=-44890.10
# Drawing
# i=563, epochs=6.75, elapsed=1.80, elbo=-44866.92
# i=564, epochs=6.76, elapsed=1.80, elbo=-44938.83
# Drawing
# i=565, epochs=6.77, elapsed=1.80, elbo=-44912.55
# i=566, epochs=6.78, elapsed=1.81, elbo=-45017.99
# Drawing
# i=567, epochs=6.80, elapsed=1.81, elbo=-44980.51
# i=568, epochs=6.81, elapsed=1.81, elbo=-44954.44
# Drawing
# i=569, epochs=6.82, elapsed=1.82, elbo=-44998.49
# i=570, epochs=6.83, elapsed=1.82, elbo=-44992.61
# Drawing
# i=571, epochs=6.84, elapsed=1.82, elbo=-44976.77
# i=572, epochs=6.86, elapsed=1.82, elbo=-45047.23
# Drawing
# i=573, epochs=6.87, elapsed=1.83, elbo=-45010.91
# i=574, epochs=6.88, elapsed=1.83, elbo=-44964.53
# Drawing
# i=575, epochs=6.89, elapsed=1.83, elbo=-44957.25
# i=576, epochs=6.90, elapsed=1.84, elbo=-44932.94
# Drawing
# i=577, epochs=6.92, elapsed=1.84, elbo=-44971.75
# i=578, epochs=6.93, elapsed=1.85, elbo=-44938.47
# Drawing
# i=579, epochs=6.94, elapsed=1.85, elbo=-44973.52
# i=580, epochs=6.95, elapsed=1.85, elbo=-44903.26
# Drawing
# i=581, epochs=6.96, elapsed=1.86, elbo=-44979.78
# i=582, epochs=6.98, elapsed=1.86, elbo=-44986.91
# Drawing
# i=583, epochs=6.99, elapsed=1.86, elbo=-44991.44
# i=584, epochs=7.00, elapsed=1.87, elbo=-44992.85
# Drawing
# i=585, epochs=7.01, elapsed=1.87, elbo=-44926.41
# i=586, epochs=7.02, elapsed=1.87, elbo=-44900.80
# Drawing
# i=587, epochs=7.04, elapsed=1.88, elbo=-45006.79
# i=588, epochs=7.05, elapsed=1.88, elbo=-44935.29
# Drawing
# i=589, epochs=7.06, elapsed=1.88, elbo=-44966.37
# i=590, epochs=7.07, elapsed=1.89, elbo=-44961.77
# Drawing
# i=591, epochs=7.08, elapsed=1.89, elbo=-44948.54
# i=592, epochs=7.10, elapsed=1.89, elbo=-44926.48
# Drawing
# i=593, epochs=7.11, elapsed=1.90, elbo=-45007.45
# i=594, epochs=7.12, elapsed=1.90, elbo=-44980.70
# Drawing
# i=595, epochs=7.13, elapsed=1.90, elbo=-44954.94
# i=596, epochs=7.14, elapsed=1.91, elbo=-44958.65
# Drawing
# i=597, epochs=7.16, elapsed=1.91, elbo=-44948.01
# i=598, epochs=7.17, elapsed=1.91, elbo=-44969.55
# Drawing
# i=599, epochs=7.18, elapsed=1.92, elbo=-44925.90
# i=600, epochs=7.19, elapsed=1.92, elbo=-44965.84
# Drawing
# i=601, epochs=7.20, elapsed=1.92, elbo=-44991.33
# i=602, epochs=7.22, elapsed=1.93, elbo=-44978.87
# Drawing
# i=603, epochs=7.23, elapsed=1.93, elbo=-44974.18
# i=604, epochs=7.24, elapsed=1.93, elbo=-44973.00
# Drawing
# i=605, epochs=7.25, elapsed=1.94, elbo=-44936.56
# i=606, epochs=7.26, elapsed=1.94, elbo=-44946.14
# Drawing
# i=607, epochs=7.28, elapsed=1.94, elbo=-44978.45
# i=608, epochs=7.29, elapsed=1.95, elbo=-44917.50
# Drawing
# i=609, epochs=7.30, elapsed=1.95, elbo=-44892.33
# i=610, epochs=7.31, elapsed=1.95, elbo=-44972.91
# Drawing
# i=611, epochs=7.32, elapsed=1.96, elbo=-44942.32
# i=612, epochs=7.34, elapsed=1.96, elbo=-44929.90
# Drawing
# i=613, epochs=7.35, elapsed=1.96, elbo=-44984.28
# i=614, epochs=7.36, elapsed=1.97, elbo=-44992.16
# Drawing
# i=615, epochs=7.37, elapsed=1.97, elbo=-44931.43
# i=616, epochs=7.38, elapsed=1.97, elbo=-44996.49
# Drawing
# i=617, epochs=7.40, elapsed=1.98, elbo=-44965.14
# i=618, epochs=7.41, elapsed=1.98, elbo=-45010.81
# Drawing
# i=619, epochs=7.42, elapsed=1.98, elbo=-44914.81
# i=620, epochs=7.43, elapsed=1.98, elbo=-45039.64
# Drawing
# i=621, epochs=7.44, elapsed=1.99, elbo=-44941.83
# i=622, epochs=7.46, elapsed=1.99, elbo=-44921.44
# Drawing
# i=623, epochs=7.47, elapsed=2.00, elbo=-44953.48
# i=624, epochs=7.48, elapsed=2.00, elbo=-44963.07
# Drawing
# i=625, epochs=7.49, elapsed=2.00, elbo=-44982.10
# i=626, epochs=7.50, elapsed=2.00, elbo=-44978.17
# Drawing
# i=627, epochs=7.52, elapsed=2.01, elbo=-45005.61
# i=628, epochs=7.53, elapsed=2.01, elbo=-45004.00
# Drawing
# i=629, epochs=7.54, elapsed=2.01, elbo=-44923.31
# i=630, epochs=7.55, elapsed=2.02, elbo=-44918.75
# Drawing
# i=631, epochs=7.56, elapsed=2.02, elbo=-44856.84
# i=632, epochs=7.58, elapsed=2.03, elbo=-44969.14
# Drawing
# i=633, epochs=7.59, elapsed=2.03, elbo=-44971.04
# i=634, epochs=7.60, elapsed=2.03, elbo=-44956.41
# Drawing
# i=635, epochs=7.61, elapsed=2.04, elbo=-44914.60
# i=636, epochs=7.62, elapsed=2.04, elbo=-44912.02
# Drawing
# i=637, epochs=7.64, elapsed=2.04, elbo=-44715.48
# i=638, epochs=7.65, elapsed=2.05, elbo=-44935.41
# Drawing
# i=639, epochs=7.66, elapsed=2.05, elbo=-44904.45
# i=640, epochs=7.67, elapsed=2.05, elbo=-44959.68
# Drawing
# i=641, epochs=7.68, elapsed=2.06, elbo=-44885.25
# i=642, epochs=7.70, elapsed=2.06, elbo=-44991.04
# Drawing
# i=643, epochs=7.71, elapsed=2.06, elbo=-44960.79
# i=644, epochs=7.72, elapsed=2.07, elbo=-44953.84
# Drawing
# i=645, epochs=7.73, elapsed=2.07, elbo=-44914.87
# i=646, epochs=7.74, elapsed=2.07, elbo=-44978.39
# Drawing
# i=647, epochs=7.76, elapsed=2.08, elbo=-44976.92
# i=648, epochs=7.77, elapsed=2.08, elbo=-44947.13
# Drawing
# i=649, epochs=7.78, elapsed=2.08, elbo=-44936.46
# i=650, epochs=7.79, elapsed=2.09, elbo=-44906.07
# Drawing
# i=651, epochs=7.80, elapsed=2.09, elbo=-44958.34
# i=652, epochs=7.82, elapsed=2.09, elbo=-44955.06
# Drawing
# i=653, epochs=7.83, elapsed=2.09, elbo=-44917.11
# i=654, epochs=7.84, elapsed=2.10, elbo=-44929.62
# Drawing
# i=655, epochs=7.85, elapsed=2.10, elbo=-44935.42
# i=656, epochs=7.86, elapsed=2.10, elbo=-44849.33
# Drawing
# i=657, epochs=7.88, elapsed=2.11, elbo=-45014.17
# i=658, epochs=7.89, elapsed=2.11, elbo=-44976.95
# Drawing
# i=659, epochs=7.90, elapsed=2.11, elbo=-44958.44
# i=660, epochs=7.91, elapsed=2.11, elbo=-44972.65
# Drawing
# i=661, epochs=7.92, elapsed=2.12, elbo=-45006.61
# i=662, epochs=7.94, elapsed=2.12, elbo=-45002.16
# Drawing
# i=663, epochs=7.95, elapsed=2.12, elbo=-44998.25
# i=664, epochs=7.96, elapsed=2.13, elbo=-44988.34
# Drawing
# i=665, epochs=7.97, elapsed=2.13, elbo=-44995.37
# i=666, epochs=7.98, elapsed=2.13, elbo=-45023.59
# Drawing
# i=667, epochs=8.00, elapsed=2.14, elbo=-44940.93
# i=668, epochs=8.01, elapsed=2.14, elbo=-44914.19
# Drawing
# i=669, epochs=8.02, elapsed=2.14, elbo=-44923.24
# i=670, epochs=8.03, elapsed=2.14, elbo=-44955.38
# Drawing
# i=671, epochs=8.04, elapsed=2.15, elbo=-44920.33
# i=672, epochs=8.06, elapsed=2.15, elbo=-44947.21
# Drawing
# i=673, epochs=8.07, elapsed=2.15, elbo=-44957.75
# i=674, epochs=8.08, elapsed=2.16, elbo=-44931.53
# Drawing
# i=675, epochs=8.09, elapsed=2.16, elbo=-44985.61
# i=676, epochs=8.10, elapsed=2.16, elbo=-45013.94
# Drawing
# i=677, epochs=8.12, elapsed=2.17, elbo=-44963.52
# i=678, epochs=8.13, elapsed=2.17, elbo=-44966.37
# Drawing
# i=679, epochs=8.14, elapsed=2.17, elbo=-44955.88
# i=680, epochs=8.15, elapsed=2.18, elbo=-45019.45
# Drawing
# i=681, epochs=8.16, elapsed=2.18, elbo=-44931.08
# i=682, epochs=8.18, elapsed=2.18, elbo=-44936.65
# Drawing
# i=683, epochs=8.19, elapsed=2.18, elbo=-45026.86
# i=684, epochs=8.20, elapsed=2.19, elbo=-44941.21
# Drawing
# i=685, epochs=8.21, elapsed=2.19, elbo=-45003.41
# i=686, epochs=8.22, elapsed=2.19, elbo=-44959.78
# Drawing
# i=687, epochs=8.24, elapsed=2.20, elbo=-44931.85
# i=688, epochs=8.25, elapsed=2.20, elbo=-44945.95
# Drawing
# i=689, epochs=8.26, elapsed=2.21, elbo=-44917.98
# i=690, epochs=8.27, elapsed=2.21, elbo=-44968.06
# Drawing
# i=691, epochs=8.28, elapsed=2.22, elbo=-44921.82
# i=692, epochs=8.30, elapsed=2.22, elbo=-45018.51
# Drawing
# i=693, epochs=8.31, elapsed=2.23, elbo=-44954.32
# i=694, epochs=8.32, elapsed=2.23, elbo=-44929.38
# Drawing
# i=695, epochs=8.33, elapsed=2.23, elbo=-44984.47
# i=696, epochs=8.34, elapsed=2.24, elbo=-44956.86
# Drawing
# i=697, epochs=8.36, elapsed=2.24, elbo=-44962.43
# i=698, epochs=8.37, elapsed=2.24, elbo=-44988.91
# Drawing
# i=699, epochs=8.38, elapsed=2.25, elbo=-44984.24
# i=700, epochs=8.39, elapsed=2.25, elbo=-45008.72
# Drawing
# i=701, epochs=8.40, elapsed=2.25, elbo=-44946.27
# i=702, epochs=8.42, elapsed=2.26, elbo=-44921.08
# Drawing
# i=703, epochs=8.43, elapsed=2.26, elbo=-44961.80
# i=704, epochs=8.44, elapsed=2.26, elbo=-44914.44
# Drawing
# i=705, epochs=8.45, elapsed=2.27, elbo=-44933.12
# i=706, epochs=8.46, elapsed=2.27, elbo=-45020.72
# Drawing
# i=707, epochs=8.47, elapsed=2.27, elbo=-45004.41
# i=708, epochs=8.49, elapsed=2.28, elbo=-44976.57
# Drawing
# i=709, epochs=8.50, elapsed=2.28, elbo=-45025.74
# i=710, epochs=8.51, elapsed=2.28, elbo=-44986.82
# Drawing
# i=711, epochs=8.52, elapsed=2.28, elbo=-45015.61
# i=712, epochs=8.53, elapsed=2.29, elbo=-44990.31
# Drawing
# i=713, epochs=8.55, elapsed=2.29, elbo=-44999.63
# i=714, epochs=8.56, elapsed=2.29, elbo=-44996.29
# Drawing
# i=715, epochs=8.57, elapsed=2.30, elbo=-44994.29
# i=716, epochs=8.58, elapsed=2.30, elbo=-45007.36
# Drawing
# i=717, epochs=8.59, elapsed=2.30, elbo=-44963.54
# i=718, epochs=8.61, elapsed=2.31, elbo=-44987.50
# Drawing
# i=719, epochs=8.62, elapsed=2.31, elbo=-45048.17
# i=720, epochs=8.63, elapsed=2.31, elbo=-44932.42
# Drawing
# i=721, epochs=8.64, elapsed=2.32, elbo=-44992.50
# i=722, epochs=8.65, elapsed=2.32, elbo=-44933.17
# Drawing
# i=723, epochs=8.67, elapsed=2.32, elbo=-44991.45
# i=724, epochs=8.68, elapsed=2.33, elbo=-44987.43
# Drawing
# i=725, epochs=8.69, elapsed=2.33, elbo=-44910.33
# i=726, epochs=8.70, elapsed=2.33, elbo=-44945.92
# Drawing
# i=727, epochs=8.71, elapsed=2.34, elbo=-44977.91
# i=728, epochs=8.73, elapsed=2.34, elbo=-44978.18
# Drawing
# i=729, epochs=8.74, elapsed=2.34, elbo=-45006.95
# i=730, epochs=8.75, elapsed=2.35, elbo=-44999.61
# Drawing
# i=731, epochs=8.76, elapsed=2.35, elbo=-44946.56
# i=732, epochs=8.77, elapsed=2.35, elbo=-45016.62
# Drawing
# i=733, epochs=8.79, elapsed=2.36, elbo=-44969.68
# i=734, epochs=8.80, elapsed=2.36, elbo=-44980.17
# Drawing
# i=735, epochs=8.81, elapsed=2.36, elbo=-44949.07
# i=736, epochs=8.82, elapsed=2.36, elbo=-44839.56
# Drawing
# i=737, epochs=8.83, elapsed=2.37, elbo=-44926.41
# i=738, epochs=8.85, elapsed=2.37, elbo=-44958.94
# Drawing
# i=739, epochs=8.86, elapsed=2.37, elbo=-44785.88
# i=740, epochs=8.87, elapsed=2.38, elbo=-44953.85
# Drawing
# i=741, epochs=8.88, elapsed=2.38, elbo=-44968.53
# i=742, epochs=8.89, elapsed=2.38, elbo=-44776.15
# Drawing
# i=743, epochs=8.91, elapsed=2.39, elbo=-44962.49
# i=744, epochs=8.92, elapsed=2.39, elbo=-44982.55
# Drawing
# i=745, epochs=8.93, elapsed=2.39, elbo=-44945.12
# i=746, epochs=8.94, elapsed=2.40, elbo=-44722.20
# Drawing
# i=747, epochs=8.95, elapsed=2.40, elbo=-44998.77
# i=748, epochs=8.97, elapsed=2.40, elbo=-45001.76
# Drawing
# i=749, epochs=8.98, elapsed=2.41, elbo=-44984.00
# i=750, epochs=8.99, elapsed=2.41, elbo=-44953.82
# Drawing
# i=751, epochs=9.00, elapsed=2.41, elbo=-44948.93
# i=752, epochs=9.01, elapsed=2.41, elbo=-44859.88
# Drawing
# i=753, epochs=9.03, elapsed=2.42, elbo=-44962.76
# i=754, epochs=9.04, elapsed=2.42, elbo=-44936.66
# Drawing
# i=755, epochs=9.05, elapsed=2.42, elbo=-44972.23
# i=756, epochs=9.06, elapsed=2.43, elbo=-44876.48
# Drawing
# i=757, epochs=9.07, elapsed=2.43, elbo=-44987.28
# i=758, epochs=9.09, elapsed=2.43, elbo=-45016.89
# Drawing
# i=759, epochs=9.10, elapsed=2.44, elbo=-44971.05
# i=760, epochs=9.11, elapsed=2.44, elbo=-44948.22
# Drawing
# i=761, epochs=9.12, elapsed=2.44, elbo=-45019.49
# i=762, epochs=9.13, elapsed=2.45, elbo=-44968.04
# Drawing
# i=763, epochs=9.15, elapsed=2.45, elbo=-44961.26
# i=764, epochs=9.16, elapsed=2.45, elbo=-45003.07
# Drawing
# i=765, epochs=9.17, elapsed=2.46, elbo=-44955.65
# i=766, epochs=9.18, elapsed=2.46, elbo=-44905.77
# Drawing
# i=767, epochs=9.19, elapsed=2.46, elbo=-44975.32
# i=768, epochs=9.21, elapsed=2.46, elbo=-44946.22
# Drawing
# i=769, epochs=9.22, elapsed=2.47, elbo=-44930.89
# i=770, epochs=9.23, elapsed=2.47, elbo=-44949.05
# Drawing
# i=771, epochs=9.24, elapsed=2.47, elbo=-44894.82
# i=772, epochs=9.25, elapsed=2.48, elbo=-44988.68
# Drawing
# i=773, epochs=9.27, elapsed=2.48, elbo=-44941.12
# i=774, epochs=9.28, elapsed=2.48, elbo=-44959.95
# Drawing
# i=775, epochs=9.29, elapsed=2.49, elbo=-44962.64
# i=776, epochs=9.30, elapsed=2.49, elbo=-44951.48
# Drawing
# i=777, epochs=9.31, elapsed=2.49, elbo=-45012.13
# i=778, epochs=9.33, elapsed=2.49, elbo=-44994.42
# Drawing
# i=779, epochs=9.34, elapsed=2.50, elbo=-45011.38
# i=780, epochs=9.35, elapsed=2.50, elbo=-44928.26
# Drawing
# i=781, epochs=9.36, elapsed=2.50, elbo=-44981.91
# i=782, epochs=9.37, elapsed=2.51, elbo=-44963.61
# Drawing
# i=783, epochs=9.39, elapsed=2.51, elbo=-45054.08
# i=784, epochs=9.40, elapsed=2.51, elbo=-44958.91
# Drawing
# i=785, epochs=9.41, elapsed=2.51, elbo=-44959.98
# i=786, epochs=9.42, elapsed=2.52, elbo=-44952.24
# Drawing
# i=787, epochs=9.43, elapsed=2.52, elbo=-44982.70
# i=788, epochs=9.45, elapsed=2.52, elbo=-45014.13
# Drawing
# i=789, epochs=9.46, elapsed=2.53, elbo=-44993.20
# i=790, epochs=9.47, elapsed=2.53, elbo=-44937.03
# Drawing
# i=791, epochs=9.48, elapsed=2.53, elbo=-44737.04
# i=792, epochs=9.49, elapsed=2.53, elbo=-44895.73
# Drawing
# i=793, epochs=9.51, elapsed=2.54, elbo=-44966.33
# i=794, epochs=9.52, elapsed=2.54, elbo=-44919.77
# Drawing
# i=795, epochs=9.53, elapsed=2.54, elbo=-44978.39
# i=796, epochs=9.54, elapsed=2.55, elbo=-44967.11
# Drawing
# i=797, epochs=9.55, elapsed=2.55, elbo=-44826.43
# i=798, epochs=9.57, elapsed=2.55, elbo=-44957.42
# Drawing
# i=799, epochs=9.58, elapsed=2.56, elbo=-44993.37
# i=800, epochs=9.59, elapsed=2.56, elbo=-44866.69
# Drawing
# i=801, epochs=9.60, elapsed=2.56, elbo=-44964.38
# i=802, epochs=9.61, elapsed=2.57, elbo=-45003.90
# Drawing
# i=803, epochs=9.63, elapsed=2.57, elbo=-45012.43
# i=804, epochs=9.64, elapsed=2.57, elbo=-44755.21
# Drawing
# i=805, epochs=9.65, elapsed=2.58, elbo=-44968.02
# i=806, epochs=9.66, elapsed=2.58, elbo=-44981.40
# Drawing
# i=807, epochs=9.67, elapsed=2.58, elbo=-44969.92
# i=808, epochs=9.69, elapsed=2.59, elbo=-45008.15
# Drawing
# i=809, epochs=9.70, elapsed=2.59, elbo=-44981.28
# i=810, epochs=9.71, elapsed=2.59, elbo=-44999.52
# Drawing
# i=811, epochs=9.72, elapsed=2.59, elbo=-44963.33
# i=812, epochs=9.73, elapsed=2.60, elbo=-44971.97
# Drawing
# i=813, epochs=9.75, elapsed=2.60, elbo=-44955.71
# i=814, epochs=9.76, elapsed=2.60, elbo=-44918.39
# Drawing
# i=815, epochs=9.77, elapsed=2.61, elbo=-44935.46
# i=816, epochs=9.78, elapsed=2.61, elbo=-44937.33
# Drawing
# i=817, epochs=9.79, elapsed=2.61, elbo=-44986.92
# i=818, epochs=9.81, elapsed=2.62, elbo=-44944.96
# Drawing
# i=819, epochs=9.82, elapsed=2.62, elbo=-44979.42
# i=820, epochs=9.83, elapsed=2.62, elbo=-44985.93
# Drawing
# i=821, epochs=9.84, elapsed=2.62, elbo=-44939.81
# i=822, epochs=9.85, elapsed=2.63, elbo=-44963.50
# Drawing
# i=823, epochs=9.87, elapsed=2.63, elbo=-44934.95
# i=824, epochs=9.88, elapsed=2.63, elbo=-44972.02
# Drawing
# i=825, epochs=9.89, elapsed=2.64, elbo=-44973.54
# i=826, epochs=9.90, elapsed=2.64, elbo=-44976.28
# Drawing
# i=827, epochs=9.91, elapsed=2.65, elbo=-44888.68
# i=828, epochs=9.93, elapsed=2.65, elbo=-44958.06
# Drawing
# i=829, epochs=9.94, elapsed=2.65, elbo=-44972.05
# i=830, epochs=9.95, elapsed=2.65, elbo=-44964.28
# Drawing
# i=831, epochs=9.96, elapsed=2.66, elbo=-44996.35
# i=832, epochs=9.97, elapsed=2.66, elbo=-44945.24
# Drawing
# i=833, epochs=9.99, elapsed=2.66, elbo=-44951.09
# i=834, epochs=10.00, elapsed=2.67, elbo=-44943.06
# Drawing
# i=835, epochs=10.01, elapsed=2.67, elbo=-44972.78
# i=836, epochs=10.02, elapsed=2.67, elbo=-45024.26
# Drawing
# i=837, epochs=10.03, elapsed=2.68, elbo=-44966.79
# i=838, epochs=10.05, elapsed=2.68, elbo=-44976.48
# Drawing
# i=839, epochs=10.06, elapsed=2.68, elbo=-44988.04
# i=840, epochs=10.07, elapsed=2.69, elbo=-44973.90
# Drawing
# i=841, epochs=10.08, elapsed=2.69, elbo=-44960.64
# i=842, epochs=10.09, elapsed=2.69, elbo=-45044.58
# Drawing
# i=843, epochs=10.11, elapsed=2.70, elbo=-44679.60
# i=844, epochs=10.12, elapsed=2.70, elbo=-44990.59
# Drawing
# i=845, epochs=10.13, elapsed=2.70, elbo=-44989.16
# i=846, epochs=10.14, elapsed=2.70, elbo=-44952.21
# Drawing
# i=847, epochs=10.15, elapsed=2.71, elbo=-44932.63
# i=848, epochs=10.17, elapsed=2.71, elbo=-44939.37
# Drawing
# i=849, epochs=10.18, elapsed=2.71, elbo=-45003.69
# i=850, epochs=10.19, elapsed=2.72, elbo=-44900.41
# Drawing
# i=851, epochs=10.20, elapsed=2.72, elbo=-44973.58
# i=852, epochs=10.21, elapsed=2.72, elbo=-44951.24
# Drawing
# i=853, epochs=10.23, elapsed=2.73, elbo=-44961.48
# i=854, epochs=10.24, elapsed=2.73, elbo=-44928.26
# Drawing
# i=855, epochs=10.25, elapsed=2.73, elbo=-44965.00
# i=856, epochs=10.26, elapsed=2.73, elbo=-44961.45
# Drawing
# i=857, epochs=10.27, elapsed=2.74, elbo=-44971.94
# i=858, epochs=10.29, elapsed=2.74, elbo=-44910.96
# Drawing
# i=859, epochs=10.30, elapsed=2.74, elbo=-44953.12
# i=860, epochs=10.31, elapsed=2.75, elbo=-44984.18
# Drawing
# i=861, epochs=10.32, elapsed=2.75, elbo=-44997.80
# i=862, epochs=10.33, elapsed=2.75, elbo=-44941.84
# Drawing
# i=863, epochs=10.35, elapsed=2.75, elbo=-45020.69
# i=864, epochs=10.36, elapsed=2.76, elbo=-44926.25
# Drawing
# i=865, epochs=10.37, elapsed=2.76, elbo=-45020.28
# i=866, epochs=10.38, elapsed=2.76, elbo=-44941.44
# Drawing
# i=867, epochs=10.39, elapsed=2.77, elbo=-44989.63
# i=868, epochs=10.40, elapsed=2.77, elbo=-45026.58
# Drawing
# i=869, epochs=10.42, elapsed=2.77, elbo=-44985.95
# i=870, epochs=10.43, elapsed=2.78, elbo=-44974.73
# Drawing
# i=871, epochs=10.44, elapsed=2.78, elbo=-44936.64
# i=872, epochs=10.45, elapsed=2.78, elbo=-44979.16
# Drawing
# i=873, epochs=10.46, elapsed=2.79, elbo=-44929.54
# i=874, epochs=10.48, elapsed=2.79, elbo=-44993.36
# Drawing
# i=875, epochs=10.49, elapsed=2.79, elbo=-45040.95
# i=876, epochs=10.50, elapsed=2.80, elbo=-44958.90
# Drawing
# i=877, epochs=10.51, elapsed=2.80, elbo=-45019.08
# i=878, epochs=10.52, elapsed=2.80, elbo=-44983.67
# Drawing
# i=879, epochs=10.54, elapsed=2.80, elbo=-44941.15
# i=880, epochs=10.55, elapsed=2.81, elbo=-44985.86
# Drawing
# i=881, epochs=10.56, elapsed=2.81, elbo=-45011.83
# i=882, epochs=10.57, elapsed=2.81, elbo=-44984.68
# Drawing
# i=883, epochs=10.58, elapsed=2.82, elbo=-44936.46
# i=884, epochs=10.60, elapsed=2.82, elbo=-44956.32
# Drawing
# i=885, epochs=10.61, elapsed=2.82, elbo=-44960.01
# i=886, epochs=10.62, elapsed=2.83, elbo=-44950.99
# Drawing
# i=887, epochs=10.63, elapsed=2.83, elbo=-44933.69
# i=888, epochs=10.64, elapsed=2.83, elbo=-44957.93
# Drawing
# i=889, epochs=10.66, elapsed=2.84, elbo=-44968.91
# i=890, epochs=10.67, elapsed=2.84, elbo=-44836.90
# Drawing
# i=891, epochs=10.68, elapsed=2.84, elbo=-44958.77
# i=892, epochs=10.69, elapsed=2.84, elbo=-44962.20
# Drawing
# i=893, epochs=10.70, elapsed=2.85, elbo=-44928.50
# i=894, epochs=10.72, elapsed=2.85, elbo=-44951.32
# Drawing
# i=895, epochs=10.73, elapsed=2.85, elbo=-45028.29
# i=896, epochs=10.74, elapsed=2.86, elbo=-45014.78
# Drawing
# i=897, epochs=10.75, elapsed=2.86, elbo=-44968.32
# i=898, epochs=10.76, elapsed=2.86, elbo=-45034.02
# Drawing
# i=899, epochs=10.78, elapsed=2.87, elbo=-44926.51
# i=900, epochs=10.79, elapsed=2.87, elbo=-44964.34
# Drawing
# i=901, epochs=10.80, elapsed=2.87, elbo=-44939.26
# i=902, epochs=10.81, elapsed=2.88, elbo=-45033.15
# Drawing
# i=903, epochs=10.82, elapsed=2.88, elbo=-45007.54
# i=904, epochs=10.84, elapsed=2.88, elbo=-44952.72
# Drawing
# i=905, epochs=10.85, elapsed=2.89, elbo=-45003.77
# i=906, epochs=10.86, elapsed=2.89, elbo=-44931.05
# Drawing
# ...
# Drawing
# i=1291, epochs=15.48, elapsed=4.15, elbo=-44972.17
# i=1292, epochs=15.49, elapsed=4.15, elbo=-44942.64
# Drawing
# i=1293, epochs=15.50, elapsed=4.16, elbo=-44931.22
# i=1294, epochs=15.51, elapsed=4.16, elbo=-44953.70
# Drawing
# i=1295, epochs=15.52, elapsed=4.17, elbo=-44973.54
# i=1296, epochs=15.54, elapsed=4.17, elbo=-44949.75
# Drawing
# i=1297, epochs=15.55, elapsed=4.17, elbo=-44983.41
# i=1298, epochs=15.56, elapsed=4.18, elbo=-45005.55
# Drawing
# i=1299, epochs=15.57, elapsed=4.18, elbo=-44973.91
# i=1300, epochs=15.58, elapsed=4.18, elbo=-44978.85
# Drawing
# i=1301, epochs=15.60, elapsed=4.19, elbo=-45011.60
# i=1302, epochs=15.61, elapsed=4.19, elbo=-45003.40
# Drawing
# i=1303, epochs=15.62, elapsed=4.20, elbo=-44978.55
# i=1304, epochs=15.63, elapsed=4.20, elbo=-44988.42
# Drawing
# i=1305, epochs=15.64, elapsed=4.20, elbo=-44965.12
# i=1306, epochs=15.66, elapsed=4.21, elbo=-44964.23
# Drawing
# i=1307, epochs=15.67, elapsed=4.21, elbo=-45007.39
# i=1308, epochs=15.68, elapsed=4.22, elbo=-45012.35
# Drawing
# i=1309, epochs=15.69, elapsed=4.22, elbo=-45001.94
# i=1310, epochs=15.70, elapsed=4.23, elbo=-45007.30
# Drawing
# i=1311, epochs=15.72, elapsed=4.24, elbo=-44941.40
# i=1312, epochs=15.73, elapsed=4.24, elbo=-44939.48
# Drawing
# i=1313, epochs=15.74, elapsed=4.25, elbo=-44955.63
# i=1314, epochs=15.75, elapsed=4.26, elbo=-44972.14
# Drawing
# i=1315, epochs=15.76, elapsed=4.26, elbo=-44981.79
# i=1316, epochs=15.78, elapsed=4.27, elbo=-44940.32
# Drawing
# i=1317, epochs=15.79, elapsed=4.27, elbo=-44997.55
# i=1318, epochs=15.80, elapsed=4.27, elbo=-44938.62
# Drawing
# i=1319, epochs=15.81, elapsed=4.28, elbo=-44941.90
# i=1320, epochs=15.82, elapsed=4.28, elbo=-44912.68
# Drawing
# i=1321, epochs=15.84, elapsed=4.28, elbo=-45004.36
# i=1322, epochs=15.85, elapsed=4.29, elbo=-44965.08
# Drawing
# i=1323, epochs=15.86, elapsed=4.29, elbo=-45037.14
# i=1324, epochs=15.87, elapsed=4.29, elbo=-44970.10
# Drawing
# i=1325, epochs=15.88, elapsed=4.30, elbo=-44940.86
# i=1326, epochs=15.90, elapsed=4.31, elbo=-45058.86
# Drawing
# i=1327, epochs=15.91, elapsed=4.31, elbo=-44936.23
# i=1328, epochs=15.92, elapsed=4.32, elbo=-44931.00
# Drawing
# i=1329, epochs=15.93, elapsed=4.32, elbo=-45037.46
# i=1330, epochs=15.94, elapsed=4.32, elbo=-44989.35
# Drawing
# i=1331, epochs=15.96, elapsed=4.33, elbo=-44990.91
# i=1332, epochs=15.97, elapsed=4.33, elbo=-44967.21
# Drawing
# i=1333, epochs=15.98, elapsed=4.34, elbo=-44980.08
# i=1334, epochs=15.99, elapsed=4.34, elbo=-44968.41
# Drawing
# i=1335, epochs=16.00, elapsed=4.34, elbo=-44936.05
# i=1336, epochs=16.01, elapsed=4.35, elbo=-44980.42
# Drawing
# i=1337, epochs=16.03, elapsed=4.35, elbo=-44950.87
# i=1338, epochs=16.04, elapsed=4.36, elbo=-44930.12
# Drawing
# i=1339, epochs=16.05, elapsed=4.36, elbo=-45029.47
# i=1340, epochs=16.06, elapsed=4.37, elbo=-45046.07
# Drawing
# i=1341, epochs=16.07, elapsed=4.37, elbo=-44729.55
# i=1342, epochs=16.09, elapsed=4.37, elbo=-44950.41
# Drawing
# i=1343, epochs=16.10, elapsed=4.38, elbo=-44988.91
# i=1344, epochs=16.11, elapsed=4.38, elbo=-45025.45
# Drawing
# i=1345, epochs=16.12, elapsed=4.38, elbo=-44945.44
# i=1346, epochs=16.13, elapsed=4.39, elbo=-44958.17
# Drawing
# i=1347, epochs=16.15, elapsed=4.39, elbo=-44988.54
# i=1348, epochs=16.16, elapsed=4.39, elbo=-44979.37
# Drawing
# i=1349, epochs=16.17, elapsed=4.40, elbo=-45046.05
# i=1350, epochs=16.18, elapsed=4.40, elbo=-45049.54
# Drawing
# i=1351, epochs=16.19, elapsed=4.40, elbo=-44964.41
# i=1352, epochs=16.21, elapsed=4.41, elbo=-45051.07
# Drawing
# i=1353, epochs=16.22, elapsed=4.41, elbo=-44992.32
# i=1354, epochs=16.23, elapsed=4.41, elbo=-45003.28
# Drawing
# i=1355, epochs=16.24, elapsed=4.42, elbo=-44956.03
# i=1356, epochs=16.25, elapsed=4.42, elbo=-44970.32
# Drawing
# i=1357, epochs=16.27, elapsed=4.42, elbo=-44976.50
# i=1358, epochs=16.28, elapsed=4.42, elbo=-44935.86
# Drawing
# i=1359, epochs=16.29, elapsed=4.43, elbo=-45000.81
# i=1360, epochs=16.30, elapsed=4.43, elbo=-44932.75
# Drawing
# i=1361, epochs=16.31, elapsed=4.44, elbo=-44962.55
# i=1362, epochs=16.33, elapsed=4.44, elbo=-44939.05
# Drawing
# i=1363, epochs=16.34, elapsed=4.44, elbo=-45000.56
# i=1364, epochs=16.35, elapsed=4.45, elbo=-44958.03
# Drawing
# i=1365, epochs=16.36, elapsed=4.45, elbo=-44715.36
# i=1366, epochs=16.37, elapsed=4.46, elbo=-44925.37
# Drawing
# i=1367, epochs=16.39, elapsed=4.46, elbo=-44976.03
# i=1368, epochs=16.40, elapsed=4.46, elbo=-44985.82
# Drawing
# i=1369, epochs=16.41, elapsed=4.47, elbo=-44970.92
# i=1370, epochs=16.42, elapsed=4.47, elbo=-44967.40
# Drawing
# i=1371, epochs=16.43, elapsed=4.48, elbo=-44971.82
# i=1372, epochs=16.45, elapsed=4.48, elbo=-45001.58
# Drawing
# i=1373, epochs=16.46, elapsed=4.48, elbo=-44993.30
# i=1374, epochs=16.47, elapsed=4.49, elbo=-44998.30
# Drawing
# i=1375, epochs=16.48, elapsed=4.49, elbo=-44983.12
# i=1376, epochs=16.49, elapsed=4.49, elbo=-45012.18
# Drawing
# i=1377, epochs=16.51, elapsed=4.50, elbo=-44989.13
# i=1378, epochs=16.52, elapsed=4.50, elbo=-44978.27
# Drawing
# i=1379, epochs=16.53, elapsed=4.51, elbo=-44996.35
# i=1380, epochs=16.54, elapsed=4.51, elbo=-44987.00
# Drawing
# i=1381, epochs=16.55, elapsed=4.51, elbo=-44955.58
# i=1382, epochs=16.57, elapsed=4.52, elbo=-44960.39
# Drawing
# i=1383, epochs=16.58, elapsed=4.52, elbo=-45052.80
# i=1384, epochs=16.59, elapsed=4.53, elbo=-45000.32
# Drawing
# i=1385, epochs=16.60, elapsed=4.54, elbo=-44856.82
# i=1386, epochs=16.61, elapsed=4.55, elbo=-44992.67
# Drawing
# i=1387, epochs=16.63, elapsed=4.55, elbo=-44952.75
# i=1388, epochs=16.64, elapsed=4.55, elbo=-44947.26
# Drawing
# i=1389, epochs=16.65, elapsed=4.56, elbo=-45041.94
# i=1390, epochs=16.66, elapsed=4.56, elbo=-44978.85
# Drawing
# i=1391, epochs=16.67, elapsed=4.56, elbo=-44872.66
# i=1392, epochs=16.69, elapsed=4.56, elbo=-44938.47
# Drawing
# i=1393, epochs=16.70, elapsed=4.57, elbo=-44979.47
# i=1394, epochs=16.71, elapsed=4.57, elbo=-45010.92
# Drawing
# i=1395, epochs=16.72, elapsed=4.57, elbo=-44970.14
# i=1396, epochs=16.73, elapsed=4.58, elbo=-44965.30
# Drawing
# i=1397, epochs=16.75, elapsed=4.58, elbo=-44965.99
# i=1398, epochs=16.76, elapsed=4.58, elbo=-44945.43
# Drawing
# i=1399, epochs=16.77, elapsed=4.59, elbo=-45021.18
# i=1400, epochs=16.78, elapsed=4.59, elbo=-44964.09
# Drawing
# i=1401, epochs=16.79, elapsed=4.59, elbo=-44975.08
# i=1402, epochs=16.81, elapsed=4.59, elbo=-44965.74
# Drawing
# i=1403, epochs=16.82, elapsed=4.60, elbo=-44938.99
# i=1404, epochs=16.83, elapsed=4.60, elbo=-45010.87
# Drawing
# i=1405, epochs=16.84, elapsed=4.60, elbo=-44977.41
# i=1406, epochs=16.85, elapsed=4.61, elbo=-44966.37
# Drawing
# i=1407, epochs=16.87, elapsed=4.61, elbo=-44984.69
# i=1408, epochs=16.88, elapsed=4.62, elbo=-45042.60
# Drawing
# i=1409, epochs=16.89, elapsed=4.62, elbo=-44962.44
# i=1410, epochs=16.90, elapsed=4.62, elbo=-44941.25
# Drawing
# i=1411, epochs=16.91, elapsed=4.63, elbo=-45051.03
# i=1412, epochs=16.93, elapsed=4.63, elbo=-44944.55
# Drawing
# i=1413, epochs=16.94, elapsed=4.63, elbo=-45011.26
# i=1414, epochs=16.95, elapsed=4.63, elbo=-44993.80
# Drawing
# i=1415, epochs=16.96, elapsed=4.64, elbo=-44956.54
# i=1416, epochs=16.97, elapsed=4.64, elbo=-44953.57
# Drawing
# i=1417, epochs=16.99, elapsed=4.64, elbo=-44924.41
# i=1418, epochs=17.00, elapsed=4.65, elbo=-44957.35
# Drawing
# i=1419, epochs=17.01, elapsed=4.65, elbo=-44976.44
# i=1420, epochs=17.02, elapsed=4.65, elbo=-44963.63
# Drawing
# i=1421, epochs=17.03, elapsed=4.65, elbo=-44945.26
# i=1422, epochs=17.05, elapsed=4.66, elbo=-44954.58
# Drawing
# i=1423, epochs=17.06, elapsed=4.66, elbo=-44999.96
# i=1424, epochs=17.07, elapsed=4.66, elbo=-44963.38
# Drawing
# i=1425, epochs=17.08, elapsed=4.67, elbo=-44895.30
# i=1426, epochs=17.09, elapsed=4.67, elbo=-44934.51
# Drawing
# i=1427, epochs=17.11, elapsed=4.67, elbo=-44967.99
# i=1428, epochs=17.12, elapsed=4.68, elbo=-44991.65
# Drawing
# i=1429, epochs=17.13, elapsed=4.68, elbo=-45016.17
# i=1430, epochs=17.14, elapsed=4.68, elbo=-44957.73
# Drawing
# i=1431, epochs=17.15, elapsed=4.68, elbo=-44943.92
# i=1432, epochs=17.17, elapsed=4.69, elbo=-44934.79
# Drawing
# i=1433, epochs=17.18, elapsed=4.69, elbo=-44976.53
# i=1434, epochs=17.19, elapsed=4.69, elbo=-45008.52
# Drawing
# i=1435, epochs=17.20, elapsed=4.70, elbo=-44981.01
# i=1436, epochs=17.21, elapsed=4.70, elbo=-44936.20
# Drawing
# i=1437, epochs=17.23, elapsed=4.70, elbo=-44800.67
# i=1438, epochs=17.24, elapsed=4.71, elbo=-44909.91
# Drawing
# i=1439, epochs=17.25, elapsed=4.71, elbo=-44986.73
# i=1440, epochs=17.26, elapsed=4.71, elbo=-44974.08
# Drawing
# i=1441, epochs=17.27, elapsed=4.71, elbo=-44974.45
# i=1442, epochs=17.29, elapsed=4.72, elbo=-44998.00
# Drawing
# i=1443, epochs=17.30, elapsed=4.72, elbo=-44983.69
# i=1444, epochs=17.31, elapsed=4.72, elbo=-44983.97
# Drawing
# i=1445, epochs=17.32, elapsed=4.73, elbo=-44746.12
# i=1446, epochs=17.33, elapsed=4.73, elbo=-45003.79
# Drawing
# i=1447, epochs=17.35, elapsed=4.73, elbo=-44965.98
# i=1448, epochs=17.36, elapsed=4.74, elbo=-44969.24
# Drawing
# i=1449, epochs=17.37, elapsed=4.74, elbo=-45036.32
# i=1450, epochs=17.38, elapsed=4.74, elbo=-44991.04
# Drawing
# i=1451, epochs=17.39, elapsed=4.74, elbo=-44969.96
# i=1452, epochs=17.41, elapsed=4.75, elbo=-44987.91
# Drawing
# i=1453, epochs=17.42, elapsed=4.75, elbo=-44969.25
# i=1454, epochs=17.43, elapsed=4.75, elbo=-44973.31
# Drawing
# i=1455, epochs=17.44, elapsed=4.76, elbo=-45011.68
# i=1456, epochs=17.45, elapsed=4.76, elbo=-45018.04
# Drawing
# i=1457, epochs=17.47, elapsed=4.76, elbo=-45059.30
# i=1458, epochs=17.48, elapsed=4.77, elbo=-44864.69
# Drawing
# i=1459, epochs=17.49, elapsed=4.77, elbo=-44984.52
# i=1460, epochs=17.50, elapsed=4.77, elbo=-44907.52
# Drawing
# i=1461, epochs=17.51, elapsed=4.77, elbo=-44968.07
# i=1462, epochs=17.53, elapsed=4.78, elbo=-44987.32
# Drawing
# i=1463, epochs=17.54, elapsed=4.78, elbo=-44966.82
# i=1464, epochs=17.55, elapsed=4.78, elbo=-44962.94
# Drawing
# i=1465, epochs=17.56, elapsed=4.79, elbo=-45013.43
# i=1466, epochs=17.57, elapsed=4.79, elbo=-44959.31
# Drawing
# i=1467, epochs=17.59, elapsed=4.79, elbo=-44993.92
# i=1468, epochs=17.60, elapsed=4.80, elbo=-44979.47
# Drawing
# i=1469, epochs=17.61, elapsed=4.80, elbo=-44967.61
# i=1470, epochs=17.62, elapsed=4.80, elbo=-44962.06
# Drawing
# i=1471, epochs=17.63, elapsed=4.80, elbo=-44958.57
# i=1472, epochs=17.65, elapsed=4.81, elbo=-44985.84
# Drawing
# i=1473, epochs=17.66, elapsed=4.81, elbo=-45008.97
# i=1474, epochs=17.67, elapsed=4.81, elbo=-44946.19
# Drawing
# i=1475, epochs=17.68, elapsed=4.82, elbo=-44998.66
# i=1476, epochs=17.69, elapsed=4.82, elbo=-44935.74
# Drawing
# i=1477, epochs=17.71, elapsed=4.82, elbo=-44963.36
# i=1478, epochs=17.72, elapsed=4.83, elbo=-44988.92
# Drawing
# i=1479, epochs=17.73, elapsed=4.83, elbo=-45005.22
# i=1480, epochs=17.74, elapsed=4.83, elbo=-45024.25
# Drawing
# i=1481, epochs=17.75, elapsed=4.83, elbo=-45013.99
# i=1482, epochs=17.77, elapsed=4.84, elbo=-44985.53
# Drawing
# i=1483, epochs=17.78, elapsed=4.84, elbo=-44978.44
# i=1484, epochs=17.79, elapsed=4.84, elbo=-45021.14
# Drawing
# i=1485, epochs=17.80, elapsed=4.85, elbo=-44987.84
# i=1486, epochs=17.81, elapsed=4.85, elbo=-45010.62
# Drawing
# i=1487, epochs=17.83, elapsed=4.85, elbo=-44976.28
# i=1488, epochs=17.84, elapsed=4.86, elbo=-44943.89
# Drawing
# i=1489, epochs=17.85, elapsed=4.86, elbo=-44995.38
# i=1490, epochs=17.86, elapsed=4.86, elbo=-45014.79
# Drawing
# i=1491, epochs=17.87, elapsed=4.86, elbo=-45042.74
# i=1492, epochs=17.88, elapsed=4.87, elbo=-44963.20
# Drawing
# i=1493, epochs=17.90, elapsed=4.87, elbo=-45010.03
# i=1494, epochs=17.91, elapsed=4.87, elbo=-45026.31
# Drawing
# i=1495, epochs=17.92, elapsed=4.88, elbo=-44852.81
# i=1496, epochs=17.93, elapsed=4.88, elbo=-44743.86
# Drawing
# i=1497, epochs=17.94, elapsed=4.88, elbo=-44988.49
# i=1498, epochs=17.96, elapsed=4.89, elbo=-44949.58
# Drawing
# i=1499, epochs=17.97, elapsed=4.89, elbo=-45024.54
# i=1500, epochs=17.98, elapsed=4.89, elbo=-44983.07
# Drawing
# i=1501, epochs=17.99, elapsed=4.89, elbo=-44989.70
# i=1502, epochs=18.00, elapsed=4.90, elbo=-44927.82
# Drawing
# i=1503, epochs=18.02, elapsed=4.90, elbo=-44964.57
# i=1504, epochs=18.03, elapsed=4.90, elbo=-44850.39
# Drawing
# i=1505, epochs=18.04, elapsed=4.91, elbo=-44977.03
# i=1506, epochs=18.05, elapsed=4.91, elbo=-44993.83
# Drawing
# i=1507, epochs=18.06, elapsed=4.91, elbo=-44989.75
# i=1508, epochs=18.08, elapsed=4.92, elbo=-44981.31
# Drawing
# i=1509, epochs=18.09, elapsed=4.92, elbo=-44961.20
# i=1510, epochs=18.10, elapsed=4.92, elbo=-44994.27
# Drawing
# i=1511, epochs=18.11, elapsed=4.92, elbo=-45028.73
# i=1512, epochs=18.12, elapsed=4.93, elbo=-44947.67
# Drawing
# i=1513, epochs=18.14, elapsed=4.93, elbo=-44949.38
# i=1514, epochs=18.15, elapsed=4.93, elbo=-45049.93
# Drawing
# i=1515, epochs=18.16, elapsed=4.94, elbo=-45000.40
# i=1516, epochs=18.17, elapsed=4.94, elbo=-44999.14
# Drawing
# i=1517, epochs=18.18, elapsed=4.94, elbo=-44725.83
# i=1518, epochs=18.20, elapsed=4.95, elbo=-44812.17
# Drawing
# i=1519, epochs=18.21, elapsed=4.95, elbo=-45032.24
# i=1520, epochs=18.22, elapsed=4.95, elbo=-44967.82
# Drawing
# i=1521, epochs=18.23, elapsed=4.95, elbo=-44994.06
# i=1522, epochs=18.24, elapsed=4.96, elbo=-44960.70
# Drawing
# i=1523, epochs=18.26, elapsed=4.96, elbo=-44975.58
# i=1524, epochs=18.27, elapsed=4.96, elbo=-45006.12
# Drawing
# i=1525, epochs=18.28, elapsed=4.97, elbo=-44971.99
# i=1526, epochs=18.29, elapsed=4.97, elbo=-44960.70
# Drawing
# i=1527, epochs=18.30, elapsed=4.97, elbo=-45020.87
# i=1528, epochs=18.32, elapsed=4.98, elbo=-45044.06
# Drawing
# i=1529, epochs=18.33, elapsed=4.98, elbo=-45017.93
# i=1530, epochs=18.34, elapsed=4.99, elbo=-44980.73
# Drawing
# i=1531, epochs=18.35, elapsed=4.99, elbo=-44957.55
# i=1532, epochs=18.36, elapsed=4.99, elbo=-44908.59
# Drawing
# i=1533, epochs=18.38, elapsed=5.00, elbo=-44708.21
# i=1534, epochs=18.39, elapsed=5.00, elbo=-44950.59
# Drawing
# i=1535, epochs=18.40, elapsed=5.00, elbo=-45022.69
# i=1536, epochs=18.41, elapsed=5.00, elbo=-45044.11
# Drawing
# i=1537, epochs=18.42, elapsed=5.01, elbo=-44974.80
# i=1538, epochs=18.44, elapsed=5.01, elbo=-44985.07
# Drawing
# i=1539, epochs=18.45, elapsed=5.01, elbo=-45046.37
# i=1540, epochs=18.46, elapsed=5.02, elbo=-45000.11
# Drawing
# i=1541, epochs=18.47, elapsed=5.02, elbo=-45026.55
# i=1542, epochs=18.48, elapsed=5.02, elbo=-45014.04
# Drawing
# i=1543, epochs=18.50, elapsed=5.03, elbo=-44979.13
# i=1544, epochs=18.51, elapsed=5.03, elbo=-44979.49
# Drawing
# i=1545, epochs=18.52, elapsed=5.03, elbo=-44947.18
# i=1546, epochs=18.53, elapsed=5.03, elbo=-44992.85
# Drawing
# i=1547, epochs=18.54, elapsed=5.04, elbo=-45030.21
# i=1548, epochs=18.56, elapsed=5.04, elbo=-45004.57
# Drawing
# i=1549, epochs=18.57, elapsed=5.04, elbo=-44994.31
# i=1550, epochs=18.58, elapsed=5.05, elbo=-44992.98
# Drawing
# i=1551, epochs=18.59, elapsed=5.05, elbo=-45004.58
# i=1552, epochs=18.60, elapsed=5.05, elbo=-44925.07
# Drawing
# i=1553, epochs=18.62, elapsed=5.06, elbo=-45020.66
# i=1554, epochs=18.63, elapsed=5.06, elbo=-45004.41
# Drawing
# i=1555, epochs=18.64, elapsed=5.06, elbo=-44986.53
# i=1556, epochs=18.65, elapsed=5.06, elbo=-44987.47
# Drawing
# i=1557, epochs=18.66, elapsed=5.07, elbo=-44952.72
# i=1558, epochs=18.68, elapsed=5.07, elbo=-44929.12
# Drawing
# i=1559, epochs=18.69, elapsed=5.07, elbo=-44762.17
# i=1560, epochs=18.70, elapsed=5.08, elbo=-45056.73
# Drawing
# i=1561, epochs=18.71, elapsed=5.08, elbo=-44975.59
# i=1562, epochs=18.72, elapsed=5.08, elbo=-44951.56
# Drawing
# i=1563, epochs=18.74, elapsed=5.09, elbo=-44956.17
# i=1564, epochs=18.75, elapsed=5.09, elbo=-45005.82
# Drawing
# i=1565, epochs=18.76, elapsed=5.09, elbo=-44978.55
# i=1566, epochs=18.77, elapsed=5.09, elbo=-45012.42
# Drawing
# i=1567, epochs=18.78, elapsed=5.10, elbo=-45020.01
# i=1568, epochs=18.80, elapsed=5.10, elbo=-44949.71
# Drawing
# i=1569, epochs=18.81, elapsed=5.10, elbo=-45043.15
# i=1570, epochs=18.82, elapsed=5.11, elbo=-45013.81
# Drawing
# i=1571, epochs=18.83, elapsed=5.11, elbo=-44993.29
# i=1572, epochs=18.84, elapsed=5.11, elbo=-44942.80
# Drawing
# i=1573, epochs=18.86, elapsed=5.12, elbo=-44955.08
# i=1574, epochs=18.87, elapsed=5.12, elbo=-44964.44
# Drawing
# i=1575, epochs=18.88, elapsed=5.12, elbo=-45003.22
# i=1576, epochs=18.89, elapsed=5.12, elbo=-45012.08
# Drawing
# i=1577, epochs=18.90, elapsed=5.13, elbo=-45010.98
# i=1578, epochs=18.92, elapsed=5.13, elbo=-45054.04
# Drawing
# i=1579, epochs=18.93, elapsed=5.13, elbo=-45003.74
# i=1580, epochs=18.94, elapsed=5.14, elbo=-44994.33
# Drawing
