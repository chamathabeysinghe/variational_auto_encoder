# %%
"""

Variational Autoencoder with a STN and Modified Loss function and inverse STN and compare reconstruction loss
Removed the classification part 
Add the cost function of new VAE implementation of Tensorflow documentation

Binary cross entropy equation - to be implemented

This is a MNIST classifier 

Add a decoder to clip values after inverse STN 

Encoder(Localizaton network) -> CNN to predict affine transformation matrix
STN -> Apply affine transformation
Decoder -> CNN to classify transformed images from STN

"""
# Out:
# '\n\nVariational Autoencoder with a STN and Modified Loss function and inverse STN and compare reconstruction loss\nRemoved the classification part \nAdd the cost function of new VAE implementation of Tensorflow documentation\n\nBinary cross entropy equation - to be implemented\n\nThis is a MNIST classifier \n\nAdd a decoder to clip values after inverse STN \n\nEncoder(Localizaton network) -> CNN to predict affine transformation matrix\nSTN -> Apply affine transformation\nDecoder -> CNN to classify transformed images from STN\n\n'

# %%
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Dense, Flatten, Activation, Reshape
from tensorflow.keras import Model
import numpy as np
from utils.data_manager import ClutteredMNIST
from utils.visualizer import plot_mnist_sample
from utils.visualizer import print_evaluation
from utils.visualizer import plot_mnist_grid
from components.STN import BilinearInterpolation

# %% [markdown]
# ## Dataset creation

# %%
dataset_path = "./datasets/mnist_cluttered_60x60_6distortions.npz"
batch_size = 256
num_epochs = 30

# data_manager = ClutteredMNIST(dataset_path)
# train_data, val_data, test_data = data_manager.load()
# x_train, y_train = train_data
x_train = np.load('./data/pyro-mnist.npy')
x_train = x_train.reshape((-1, 50, 50 ,1))
x_train[x_train>=.5] = 1.0
x_train[x_train<.5] = 0.0
plot_mnist_sample(x_train[7])

# %%
for i in range(10):
    plot_mnist_sample(x_train[i])

# %% [markdown]
# ## Sampling layer

# %%
class Sampling(layers.Layer):
  """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

  def call(self, inputs):
    z_mean, z_log_var = inputs
    batch = tf.shape(z_mean)[0]
    dim = tf.shape(z_mean)[1]
    epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# ## Encoder layer

# %%
class Encoder(layers.Layer):
  """Maps MNIST digits to a triplet (z_mean, z_log_var, z)."""

  def __init__(self,
               latent_dim=3,
               intermediate_dim=64,
               name='encoder',
               **kwargs):
    super(Encoder, self).__init__(name=name, **kwargs)
    self.conv_1 = layers.Conv2D(20, (5, 5), padding='same', activation='relu')
    self.max_1 = layers.MaxPool2D(pool_size=(2, 2))
    self.conv_2 = layers.Conv2D(20, (5, 5), activation='relu')
    self.max_2 = layers.MaxPool2D(pool_size=(2, 2))
    
    self.flatten = layers.Flatten()
    
    self.dense_1 = layers.Dense(50, activation='relu')
    
    self.dense_mean = layers.Dense(3)
    self.dense_log_var = layers.Dense(3)
    
    self.sampling = Sampling()

  def call(self, inputs):
    x = self.conv_1(inputs)
    x = self.max_1(x)
    x = self.conv_2(x)
    x = self.max_2(x)
    x = self.flatten(x)
    x = self.dense_1(x)
    z_mean = self.dense_mean(x)
    z_log_var = self.dense_log_var(x)
    z = self.sampling((z_mean, z_log_var))
    return z_mean, z_log_var, z

# %%
class DigitEncoder(layers.Layer):
  """Maps MNIST digits to a triplet (z_mean, z_log_var, z)."""

  def __init__(self,
               name='digit_encoder',
               **kwargs):
    super(DigitEncoder, self).__init__(name=name, **kwargs)
    self.conv_1 = layers.Conv2D(20, (3, 3), padding='same', activation='relu')
    self.max_1 = layers.MaxPool2D(pool_size=(2, 2))
    self.conv_2 = layers.Conv2D(20, (3, 3), activation='relu')
    self.max_2 = layers.MaxPool2D(pool_size=(2, 2))
    
    self.flatten = layers.Flatten()
    
    self.dense_1 = layers.Dense(200, activation='relu')
    
    self.dense_mean = layers.Dense(50)
    self.dense_log_var = layers.Dense(50)
    
    self.sampling = Sampling()

  def call(self, inputs):
    x = self.conv_1(inputs)
    x = self.max_1(x)
    x = self.conv_2(x)
    x = self.max_2(x)
    x = self.flatten(x)
    x = self.dense_1(x)
    z_mean = self.dense_mean(x)
    z_log_var = self.dense_log_var(x)
    z = self.sampling((z_mean, z_log_var))
    return z_mean, z_log_var, z

# %% [markdown]
# ## Decoder layer

# %%
class Decoder(layers.Layer):
  """Converts z, the encoded digit vector, back into a readable digit."""

  def __init__(self,
               name='decoder',
               **kwargs):
    super(Decoder, self).__init__(name=name, **kwargs)
    self.flatten = layers.Flatten()
    self.dense_1 = layers.Dense(2500, activation='sigmoid')
    self.reshape = layers.Reshape((-1, 50, 50))

    
  def call(self, inputs):
    x = self.flatten(inputs)
    x = self.dense_1(x)
    x = self.reshape(x)
    return x

# %%
class DigitDecoder(layers.Layer):
  """Converts z, the encoded digit vector, back into a readable digit."""

  def __init__(self,
               name='decoder',
               **kwargs):
    super(DigitDecoder, self).__init__(name=name, **kwargs)
    self.dense_1 = layers.Dense(100, activation='relu')
    self.dense_2 = layers.Dense(2500, activation='sigmoid')
    self.reshape = layers.Reshape((50, 50, 1))

    
  def call(self, inputs):
    x = self.dense_1(inputs)
    x = self.dense_2(x)
    x = self.reshape(x)
    return x

# %% [markdown]
# ## Variational Auto Encoder

# %%
a = tf.ones((10,3))

# %%
b = tf.ones(a.shape)

# %%
class VariationalAutoEncoder(tf.keras.Model):
  """Combines the encoder and decoder into an end-to-end model for training."""

  def __init__(self,
               num_classes,
               intermediate_dim=64,
               latent_dim=3,
               name='autoencoder',
               **kwargs):
    super(VariationalAutoEncoder, self).__init__(name=name, **kwargs)
    self.num_classes = num_classes
    self.encoder = Encoder(latent_dim=latent_dim,
                           intermediate_dim=intermediate_dim)
    self.stn = BilinearInterpolation((30, 30), name='stn_layer')
    self.digit_encoder = DigitEncoder()
    self.digit_decoder = DigitDecoder()
    self.re_stn = BilinearInterpolation((50, 50), name='stn_layer')
#     self.decoder = Decoder()

  def call(self, inputs):
    z_mean, z_log_var, z_where = self.encoder(inputs)
    n = z_where.shape[0]
    z_where_indexes = tf.repeat([[0,0,1,0,0,2]], n, axis=0)
    z_where_selections = tf.repeat([[1.0, 0.0 , 1.0, 0.0, 1.0, 1.0]], n, axis=0)
    z_where_modified = tf.gather(z_where, z_where_indexes, batch_dims=1)
    z_where_modified = tf.math.multiply(z_where_modified, z_where_selections)
    
    inverse_z_where =  tf.map_fn(lambda x: x/x[0], z_where)
    inverse_z_where_compliments = tf.repeat([[1.0, -1.0 , -1.0]], n, axis=0)    
    inverse_z_where = tf.math.multiply(inverse_z_where, inverse_z_where_compliments)
    
    inverse_z_where_modified = tf.gather(inverse_z_where, z_where_indexes, batch_dims=1)
    inverse_z_where_modified = tf.math.multiply(inverse_z_where_modified, z_where_selections)
    
    
    transformed_image = self.stn([inputs, z_where_modified])
    
    z_what_mean, z_what_log_var, z_what = self.digit_encoder(transformed_image)
    reconstructed_crop = self.digit_decoder(z_what)
    
    reconstructed_image = self.re_stn([reconstructed_crop, inverse_z_where_modified])
    
    # Add KL divergence regularization loss.
    kl_loss_where = - 0.5 * tf.reduce_mean(
        z_log_var - tf.square(z_mean) - tf.exp(z_log_var) + 1)
#     self.add_loss(kl_loss_where)
    
    kl_loss_what = - 0.5 * tf.reduce_mean(
        z_what_log_var - tf.square(z_what_mean) - tf.exp(z_what_log_var) + 1)
#     self.add_loss(kl_loss_what)
    
#     clipped_image = self.decoder(reconstructed_image)

    return transformed_image, [z_mean, z_log_var, z_where], [], reconstructed_image

# %%
num_classes = 10
vae = VariationalAutoEncoder(num_classes, 64, 6)

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
crossentropy_loss_fn = tf.keras.losses.BinaryCrossentropy()

# %% [markdown]
# ## Training

# %%
epochs = 100
batch_size = 128
iterations = x_train.shape[0] // batch_size
loss_metric = tf.keras.metrics.Mean()
mse_loss_fn = tf.keras.losses.MeanSquaredError()
mse_loss_log_fn = tf.keras.losses.MeanSquaredLogarithmicError()

# %%
def log_normal_pdf(sample, mean, logvar, raxis=1):
  log2pi = tf.math.log(2. * np.pi)
  return tf.reduce_sum(
      -.5 * ((sample - mean) ** 2. * tf.exp(-logvar) + logvar + log2pi),
      axis=raxis)

# %%
for epoch in range(epochs):  
    print('Start of epoch %d' % (epoch,))
    inital_loss = 0
    # Iterate over the batches of the dataset.
    for batch_arg in range(iterations):
        
        with tf.GradientTape() as tape:
            arg_0 = batch_arg * batch_size
            arg_1 = (batch_arg + 1) * batch_size
            x_batch = x_train[arg_0:arg_1]
            
            transformed_image, (z_mean, z_log_var, z_where), clipped_image ,reconstructed_image = vae(x_batch)
            
#             cross_ent = tf.nn.sigmoid_cross_entropy_with_logits(logits=classification, labels=y_batch)
#             logpx_z = -tf.reduce_sum(cross_ent, axis=[1])
#             logpz = log_normal_pdf(z_where, 0., 0.)
#             logqz_x = log_normal_pdf(z_where, z_mean, z_log_var)
#             loss =  -tf.reduce_mean(logpz - logqz_x)
            loss = crossentropy_loss_fn(x_batch, reconstructed_image)
#             print('***********')
#             print(loss)
            loss += sum(vae.losses)
            
            inital_loss += sum(vae.losses)
#             print(vae.losses)
#             print(inital_loss)
            
#             loss = crossentropy_loss_fn(y_batch, classification)
#             loss += sum(vae.losses)
        
        grads = tape.gradient(loss, vae.trainable_weights)
        optimizer.apply_gradients(zip(grads, vae.trainable_weights))
        
        loss_metric(loss)

        if batch_arg % 10 == 0:
          print('step %s: mean loss = %s' % (batch_arg, loss_metric.result()))
    print('Epoch loss:{}'.format(inital_loss))
# Out:
# Start of epoch 0
# WARNING:tensorflow:From /Users/chamathabeysinghe/Projects/monash/test/variational_auto_encoder/venv2/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:644: _EagerTensorBase.cpu (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.identity instead.
# step 0: mean loss = tf.Tensor(0.43105263, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.4113262, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.37702128, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.352796, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.33563355, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.32485336, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.3157154, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.30918854, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.30172372, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.29530868, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.28976908, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.28333828, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.27596843, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.2673059, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.25754637, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.24686185, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 1
# step 0: mean loss = tf.Tensor(0.24078622, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.23077975, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.22155811, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.21333149, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.20560832, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.19829832, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.19165927, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.18562977, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.18003784, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.17480752, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.16994296, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.1654381, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.16127132, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.15737276, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.15373123, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.15030886, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 2
# step 0: mean loss = tf.Tensor(0.14838096, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.14531004, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.14241204, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.13971388, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.13714112, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.1347068, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.132414, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.13024138, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.12814663, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.1261615, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.12428022, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.1224856, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.1207893, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.119154066, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.11758892, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.11608171, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 3
# step 0: mean loss = tf.Tensor(0.115222454, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.11382798, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.11248237, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.11121355, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.109976605, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.10878662, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.10765096, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.10655912, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.105483145, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.10445136, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.10346067, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.1025017, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.10158582, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.100688875, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.099821396, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.09897408, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 4
# step 0: mean loss = tf.Tensor(0.09848954, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.09769364, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.09691788, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.096183844, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.0954576, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.09475208, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.094073854, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.093415864, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.09275766, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.09212292, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.09151121, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.09091359, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.090340674, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.08977452, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.08922205, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.088677794, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 5
# step 0: mean loss = tf.Tensor(0.08836657, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.08785154, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.0873461, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.08686758, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.08638997, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.08592286, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.085473515, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.08503577, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.08459159, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.0841608, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.0837454, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.0833381, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.08294752, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.08255816, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.08217696, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.08179774, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 6
# step 0: mean loss = tf.Tensor(0.08158216, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.08122256, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.080868006, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.08053268, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.08019414, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.07986207, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.079542354, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.07922984, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.07890942, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.07859833, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.07829761, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.07800147, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.07771655, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.07743064, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.07714992, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.07687096, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 7
# step 0: mean loss = tf.Tensor(0.076712884, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.076447695, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.07618486, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.07593648, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.0756841, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.07543626, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.07519786, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.07496404, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.07472185, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.0744865, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.074258365, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.07403298, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.07381651, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.073598325, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.07338381, shape=(), dtype=float32)
# step 150: mean loss = tf.Tensor(0.073169395, shape=(), dtype=float32)
# Epoch loss:0
# Start of epoch 8
# step 0: mean loss = tf.Tensor(0.073048346, shape=(), dtype=float32)
# step 10: mean loss = tf.Tensor(0.0728436, shape=(), dtype=float32)
# step 20: mean loss = tf.Tensor(0.072640665, shape=(), dtype=float32)
# step 30: mean loss = tf.Tensor(0.072449856, shape=(), dtype=float32)
# step 40: mean loss = tf.Tensor(0.07225433, shape=(), dtype=float32)
# step 50: mean loss = tf.Tensor(0.072062194, shape=(), dtype=float32)
# step 60: mean loss = tf.Tensor(0.07187707, shape=(), dtype=float32)
# step 70: mean loss = tf.Tensor(0.07169623, shape=(), dtype=float32)
# step 80: mean loss = tf.Tensor(0.07150747, shape=(), dtype=float32)
# step 90: mean loss = tf.Tensor(0.07132321, shape=(), dtype=float32)
# step 100: mean loss = tf.Tensor(0.07114463, shape=(), dtype=float32)
# step 110: mean loss = tf.Tensor(0.07096814, shape=(), dtype=float32)
# step 120: mean loss = tf.Tensor(0.070798755, shape=(), dtype=float32)
# step 130: mean loss = tf.Tensor(0.070627056, shape=(), dtype=float32)
# step 140: mean loss = tf.Tensor(0.070457675, shape=(), dtype=float32)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-ea71d64e31cd> in <module>
#      29 #             loss += sum(vae.losses)
#      30
# ---> 31         grads = tape.gradient(loss, vae.trainable_weights)
#      32         optimizer.apply_gradients(zip(grads, vae.trainable_weights))
#      33
#
# ~/Projects/monash/test/variational_auto_encoder/venv2/lib/python3.7/site-packages/tensorflow/python/eager/backprop.py in gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1046         output_gradients=output_gradients,
#    1047         sources_raw=flat_sources_raw,
# -> 1048         unconnected_gradients=unconnected_gradients)
#    1049
#    1050     if not self._persistent:
#
# ~/Projects/monash/test/variational_auto_encoder/venv2/lib/python3.7/site-packages/tensorflow/python/eager/imperative_grad.py in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      75       output_gradients,
#      76       sources_raw,
# ---> 77       compat.as_str(unconnected_gradients.value))
#
# ~/Projects/monash/test/variational_auto_encoder/venv2/lib/python3.7/site-packages/tensorflow/python/eager/backprop.py in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     155       gradient_name_scope = "gradient_tape/"
#     156     with ops.name_scope(gradient_name_scope):
# --> 157       return grad_fn(mock_op, *out_grads)
#     158   else:
#     159     return grad_fn(mock_op, *out_grads)
#
# ~/Projects/monash/test/variational_auto_encoder/venv2/lib/python3.7/site-packages/tensorflow/python/ops/nn_grad.py in _Conv2DGrad(op, grad)
#     567   """Gradient function for Conv2D."""
#     568   dilations = op.get_attr("dilations")
# --> 569   strides = op.get_attr("strides")
#     570   padding = op.get_attr("padding")
#     571   explicit_paddings = op.get_attr("explicit_paddings")
#
# ~/Projects/monash/test/variational_auto_encoder/venv2/lib/python3.7/site-packages/tensorflow/python/eager/backprop.py in get_attr(self, attr)
#     109
#     110   def get_attr(self, attr):
# --> 111     typ = op_attr_type(self.type, attr)
#     112     for i in range(0, len(self.attrs), 2):
#     113       if self.attrs[i] == attr:
#
# ~/Projects/monash/test/variational_auto_encoder/venv2/lib/python3.7/site-packages/tensorflow/python/eager/backprop.py in op_attr_type(op_type, attr_name)
#      69 def op_attr_type(op_type, attr_name):
#      70   try:
# ---> 71     return _op_attr_type_cache[(op_type, attr_name)]
#      72   except KeyError:
#      73     context.ensure_initialized()
#
# KeyboardInterrupt:

# %%
vae.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder (Encoder)            multiple                  110896
# _________________________________________________________________
# stn_layer (BilinearInterpola multiple                  0
# _________________________________________________________________
# digit_encoder (DigitEncoder) multiple                  168120
# _________________________________________________________________
# decoder (DigitDecoder)       multiple                  257600
# _________________________________________________________________
# stn_layer (BilinearInterpola multiple                  0
# =================================================================
# Total params: 536,616
# Trainable params: 536,616
# Non-trainable params: 0
# _________________________________________________________________

# %%
visualize = x_train[0:60]

# %%
transformed_image, [z_mean, z_log_var, z_where], clipped_image, reconstructed_image = vae(visualize)
# transformed_image, [z_mean, z_log_var, z_where], clipped_image, reconstructed_image

# %%
z_mean
# Out:
# <tf.Tensor: shape=(60, 3), dtype=float32, numpy=
# array([[ 22.740723  ,  16.07249   ,   9.733703  ],
#        [ 16.168491  ,   1.3119354 ,  -7.570204  ],
#        [ 17.650446  ,   7.8471446 ,   0.27605417],
#        [ 12.99415   ,  12.05566   ,  -1.2210501 ],
#        [ 21.754234  ,  14.170747  , -11.686621  ],
#        [ 12.406997  ,   6.9520636 ,  -6.034303  ],
#        [ 15.08788   ,   8.524871  ,  -8.773995  ],
#        [ 24.406275  ,   0.800605  ,  11.470909  ],
#        [ 18.474321  ,  15.886259  ,   4.2581406 ],
#        [ 17.251213  ,  -3.1518574 ,  -5.2932277 ],
#        [ 27.444199  ,   4.654027  ,  -5.8168864 ],
#        [ 15.017496  ,   4.7240367 ,   5.425525  ],
#        [ 19.07197   ,   4.4481783 ,  -2.9455492 ],
#        [ 15.981754  ,  -1.9511243 ,   8.353288  ],
#        [ 15.762713  ,   8.870756  ,  -0.5423789 ],
#        [ 16.23362   ,  10.439758  ,  -0.24174413],
#        [ 18.790092  ,   6.4435983 ,  -5.0133867 ],
#        [ 17.855793  ,   9.903835  ,  -8.080615  ],
#        [ 16.545837  ,   6.401823  ,   7.1220307 ],
#        [ 16.983152  ,  -1.0243933 ,   7.12316   ],
#        [ 15.598977  ,   3.689337  ,  -9.136612  ],
#        [ 15.844978  ,   0.29925182,  -0.5273781 ],
#        [ 23.58739   ,   8.890946  ,  -8.374602  ],
#        [ 25.926416  ,  -3.3350194 ,  -6.299662  ],
#        [ 12.425573  ,  11.554876  ,   5.5435205 ],
#        [ 14.461543  ,   8.928297  ,  -2.2961519 ],
#        [ 19.142698  ,   1.5118906 ,   0.5526347 ],
#        [ 16.02243   ,   4.310829  ,   6.7169104 ],
#        [ 21.49974   ,  15.221132  , -11.332782  ],
#        [ 18.819384  ,  13.619498  ,   5.9491425 ],
#        [ 11.216131  ,  10.576015  ,  -0.61462414],
#        [ 11.482667  ,   9.248822  ,   6.4917173 ],
#        [ 19.39356   ,   4.8561683 ,   2.4001987 ],
#        [ 11.574816  ,   7.490437  ,   5.400976  ],
#        [ 23.643621  ,  13.989595  , -11.16188   ],
#        [ 16.245237  ,   8.10311   ,   6.99818   ],
#        [ 22.617266  ,  -2.8879664 ,   5.6712875 ],
#        [ 12.491118  ,  10.133916  ,  -6.2167687 ],
#        [ 18.25566   ,  12.946184  ,   2.5871081 ],
#        [ 13.926711  ,   4.3246794 ,  -7.987572  ],
#        [ 23.012093  ,   0.31623825,  -2.7608407 ],
#        [ 19.391462  ,   5.1388216 ,   1.3798068 ],
#        [ 19.24346   ,   4.521194  ,  -8.537521  ],
#        [ 15.946972  ,   7.059048  ,  -6.0214067 ],
#        [ 17.923471  ,   3.9027    ,   3.5550098 ],
#        [ 21.959585  ,   6.239724  ,   9.337205  ],
#        [ 23.70623   ,  17.192415  ,   4.4527087 ],
#        [ 12.813257  ,   6.2823563 ,   3.8148508 ],
#        [ 15.757186  ,   8.928354  ,   4.0169406 ],
#        [ 22.637775  ,  12.907886  ,   1.8523206 ],
#        [ 20.629202  ,  11.846492  ,  -9.221097  ],
#        [ 16.954433  ,  -2.321117  ,   3.1885371 ],
#        [ 22.01343   ,   6.4445686 ,  -2.3294797 ],
#        [ 10.504229  ,   3.08198   ,   0.7134373 ],
#        [ 12.81167   ,  11.186392  ,   0.92327553],
#        [ 12.145142  ,   0.6423268 ,   5.7049026 ],
#        [ 22.23505   ,  10.365061  ,   8.913088  ],
#        [ 17.622087  ,  -3.4457316 ,  -0.87538147],
#        [ 12.281208  ,   3.386573  ,   6.737228  ],
#        [ 17.225475  ,   1.008131  ,   0.715785  ]], dtype=float32)>

# %%
for i in range(60):
    plot_mnist_sample(transformed_image[i])

# %%
for i in range(10):
    plot_mnist_sample(visualize[i])

# %%
index = 0

# %%
mse_loss_log_fn(visualize, reconstructed_image)

# %%
mse_loss_log_fn(visualize, reconstructed_image)

# %%
plot_mnist_grid(visualize)

# %%
plot_mnist_grid(transformed_image)

# %%
result[3].shape

# %%
plot_mnist_grid(reconstructed_image)
